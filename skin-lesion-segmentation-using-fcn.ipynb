# %% [markdown]
# ## Importing the Libraries

# %%
from keras.models import Model, Sequential
from keras.layers import Activation, Dense, BatchNormalization, Dropout, Conv2D, Conv2DTranspose, MaxPooling2D, UpSampling2D, Input, Reshape
from keras.callbacks import EarlyStopping
from keras import backend as K
from keras.optimizers import Adam
import tensorflow as tf
import numpy as np
import pandas as pd
import glob
import PIL
from PIL import Image
import matplotlib.pyplot as plt
import cv2
# %matplotlib inline

from keras.preprocessing.image import ImageDataGenerator
from sklearn.model_selection import train_test_split
from warnings import filterwarnings

filterwarnings('ignore')
plt.rcParams["axes.grid"] = False
np.random.seed(101)
# Out:
# Using TensorFlow backend.

# %% [markdown]
# ## Loading the Data

# %% [markdown]
# Defining a function to load the data in sorted order

# %%
import re
numbers = re.compile(r'(\d+)')
def numericalSort(value):
    parts = numbers.split(value)
    parts[1::2] = map(int, parts[1::2])
    return parts

# %%
filelist_trainx = sorted(glob.glob('../input/*/trainx/*.bmp'), key=numericalSort)
X_train = np.array([np.array(Image.open(fname)) for fname in filelist_trainx])

filelist_trainy = sorted(glob.glob('../input/*/trainy/*.bmp'), key=numericalSort)
Y_train = np.array([np.array(Image.open(fname)) for fname in filelist_trainy])

# %% [markdown]
# Splitting the dataset into training set and test set to verify our model performance without any bias.

# %%
x_train, x_test, y_train, y_test = train_test_split(X_train, Y_train, test_size = 0.25)

# %% [markdown]
# Let's plot an image to see how the original images look.

# %%
plt.figure(figsize=(20,9))
plt.subplot(2,4,1)
plt.imshow(X_train[0])
plt.subplot(2,4,2)
plt.imshow(X_train[3])
plt.subplot(2,4,3)
plt.imshow(X_train[54])
plt.subplot(2,4,4)
plt.imshow(X_train[77])
plt.subplot(2,4,5)
plt.imshow(X_train[100])
plt.subplot(2,4,6)
plt.imshow(X_train[125])
plt.subplot(2,4,7)
plt.imshow(X_train[130])
plt.subplot(2,4,8)
plt.imshow(X_train[149])
plt.show()

# %% [markdown]
# Now let's see their corresponding masks.

# %%
plt.figure(figsize=(20,9))
plt.subplot(2,4,1)
plt.imshow(Y_train[0], cmap = plt.cm.binary_r)
plt.subplot(2,4,2)
plt.imshow(Y_train[3], cmap = plt.cm.binary_r)
plt.subplot(2,4,3)
plt.imshow(Y_train[54], cmap = plt.cm.binary_r)
plt.subplot(2,4,4)
plt.imshow(Y_train[77], cmap = plt.cm.binary_r)
plt.subplot(2,4,5)
plt.imshow(Y_train[100], cmap = plt.cm.binary_r)
plt.subplot(2,4,6)
plt.imshow(Y_train[125], cmap = plt.cm.binary_r)
plt.subplot(2,4,7)
plt.imshow(Y_train[130], cmap = plt.cm.binary_r)
plt.subplot(2,4,8)
plt.imshow(Y_train[149], cmap = plt.cm.binary_r)
plt.show()

# %% [markdown]
# ## Defining the Loss Function

# %% [markdown]
# #### Jaccard Distance
# The Jaccard distance, which measures dissimilarity between sample sets, is complementary to the Jaccard coefficient and is obtained by subtracting the Jaccard coefficient from 1, or, equivalently, by dividing the difference of the sizes of the union and the intersection of two sets by the size of the union:

# %% [markdown]
# ![jd](https://www.geeksforgeeks.org/wp-content/ql-cache/quicklatex.com-44046533fcd54e98cb53619b3390e083_l3.svg)

# %%
def jaccard_distance(y_true, y_pred, smooth=100):
    intersection = K.sum(K.abs(y_true * y_pred), axis=-1)
    sum_ = K.sum(K.square(y_true), axis = -1) + K.sum(K.square(y_pred), axis=-1)
    jac = (intersection + smooth) / (sum_ - intersection + smooth)
    return (1 - jac)

# %% [markdown]
# ## Defining Evaluation Metrics

# %% [markdown]
# #### Intersection over Union
# The Jaccard index, also known as Intersection over Union and the Jaccard similarity coefficient is a statistic used for gauging the similarity and diversity of sample sets. The Jaccard coefficient measures similarity between finite sample sets, and is defined as the size of the intersection divided by the size of the union of the sample sets:

# %% [markdown]
# ![iou](https://www.d2l.ai/_images/iou.svg)

# %%
def iou(y_true, y_pred, smooth = 100):
    intersection = K.sum(K.abs(y_true * y_pred), axis=-1)
    sum_ = K.sum(K.square(y_true), axis = -1) + K.sum(K.square(y_pred), axis=-1)
    jac = (intersection + smooth) / (sum_ - intersection + smooth)
    return jac

# %% [markdown]
# #### Dice coefficient
# The Dice score is not only a measure of how many positives you find, but it also penalizes for the false positives that the method finds, similar to precision. so it is more similar to precision than accuracy.

# %% [markdown]
# ![dc](https://cdn-images-1.medium.com/max/1600/1*Z1hkDvyhFBogT9EkzVkX2A.png)

# %%
def dice_coef(y_true, y_pred, smooth = 100):
    y_true_f = K.flatten(y_true)
    y_pred_f = K.flatten(y_pred)
    intersection = K.sum(y_true_f * y_pred_f)
    return (2. * intersection + smooth) / (K.sum(y_true_f) + K.sum(y_pred_f) + smooth)

# %% [markdown]
# #### Precision
# Precision is a good measure to determine, when the costs of False Positive is high.

# %% [markdown]
# ![precsion](https://wikimedia.org/api/rest_v1/media/math/render/svg/26106935459abe7c266f7b1ebfa2a824b334c807)

# %%
def precision(y_true, y_pred):
    '''Calculates the precision, a metric for multi-label classification of
    how many selected items are relevant.
    '''
    true_positives = K.sum(K.round(K.clip(y_true * y_pred, 0, 1)))
    predicted_positives = K.sum(K.round(K.clip(y_pred, 0, 1)))
    precision = true_positives / (predicted_positives + K.epsilon())
    return precision

# %% [markdown]
# #### Recall
# Recall actually calculates how many of the Actual Positives our model capture through labeling it as Positive (True Positive). Applying the same understanding, we know that Recall shall be the model metric we use to select our best model when there is a high cost associated with False Negative.

# %% [markdown]
# ![recall](https://wikimedia.org/api/rest_v1/media/math/render/svg/4c233366865312bc99c832d1475e152c5074891b)

# %%
def recall(y_true, y_pred):
    '''Calculates the recall, a metric for multi-label classification of
    how many relevant items are selected.
    '''
    true_positives = K.sum(K.round(K.clip(y_true * y_pred, 0, 1)))
    possible_positives = K.sum(K.round(K.clip(y_true, 0, 1)))
    recall = true_positives / (possible_positives + K.epsilon())
    return recall

# %% [markdown]
# #### Accuracy

# %%
def accuracy(y_true, y_pred):
    '''Calculates the mean accuracy rate across all predictions for binary
    classification problems.
    '''
    return K.mean(K.equal(y_true, K.round(y_pred)))

# %%
epsilon = 1e-5
smooth = 1

def tversky(y_true, y_pred):
    y_true_pos = K.flatten(y_true)
    y_pred_pos = K.flatten(y_pred)
    true_pos = K.sum(y_true_pos * y_pred_pos)
    false_neg = K.sum(y_true_pos * (1-y_pred_pos))
    false_pos = K.sum((1-y_true_pos)*y_pred_pos)
    alpha = 0.7
    return (true_pos + smooth)/(true_pos + alpha*false_neg + (1-alpha)*false_pos + smooth)

def focal_tversky(y_true,y_pred):
    y_true = tf.cast(y_true, tf.float32)
    y_pred = tf.cast(y_pred, tf.float32)
    
    pt_1 = tversky(y_true, y_pred)
    gamma = 0.75
    return K.pow((1-pt_1), gamma)

def tversky_loss(y_true, y_pred):
    return 1 - tversky(y_true,y_pred)

# %% [markdown]
# ## Image Augmentation
# To build a powerful image classifier using very little training data, image augmentation is usually required to boost the performance of deep networks. Image augmentation artificially creates training images through different ways of processing or combination of multiple processing, such as random rotation, shifts, shear and flips, etc.

# %% [markdown]
# We are going to define to methods for augmentation, one for **random rotation** and one for **horizontal flipping**

# %%
def random_rotation(x_image, y_image):
    rows_x,cols_x, chl_x = x_image.shape
    rows_y,cols_y = y_image.shape
    rand_num = np.random.randint(-40,40)
    M1 = cv2.getRotationMatrix2D((cols_x/2,rows_x/2),rand_num,1)
    M2 = cv2.getRotationMatrix2D((cols_y/2,rows_y/2),rand_num,1)
    x_image = cv2.warpAffine(x_image,M1,(cols_x,rows_x))
    y_image = cv2.warpAffine(y_image.astype('float32'),M2,(cols_y,rows_y))
    return x_image, y_image.astype('int')

def horizontal_flip(x_image, y_image):
    x_image = cv2.flip(x_image, 1)
    y_image = cv2.flip(y_image.astype('float32'), 1)
    return x_image, y_image.astype('int')

# %%
def img_augmentation(x_train, y_train):
    x_rotat = []
    y_rotat = []
    x_flip = []
    y_flip = []
    x_nois = []
    for idx in range(len(x_train)):
        x,y = random_rotation(x_train[idx], y_train[idx])
        x_rotat.append(x)
        y_rotat.append(y)
        
        x,y = horizontal_flip(x_train[idx], y_train[idx])
        x_flip.append(x)
        y_flip.append(y)
        return np.array(x_rotat), np.array(y_rotat), np.array(x_flip), np.array(y_flip)

# %%
def img_augmentation(x_test, y_test):
    x_rotat = []
    y_rotat = []
    x_flip = []
    y_flip = []
    x_nois = []
    for idx in range(len(x_test)):
        x,y = random_rotation(x_test[idx], y_test[idx])
        x_rotat.append(x)
        y_rotat.append(y)
        
        x,y = horizontal_flip(x_test[idx], y_test[idx])
        x_flip.append(x)
        y_flip.append(y)

    return np.array(x_rotat), np.array(y_rotat), np.array(x_flip), np.array(y_flip)

# %% [markdown]
# calling the functions for the training data.

# %%
x_rotated, y_rotated, x_flipped, y_flipped = img_augmentation(x_train, y_train)
x_rotated_t, y_rotated_t, x_flipped_t, y_flipped_t = img_augmentation(x_test, y_test)

# %% [markdown]
# Let us have a look at our transformations.

# %%
img_num = 114
plt.figure(figsize=(12,12))
plt.subplot(3,2,1)
plt.imshow(x_train[img_num])
plt.title('Original Image')
plt.subplot(3,2,2)
plt.imshow(y_train[img_num], plt.cm.binary_r)
plt.title('Original Mask')
plt.subplot(3,2,3)
plt.imshow(x_rotated[img_num])
plt.title('Rotated Image')
plt.subplot(3,2,4)
plt.imshow(y_rotated[img_num], plt.cm.binary_r)
plt.title('Rotated Mask')
plt.subplot(3,2,5)
plt.imshow(x_flipped[img_num])
plt.title('Flipped Image')
plt.subplot(3,2,6)
plt.imshow(y_flipped[img_num], plt.cm.binary_r)
plt.title('Flipped Mask')
plt.show()

# %% [markdown]
# Now we join all the augmentations image arrays to the original training arrays.

# %%
# For training Set
x_train_full = np.concatenate([x_train, x_rotated, x_flipped])
y_train_full = np.concatenate([y_train, y_rotated, y_flipped])

# %% [markdown]
# #### Making a Validation Set
# We will split our full training set into train and validation set.
# Validation dataset is used to validate the performance after each epoch.

# %%
x_train, x_val, y_train, y_val = train_test_split(x_train_full, y_train_full, test_size = 0.20, random_state = 101)

# %%
print("Length of the Training Set   : {}".format(len(x_train)))
print("Length of the Test Set       : {}".format(len(x_test)))
print("Length of the Validation Set : {}".format(len(x_val)))
# Out:
# Length of the Training Set   : 360
# Length of the Test Set       : 50
# Length of the Validation Set : 90

# %% [markdown]
# ## The Model

# %% [markdown]
# Defining the model in a function which takes two arguments when called
# * **epoch_num**: number of epochs to run
# * **savename**: the name of the model for saving after training

# %% [markdown]
# #### Optimizer and Learning Rate
# * We adopt adam optimization algorithm or adaptive moments, to adjust the learning rate.
# * It is well known that learning rate is one of the critical hyperparameters that have a signiﬁcant impact on classiﬁcation performance.
# * Advantages of Adam optimizer are:
#     - Relatively low memory requirements (though higher than gradient descent and gradient descent with momentum).
#     - Usually works well even with a little tuning of hyperparameter
# * Adam is fairly robust to the choice of hyperparameters, and set the learning rate **α** as 0.003 to speed up the training procedure in this study as advised in the paper [here](https://arxiv.org/pdf/1703.05165v2.pdf)

# %% [markdown]
# ### Model Function

# %% [markdown]
# ![arch](https://raw.githubusercontent.com/hashbanger/Skin_Lesion_Segmentation/master/graphics/fcn_arch.png)

# %%
def fcn_net(epochs_num,savename):

    # Convolution Layers (BatchNorm after non-linear activation)

    img_input = Input(shape= (192, 256, 3))
    x = Conv2D(16, (5, 5), padding='same', name='conv1',strides= (1,1))(img_input)
    x = BatchNormalization(name='bn1')(x)
    x = Activation('relu')(x)
    x = Conv2D(32, (3, 3), padding='same', name='conv2')(x)
    x = BatchNormalization(name='bn2')(x)
    x = Activation('relu')(x)
    x = MaxPooling2D()(x)
    x = Conv2D(64, (4, 4), padding='same', name='conv3')(x)
    x = BatchNormalization(name='bn3')(x)
    x = Activation('relu')(x)
    x = Conv2D(64, (4, 4), padding='same', name='conv4')(x)
    x = BatchNormalization(name='bn4')(x)
    x = Activation('relu')(x)
    x = MaxPooling2D()(x)
    
    x = Dropout(0.5)(x)
    
    x = Conv2D(512, (3, 3), padding='same', name='conv5')(x)
    x = BatchNormalization(name='bn5')(x)
    x = Activation('relu')(x)
    x = Dense(1024, activation = 'relu', name='fc1')(x)
    x = Dense(1024, activation = 'relu', name='fc2')(x)

    # Deconvolution Layers (BatchNorm after non-linear activation)

    x = Conv2DTranspose(256, (3, 3), padding='same', name='deconv1')(x)
    x = BatchNormalization(name='bn6')(x)
    x = Activation('relu')(x)
    x = UpSampling2D()(x)
    x = Conv2DTranspose(256, (3, 3), padding='same', name='deconv2')(x)
    x = BatchNormalization(name='bn7')(x)
    x = Activation('relu')(x)
    x = Conv2DTranspose(128, (3, 3), padding='same', name='deconv3')(x)
    x = BatchNormalization(name='bn8')(x)
    x = Activation('relu')(x)
    x = UpSampling2D()(x)
    x = Conv2DTranspose(1, (3, 3), padding='same', name='deconv4')(x)
    x = BatchNormalization(name='bn9')(x)
    
    x = Dropout(0.5)(x)

    x = Activation('sigmoid')(x)
    pred = Reshape((192,256))(x)
    
    model = Model(inputs=img_input, outputs=pred)
    
    model.compile(optimizer= Adam(lr = 0.003), loss= [jaccard_distance]
                  , metrics=[iou, dice_coef, precision, recall, accuracy,tversky])

    hist = model.fit(x_train, y_train, epochs= epochs_num, batch_size= 18, validation_data= (x_val, y_val), verbose=1)

    model.save(savename)
    return model,hist

# %% [markdown]
# <font color='red'>**Problems In Guided Dropout Implementation**
#
# - The entire network architecture is implemented using Keras.
# - Now to implement the Guided Dropout Layer using Keras we have to know the detailed backend of the Keras Library because:
# - We should know in what form the inputs will be coming to our layer so we could manipulate them.
# - We should also know in what form the output should be given to the next layer.
# - If we implement Guided Dropout from scratch then we will have to implement entire architecture from scratch which will be neither efficient nor easily feasible.</font>

# %% [markdown]
# **After 1 epoch**

# %%
model, hist = fcn_net(epochs_num= 1, savename= 'fcn_1_epochs.h5')
# Out:
# Train on 360 samples, validate on 90 samples
# Epoch 1/1
# 360/360 [==============================] - 13s 36ms/step - loss: 0.2718 - iou: 0.7282 - dice_coef: 0.4778 - precision: 0.6617 - recall: 0.3432 - accuracy: 0.7258 - tversky: 0.5169 - val_loss: 0.4831 - val_iou: 0.5169 - val_dice_coef: 0.4818 - val_precision: 0.3144 - val_recall: 1.0000 - val_accuracy: 0.3163 - val_tversky: 0.6064

# %% [markdown]
# ## Loading the Model

# %% [markdown]
# Here we can load a pretrained model

# %%
img_input = Input(shape= (192, 256, 3))
x = Conv2D(16, (5, 5), padding='same', name='conv1',strides= (1,1))(img_input)
x = BatchNormalization(name='bn1')(x)
x = Activation('relu')(x)
x = Conv2D(32, (3, 3), padding='same', name='conv2')(x)
x = BatchNormalization(name='bn2')(x)
x = Activation('relu')(x)
x = MaxPooling2D()(x)
x = Conv2D(64, (4, 4), padding='same', name='conv3')(x)
x = BatchNormalization(name='bn3')(x)
x = Activation('relu')(x)
x = Conv2D(64, (4, 4), padding='same', name='conv4')(x)
x = BatchNormalization(name='bn4')(x)
x = Activation('relu')(x)
x = MaxPooling2D()(x)

x = Dropout(0.5)(x)

x = Conv2D(512, (3, 3), padding='same', name='conv5')(x)
x = BatchNormalization(name='bn5')(x)
x = Activation('relu')(x)
x = Dense(1024, activation = 'relu', name='fc1')(x)
x = Dense(1024, activation = 'relu', name='fc2')(x)

# Deconvolution Layers (BatchNorm after non-linear activation)

x = Conv2DTranspose(256, (3, 3), padding='same', name='deconv1')(x)
x = BatchNormalization(name='bn6')(x)
x = Activation('relu')(x)
x = UpSampling2D()(x)
x = Conv2DTranspose(256, (3, 3), padding='same', name='deconv2')(x)
x = BatchNormalization(name='bn7')(x)
x = Activation('relu')(x)
x = Conv2DTranspose(128, (3, 3), padding='same', name='deconv3')(x)
x = BatchNormalization(name='bn8')(x)
x = Activation('relu')(x)
x = UpSampling2D()(x)
x = Conv2DTranspose(1, (3, 3), padding='same', name='deconv4')(x)
x = BatchNormalization(name='bn9')(x)

x = Dropout(0.5)(x)

x = Activation('sigmoid')(x)
pred = Reshape((192,256))(x)

# %%
model_0 = Model(inputs=img_input, outputs=pred)
model_0.compile(optimizer= Adam(lr = 0.003), loss= [jaccard_distance], metrics=[iou, dice_coef, precision, recall, accuracy,tversky])

# %%
model_0.load_weights('fcn_1_epochs.h5')

# %%
print('\n~~~~~~~~~~~~~~~Stats after 1 epoch~~~~~~~~~~~~~~~~~~~')
print('\n-------------On Train Set--------------------------\n')
res = model_0.evaluate(x_train, y_train, batch_size= 18)
print('________________________')
print('IOU:       |   {:.2f}  |'.format(res[1]*100))
print('Dice Coef: |   {:.2f}  |'.format(res[2]*100))
print('Precision: |   {:.2f}  |'.format(res[3]*100))
print('Recall:    |   {:.2f}  |'.format(res[4]*100))
print('Accuracy:  |   {:.2f}  |'.format(res[5]*100))
print('Tversky:   |   {:.2f}  |'.format(res[6]*100))
print("Loss:      |   {:.2f}  |".format(res[0]*100))
print('________________________')
print('\n-------------On Test  Set--------------------------\n')
res = model_0.evaluate(x_test, y_test, batch_size= 18)
print('________________________')
print('IOU:       |   {:.2f}  |'.format(res[1]*100))
print('Dice Coef: |   {:.2f}  |'.format(res[2]*100))
print('Precision: |   {:.2f}  |'.format(res[3]*100))
print('Recall:    |   {:.2f}  |'.format(res[4]*100))
print('Accuracy:  |   {:.2f}  |'.format(res[5]*100))
print('Tversky:   |   {:.2f}  |'.format(res[6]*100))
print("Loss:      |   {:.2f}  |".format(res[0]*100))
print('________________________')
print('\n-------------On validation Set---------------------\n')
res = model_0.evaluate(x_val, y_val, batch_size= 18)
print('________________________')
print('IOU:       |   {:.2f}  |'.format(res[1]*100))
print('Dice Coef: |   {:.2f}  |'.format(res[2]*100))
print('Precision: |   {:.2f}  |'.format(res[3]*100))
print('Recall:    |   {:.2f}  |'.format(res[4]*100))
print('Accuracy:  |   {:.2f}  |'.format(res[5]*100))
print('Tversky:   |   {:.2f}  |'.format(res[6]*100))
print("Loss:      |   {:.2f}  |".format(res[0]*100))
print('________________________')
# Out:
# ~~~~~~~~~~~~~~~Stats after 1 epoch~~~~~~~~~~~~~~~~~~~
#
# -------------On Train Set--------------------------
#
# 360/360 [==============================] - 3s 8ms/step
# ________________________
# IOU:       |   52.40  |
# Dice Coef: |   49.07  |
# Precision: |   32.42  |
# Recall:    |   99.99  |
# Accuracy:  |   32.65  |
# Tversky:   |   61.31  |
# Loss:      |   47.60  |
# ________________________
#
# -------------On Test  Set--------------------------
#
# 50/50 [==============================] - 1s 15ms/step
# ________________________
# IOU:       |   51.68  |
# Dice Coef: |   48.18  |
# Precision: |   31.48  |
# Recall:    |   100.00  |
# Accuracy:  |   31.71  |
# Tversky:   |   60.60  |
# Loss:      |   48.32  |
# ________________________
#
# -------------On validation Set---------------------
#
# 90/90 [==============================] - 1s 7ms/step
# ________________________
# IOU:       |   51.69  |
# Dice Coef: |   48.18  |
# Precision: |   31.44  |
# Recall:    |   100.00  |
# Accuracy:  |   31.63  |
# Tversky:   |   60.64  |
# Loss:      |   48.31  |
# ________________________

# %% [markdown]
# #### After 100 epochs

# %%
model, hist = fcn_net(epochs_num= 100, savename= 'fcn_100_epoch.h5')
# Out:
# Train on 360 samples, validate on 90 samples
# Epoch 1/100
# 360/360 [==============================] - 10s 27ms/step - loss: 0.2636 - iou: 0.7364 - dice_coef: 0.4977 - precision: 0.6937 - recall: 0.3959 - accuracy: 0.7308 - tversky: 0.5398 - val_loss: 0.2187 - val_iou: 0.7813 - val_dice_coef: 0.6557 - val_precision: 0.5573 - val_recall: 0.8643 - val_accuracy: 0.7426 - val_tversky: 0.7272
# Epoch 2/100
# 360/360 [==============================] - 7s 19ms/step - loss: 0.2345 - iou: 0.7655 - dice_coef: 0.5341 - precision: 0.8197 - recall: 0.4143 - accuracy: 0.7798 - tversky: 0.5749 - val_loss: 0.2183 - val_iou: 0.7817 - val_dice_coef: 0.4235 - val_precision: 0.9984 - val_recall: 0.1923 - val_accuracy: 0.7485 - val_tversky: 0.3805
# Epoch 3/100
# 360/360 [==============================] - 7s 19ms/step - loss: 0.2318 - iou: 0.7682 - dice_coef: 0.5331 - precision: 0.8596 - recall: 0.3949 - accuracy: 0.7827 - tversky: 0.5708 - val_loss: 0.1916 - val_iou: 0.8084 - val_dice_coef: 0.4882 - val_precision: 0.9759 - val_recall: 0.3666 - val_accuracy: 0.8011 - val_tversky: 0.4836
# Epoch 4/100
# 360/360 [==============================] - 7s 19ms/step - loss: 0.2300 - iou: 0.7700 - dice_coef: 0.5402 - precision: 0.8395 - recall: 0.4100 - accuracy: 0.7824 - tversky: 0.5785 - val_loss: 0.1509 - val_iou: 0.8491 - val_dice_coef: 0.6066 - val_precision: 0.9111 - val_recall: 0.5661 - val_accuracy: 0.8473 - val_tversky: 0.6178
# Epoch 5/100
# 360/360 [==============================] - 7s 19ms/step - loss: 0.2268 - iou: 0.7732 - dice_coef: 0.5443 - precision: 0.8642 - recall: 0.4063 - accuracy: 0.7862 - tversky: 0.5808 - val_loss: 0.2540 - val_iou: 0.7460 - val_dice_coef: 0.4230 - val_precision: 0.6131 - val_recall: 0.3582 - val_accuracy: 0.7262 - val_tversky: 0.4349
# Epoch 6/100
# 360/360 [==============================] - 7s 19ms/step - loss: 0.2237 - iou: 0.7763 - dice_coef: 0.5510 - precision: 0.8714 - recall: 0.4126 - accuracy: 0.7891 - tversky: 0.5867 - val_loss: 0.3840 - val_iou: 0.6160 - val_dice_coef: 0.5201 - val_precision: 0.3624 - val_recall: 0.9724 - val_accuracy: 0.4564 - val_tversky: 0.6259
# Epoch 7/100
# 360/360 [==============================] - 7s 19ms/step - loss: 0.2256 - iou: 0.7744 - dice_coef: 0.5475 - precision: 0.8640 - recall: 0.4061 - accuracy: 0.7851 - tversky: 0.5829 - val_loss: 0.3038 - val_iou: 0.6962 - val_dice_coef: 0.1748 - val_precision: 0.0000e+00 - val_recall: 0.0000e+00 - val_accuracy: 0.6865 - val_tversky: 0.1499
# Epoch 8/100
# 360/360 [==============================] - 7s 19ms/step - loss: 0.2238 - iou: 0.7762 - dice_coef: 0.5558 - precision: 0.8521 - recall: 0.4183 - accuracy: 0.7875 - tversky: 0.5910 - val_loss: 0.2706 - val_iou: 0.7294 - val_dice_coef: 0.2549 - val_precision: 1.0000 - val_recall: 0.0024 - val_accuracy: 0.6872 - val_tversky: 0.2245
# Epoch 9/100
# 360/360 [==============================] - 7s 19ms/step - loss: 0.2214 - iou: 0.7786 - dice_coef: 0.5551 - precision: 0.8807 - recall: 0.4114 - accuracy: 0.7902 - tversky: 0.5894 - val_loss: 0.1945 - val_iou: 0.8055 - val_dice_coef: 0.5583 - val_precision: 0.6488 - val_recall: 0.7667 - val_accuracy: 0.7973 - val_tversky: 0.5947
# Epoch 10/100
# 360/360 [==============================] - 7s 19ms/step - loss: 0.2252 - iou: 0.7748 - dice_coef: 0.5549 - precision: 0.8389 - recall: 0.4185 - accuracy: 0.7840 - tversky: 0.5903 - val_loss: 0.1739 - val_iou: 0.8261 - val_dice_coef: 0.5649 - val_precision: 0.8248 - val_recall: 0.6178 - val_accuracy: 0.8384 - val_tversky: 0.5884
# Epoch 11/100
# 360/360 [==============================] - 7s 19ms/step - loss: 0.2205 - iou: 0.7795 - dice_coef: 0.5596 - precision: 0.8706 - recall: 0.4192 - accuracy: 0.7910 - tversky: 0.5942 - val_loss: 0.2230 - val_iou: 0.7770 - val_dice_coef: 0.5496 - val_precision: 0.5804 - val_recall: 0.7312 - val_accuracy: 0.7514 - val_tversky: 0.5974
# Epoch 12/100
# 360/360 [==============================] - 7s 19ms/step - loss: 0.2176 - iou: 0.7824 - dice_coef: 0.5636 - precision: 0.8806 - recall: 0.4242 - accuracy: 0.7939 - tversky: 0.5977 - val_loss: 0.1362 - val_iou: 0.8638 - val_dice_coef: 0.6607 - val_precision: 0.7933 - val_recall: 0.9183 - val_accuracy: 0.8998 - val_tversky: 0.7162
# Epoch 13/100
# 360/360 [==============================] - 7s 19ms/step - loss: 0.2178 - iou: 0.7822 - dice_coef: 0.5661 - precision: 0.8743 - recall: 0.4280 - accuracy: 0.7936 - tversky: 0.6006 - val_loss: 0.1604 - val_iou: 0.8396 - val_dice_coef: 0.6476 - val_precision: 0.7536 - val_recall: 0.8997 - val_accuracy: 0.8763 - val_tversky: 0.7126
# Epoch 14/100
# 360/360 [==============================] - 7s 19ms/step - loss: 0.2158 - iou: 0.7842 - dice_coef: 0.5700 - precision: 0.8874 - recall: 0.4260 - accuracy: 0.7960 - tversky: 0.6036 - val_loss: 0.1802 - val_iou: 0.8198 - val_dice_coef: 0.6586 - val_precision: 0.6261 - val_recall: 0.9610 - val_accuracy: 0.8070 - val_tversky: 0.7319
# Epoch 15/100
# 360/360 [==============================] - 7s 19ms/step - loss: 0.2188 - iou: 0.7812 - dice_coef: 0.5663 - precision: 0.8656 - recall: 0.4263 - accuracy: 0.7917 - tversky: 0.6005 - val_loss: 0.1467 - val_iou: 0.8533 - val_dice_coef: 0.5967 - val_precision: 0.8988 - val_recall: 0.6601 - val_accuracy: 0.8704 - val_tversky: 0.6134
# Epoch 16/100
# 360/360 [==============================] - 7s 19ms/step - loss: 0.2137 - iou: 0.7863 - dice_coef: 0.5750 - precision: 0.8976 - recall: 0.4284 - accuracy: 0.7986 - tversky: 0.6084 - val_loss: 0.1884 - val_iou: 0.8116 - val_dice_coef: 0.5179 - val_precision: 0.9623 - val_recall: 0.5229 - val_accuracy: 0.8435 - val_tversky: 0.5296
# Epoch 17/100
# 360/360 [==============================] - 7s 19ms/step - loss: 0.2128 - iou: 0.7872 - dice_coef: 0.5766 - precision: 0.8904 - recall: 0.4341 - accuracy: 0.7995 - tversky: 0.6103 - val_loss: 0.1571 - val_iou: 0.8429 - val_dice_coef: 0.5807 - val_precision: 0.9051 - val_recall: 0.6731 - val_accuracy: 0.8748 - val_tversky: 0.6030
# Epoch 18/100
# 360/360 [==============================] - 7s 19ms/step - loss: 0.2125 - iou: 0.7875 - dice_coef: 0.5785 - precision: 0.8937 - recall: 0.4339 - accuracy: 0.7995 - tversky: 0.6121 - val_loss: 0.1425 - val_iou: 0.8575 - val_dice_coef: 0.6075 - val_precision: 0.9022 - val_recall: 0.6785 - val_accuracy: 0.8758 - val_tversky: 0.6219
# Epoch 19/100
# 360/360 [==============================] - 7s 19ms/step - loss: 0.2106 - iou: 0.7894 - dice_coef: 0.5812 - precision: 0.9051 - recall: 0.4346 - accuracy: 0.8023 - tversky: 0.6143 - val_loss: 0.1416 - val_iou: 0.8584 - val_dice_coef: 0.6637 - val_precision: 0.7381 - val_recall: 0.9396 - val_accuracy: 0.8766 - val_tversky: 0.7246
# Epoch 20/100
# 360/360 [==============================] - 7s 19ms/step - loss: 0.2093 - iou: 0.7907 - dice_coef: 0.5850 - precision: 0.9043 - recall: 0.4400 - accuracy: 0.8039 - tversky: 0.6187 - val_loss: 0.2419 - val_iou: 0.7581 - val_dice_coef: 0.5526 - val_precision: 0.5237 - val_recall: 0.8700 - val_accuracy: 0.7093 - val_tversky: 0.6195
# Epoch 21/100
# 360/360 [==============================] - 7s 19ms/step - loss: 0.2147 - iou: 0.7853 - dice_coef: 0.5747 - precision: 0.8848 - recall: 0.4285 - accuracy: 0.7957 - tversky: 0.6080 - val_loss: 0.1296 - val_iou: 0.8704 - val_dice_coef: 0.6635 - val_precision: 0.7701 - val_recall: 0.9327 - val_accuracy: 0.8919 - val_tversky: 0.7134
# Epoch 22/100
# 360/360 [==============================] - 7s 19ms/step - loss: 0.2137 - iou: 0.7863 - dice_coef: 0.5766 - precision: 0.8970 - recall: 0.4288 - accuracy: 0.7988 - tversky: 0.6091 - val_loss: 0.2231 - val_iou: 0.7769 - val_dice_coef: 0.6060 - val_precision: 0.5461 - val_recall: 0.8388 - val_accuracy: 0.7352 - val_tversky: 0.6754
# Epoch 23/100
# 360/360 [==============================] - 7s 19ms/step - loss: 0.2121 - iou: 0.7879 - dice_coef: 0.5807 - precision: 0.8951 - recall: 0.4338 - accuracy: 0.8002 - tversky: 0.6135 - val_loss: 0.1878 - val_iou: 0.8122 - val_dice_coef: 0.5932 - val_precision: 0.6480 - val_recall: 0.8437 - val_accuracy: 0.8054 - val_tversky: 0.6469
# Epoch 24/100
# 360/360 [==============================] - 7s 19ms/step - loss: 0.2078 - iou: 0.7922 - dice_coef: 0.5887 - precision: 0.9114 - recall: 0.4423 - accuracy: 0.8056 - tversky: 0.6218 - val_loss: 0.0917 - val_iou: 0.9083 - val_dice_coef: 0.7193 - val_precision: 0.8905 - val_recall: 0.9035 - val_accuracy: 0.9338 - val_tversky: 0.7594
# Epoch 25/100
# 360/360 [==============================] - 7s 19ms/step - loss: 0.2131 - iou: 0.7869 - dice_coef: 0.5775 - precision: 0.9052 - recall: 0.4289 - accuracy: 0.7986 - tversky: 0.6100 - val_loss: 0.3946 - val_iou: 0.6054 - val_dice_coef: 0.4958 - val_precision: 0.3510 - val_recall: 0.9904 - val_accuracy: 0.4236 - val_tversky: 0.5961
# Epoch 26/100
# 360/360 [==============================] - 7s 19ms/step - loss: 0.2146 - iou: 0.7854 - dice_coef: 0.5798 - precision: 0.8836 - recall: 0.4328 - accuracy: 0.7975 - tversky: 0.6126 - val_loss: 0.1051 - val_iou: 0.8949 - val_dice_coef: 0.7012 - val_precision: 0.9174 - val_recall: 0.7814 - val_accuracy: 0.9093 - val_tversky: 0.7266
# Epoch 27/100
# 360/360 [==============================] - 7s 19ms/step - loss: 0.2099 - iou: 0.7901 - dice_coef: 0.5835 - precision: 0.9027 - recall: 0.4367 - accuracy: 0.8025 - tversky: 0.6160 - val_loss: 0.2241 - val_iou: 0.7759 - val_dice_coef: 0.5451 - val_precision: 0.5547 - val_recall: 0.7197 - val_accuracy: 0.7335 - val_tversky: 0.5812
# Epoch 28/100
# 360/360 [==============================] - 7s 19ms/step - loss: 0.2087 - iou: 0.7913 - dice_coef: 0.5872 - precision: 0.8979 - recall: 0.4451 - accuracy: 0.8037 - tversky: 0.6210 - val_loss: 0.2716 - val_iou: 0.7284 - val_dice_coef: 0.5472 - val_precision: 0.4667 - val_recall: 0.8290 - val_accuracy: 0.6503 - val_tversky: 0.6168
# Epoch 29/100
# 360/360 [==============================] - 7s 19ms/step - loss: 0.2114 - iou: 0.7886 - dice_coef: 0.5835 - precision: 0.8971 - recall: 0.4373 - accuracy: 0.8003 - tversky: 0.6164 - val_loss: 0.1638 - val_iou: 0.8362 - val_dice_coef: 0.5371 - val_precision: 0.9861 - val_recall: 0.4779 - val_accuracy: 0.8348 - val_tversky: 0.5071
# Epoch 30/100
# 360/360 [==============================] - 7s 19ms/step - loss: 0.2110 - iou: 0.7890 - dice_coef: 0.5828 - precision: 0.9009 - recall: 0.4368 - accuracy: 0.8012 - tversky: 0.6158 - val_loss: 0.1808 - val_iou: 0.8192 - val_dice_coef: 0.5192 - val_precision: 0.9390 - val_recall: 0.4354 - val_accuracy: 0.8138 - val_tversky: 0.4979
# Epoch 31/100
# 360/360 [==============================] - 7s 19ms/step - loss: 0.2084 - iou: 0.7916 - dice_coef: 0.5876 - precision: 0.9076 - recall: 0.4422 - accuracy: 0.8045 - tversky: 0.6210 - val_loss: 0.1679 - val_iou: 0.8321 - val_dice_coef: 0.5799 - val_precision: 0.8741 - val_recall: 0.5619 - val_accuracy: 0.8380 - val_tversky: 0.5885
# Epoch 32/100
# 360/360 [==============================] - 7s 19ms/step - loss: 0.2079 - iou: 0.7921 - dice_coef: 0.5873 - precision: 0.9175 - recall: 0.4373 - accuracy: 0.8050 - tversky: 0.6195 - val_loss: 0.1420 - val_iou: 0.8580 - val_dice_coef: 0.6810 - val_precision: 0.7374 - val_recall: 0.9325 - val_accuracy: 0.8745 - val_tversky: 0.7412
# Epoch 33/100
# 360/360 [==============================] - 7s 19ms/step - loss: 0.2068 - iou: 0.7932 - dice_coef: 0.5925 - precision: 0.9010 - recall: 0.4516 - accuracy: 0.8063 - tversky: 0.6268 - val_loss: 0.1185 - val_iou: 0.8815 - val_dice_coef: 0.7020 - val_precision: 0.8138 - val_recall: 0.8823 - val_accuracy: 0.9004 - val_tversky: 0.7507
# Epoch 34/100
# 360/360 [==============================] - 7s 19ms/step - loss: 0.2049 - iou: 0.7951 - dice_coef: 0.5955 - precision: 0.9254 - recall: 0.4434 - accuracy: 0.8082 - tversky: 0.6277 - val_loss: 0.2235 - val_iou: 0.7765 - val_dice_coef: 0.6061 - val_precision: 0.5534 - val_recall: 0.9277 - val_accuracy: 0.7433 - val_tversky: 0.6833
# Epoch 35/100
# 360/360 [==============================] - 7s 19ms/step - loss: 0.2073 - iou: 0.7927 - dice_coef: 0.5891 - precision: 0.9127 - recall: 0.4418 - accuracy: 0.8058 - tversky: 0.6216 - val_loss: 0.1252 - val_iou: 0.8748 - val_dice_coef: 0.6208 - val_precision: 0.9782 - val_recall: 0.6000 - val_accuracy: 0.8706 - val_tversky: 0.6120
# Epoch 36/100
# 360/360 [==============================] - 7s 19ms/step - loss: 0.2071 - iou: 0.7929 - dice_coef: 0.5918 - precision: 0.9051 - recall: 0.4473 - accuracy: 0.8058 - tversky: 0.6253 - val_loss: 0.1340 - val_iou: 0.8660 - val_dice_coef: 0.6600 - val_precision: 0.8253 - val_recall: 0.7701 - val_accuracy: 0.8766 - val_tversky: 0.6908
# Epoch 37/100
# 360/360 [==============================] - 7s 19ms/step - loss: 0.2048 - iou: 0.7952 - dice_coef: 0.5952 - precision: 0.9232 - recall: 0.4472 - accuracy: 0.8087 - tversky: 0.6283 - val_loss: 0.1054 - val_iou: 0.8946 - val_dice_coef: 0.6968 - val_precision: 0.8747 - val_recall: 0.8813 - val_accuracy: 0.9227 - val_tversky: 0.7368
# Epoch 38/100
# 360/360 [==============================] - 7s 19ms/step - loss: 0.2027 - iou: 0.7973 - dice_coef: 0.6011 - precision: 0.9284 - recall: 0.4521 - accuracy: 0.8116 - tversky: 0.6339 - val_loss: 0.1997 - val_iou: 0.8003 - val_dice_coef: 0.5887 - val_precision: 0.6402 - val_recall: 0.8047 - val_accuracy: 0.7965 - val_tversky: 0.6385
# Epoch 39/100
# 360/360 [==============================] - 7s 19ms/step - loss: 0.2074 - iou: 0.7926 - dice_coef: 0.5917 - precision: 0.9148 - recall: 0.4433 - accuracy: 0.8051 - tversky: 0.6248 - val_loss: 0.1035 - val_iou: 0.8965 - val_dice_coef: 0.7172 - val_precision: 0.8517 - val_recall: 0.8999 - val_accuracy: 0.9178 - val_tversky: 0.7648
# Epoch 40/100
# 360/360 [==============================] - 7s 19ms/step - loss: 0.2046 - iou: 0.7954 - dice_coef: 0.5970 - precision: 0.9171 - recall: 0.4495 - accuracy: 0.8087 - tversky: 0.6299 - val_loss: 0.3698 - val_iou: 0.6302 - val_dice_coef: 0.5264 - val_precision: 0.3730 - val_recall: 0.9816 - val_accuracy: 0.4781 - val_tversky: 0.6289
# Epoch 41/100
# 360/360 [==============================] - 7s 19ms/step - loss: 0.2040 - iou: 0.7960 - dice_coef: 0.5990 - precision: 0.9204 - recall: 0.4519 - accuracy: 0.8096 - tversky: 0.6323 - val_loss: 0.2455 - val_iou: 0.7545 - val_dice_coef: 0.5974 - val_precision: 0.5250 - val_recall: 0.9469 - val_accuracy: 0.7118 - val_tversky: 0.6832
# Epoch 42/100
# 360/360 [==============================] - 7s 19ms/step - loss: 0.2032 - iou: 0.7968 - dice_coef: 0.5970 - precision: 0.9272 - recall: 0.4507 - accuracy: 0.8105 - tversky: 0.6299 - val_loss: 0.0786 - val_iou: 0.9214 - val_dice_coef: 0.7239 - val_precision: 0.9202 - val_recall: 0.8893 - val_accuracy: 0.9396 - val_tversky: 0.7471
# Epoch 43/100
# 360/360 [==============================] - 7s 19ms/step - loss: 0.2020 - iou: 0.7980 - dice_coef: 0.6023 - precision: 0.9280 - recall: 0.4545 - accuracy: 0.8121 - tversky: 0.6354 - val_loss: 0.1125 - val_iou: 0.8875 - val_dice_coef: 0.6428 - val_precision: 0.9611 - val_recall: 0.7394 - val_accuracy: 0.9077 - val_tversky: 0.6557
# Epoch 44/100
# 360/360 [==============================] - 7s 19ms/step - loss: 0.2012 - iou: 0.7988 - dice_coef: 0.6039 - precision: 0.9236 - recall: 0.4595 - accuracy: 0.8129 - tversky: 0.6378 - val_loss: 0.1161 - val_iou: 0.8839 - val_dice_coef: 0.6608 - val_precision: 0.9076 - val_recall: 0.8469 - val_accuracy: 0.9231 - val_tversky: 0.6962
# Epoch 45/100
# 360/360 [==============================] - 7s 20ms/step - loss: 0.2031 - iou: 0.7969 - dice_coef: 0.5980 - precision: 0.9239 - recall: 0.4530 - accuracy: 0.8103 - tversky: 0.6314 - val_loss: 0.1310 - val_iou: 0.8690 - val_dice_coef: 0.6566 - val_precision: 0.8704 - val_recall: 0.8774 - val_accuracy: 0.9196 - val_tversky: 0.7035
# Epoch 46/100
# 360/360 [==============================] - 7s 19ms/step - loss: 0.2020 - iou: 0.7980 - dice_coef: 0.6029 - precision: 0.9197 - recall: 0.4585 - accuracy: 0.8117 - tversky: 0.6367 - val_loss: 0.0878 - val_iou: 0.9122 - val_dice_coef: 0.7118 - val_precision: 0.9327 - val_recall: 0.8138 - val_accuracy: 0.9219 - val_tversky: 0.7250
# Epoch 47/100
# 360/360 [==============================] - 7s 19ms/step - loss: 0.2018 - iou: 0.7982 - dice_coef: 0.6014 - precision: 0.9341 - recall: 0.4531 - accuracy: 0.8122 - tversky: 0.6344 - val_loss: 0.0986 - val_iou: 0.9014 - val_dice_coef: 0.7149 - val_precision: 0.8391 - val_recall: 0.8971 - val_accuracy: 0.9126 - val_tversky: 0.7471
# Epoch 48/100
# 360/360 [==============================] - 7s 19ms/step - loss: 0.2010 - iou: 0.7990 - dice_coef: 0.6050 - precision: 0.9284 - recall: 0.4583 - accuracy: 0.8132 - tversky: 0.6386 - val_loss: 0.1066 - val_iou: 0.8934 - val_dice_coef: 0.6806 - val_precision: 0.9597 - val_recall: 0.7031 - val_accuracy: 0.8971 - val_tversky: 0.6851
# Epoch 49/100
# 360/360 [==============================] - 7s 19ms/step - loss: 0.1992 - iou: 0.8008 - dice_coef: 0.6086 - precision: 0.9337 - recall: 0.4605 - accuracy: 0.8151 - tversky: 0.6419 - val_loss: 0.1221 - val_iou: 0.8779 - val_dice_coef: 0.6367 - val_precision: 0.9831 - val_recall: 0.6133 - val_accuracy: 0.8752 - val_tversky: 0.6309
# Epoch 50/100
# 360/360 [==============================] - 7s 19ms/step - loss: 0.1996 - iou: 0.8004 - dice_coef: 0.6066 - precision: 0.9336 - recall: 0.4593 - accuracy: 0.8146 - tversky: 0.6400 - val_loss: 0.0831 - val_iou: 0.9169 - val_dice_coef: 0.7224 - val_precision: 0.9423 - val_recall: 0.8110 - val_accuracy: 0.9240 - val_tversky: 0.7324
# Epoch 51/100
# 360/360 [==============================] - 7s 19ms/step - loss: 0.1994 - iou: 0.8006 - dice_coef: 0.6085 - precision: 0.9331 - recall: 0.4611 - accuracy: 0.8151 - tversky: 0.6420 - val_loss: 0.1058 - val_iou: 0.8942 - val_dice_coef: 0.6768 - val_precision: 0.9498 - val_recall: 0.7657 - val_accuracy: 0.9114 - val_tversky: 0.6960
# Epoch 52/100
# 360/360 [==============================] - 7s 19ms/step - loss: 0.1997 - iou: 0.8003 - dice_coef: 0.6071 - precision: 0.9374 - recall: 0.4577 - accuracy: 0.8145 - tversky: 0.6402 - val_loss: 0.1031 - val_iou: 0.8969 - val_dice_coef: 0.7178 - val_precision: 0.8397 - val_recall: 0.8741 - val_accuracy: 0.9072 - val_tversky: 0.7513
# Epoch 53/100
# 360/360 [==============================] - 7s 19ms/step - loss: 0.1999 - iou: 0.8001 - dice_coef: 0.6065 - precision: 0.9338 - recall: 0.4585 - accuracy: 0.8141 - tversky: 0.6399 - val_loss: 0.1153 - val_iou: 0.8847 - val_dice_coef: 0.6358 - val_precision: 0.9649 - val_recall: 0.6552 - val_accuracy: 0.8836 - val_tversky: 0.6296
# Epoch 54/100
# 360/360 [==============================] - 7s 19ms/step - loss: 0.1998 - iou: 0.8002 - dice_coef: 0.6070 - precision: 0.9261 - recall: 0.4636 - accuracy: 0.8144 - tversky: 0.6413 - val_loss: 0.0915 - val_iou: 0.9085 - val_dice_coef: 0.7437 - val_precision: 0.8289 - val_recall: 0.9290 - val_accuracy: 0.9156 - val_tversky: 0.7892
# Epoch 55/100
# 360/360 [==============================] - 7s 19ms/step - loss: 0.2038 - iou: 0.7962 - dice_coef: 0.6002 - precision: 0.9172 - recall: 0.4514 - accuracy: 0.8093 - tversky: 0.6331 - val_loss: 0.1031 - val_iou: 0.8969 - val_dice_coef: 0.6944 - val_precision: 0.9599 - val_recall: 0.6655 - val_accuracy: 0.8872 - val_tversky: 0.6806
# Epoch 56/100
# 360/360 [==============================] - 7s 19ms/step - loss: 0.2025 - iou: 0.7975 - dice_coef: 0.6022 - precision: 0.9273 - recall: 0.4515 - accuracy: 0.8112 - tversky: 0.6347 - val_loss: 0.0768 - val_iou: 0.9232 - val_dice_coef: 0.7621 - val_precision: 0.8873 - val_recall: 0.8731 - val_accuracy: 0.9261 - val_tversky: 0.7836
# Epoch 57/100
# 360/360 [==============================] - 7s 19ms/step - loss: 0.2007 - iou: 0.7993 - dice_coef: 0.6052 - precision: 0.9283 - recall: 0.4584 - accuracy: 0.8131 - tversky: 0.6387 - val_loss: 0.0803 - val_iou: 0.9197 - val_dice_coef: 0.7566 - val_precision: 0.8748 - val_recall: 0.9278 - val_accuracy: 0.9329 - val_tversky: 0.7911
# Epoch 58/100
# 360/360 [==============================] - 7s 19ms/step - loss: 0.2005 - iou: 0.7995 - dice_coef: 0.6062 - precision: 0.9294 - recall: 0.4596 - accuracy: 0.8137 - tversky: 0.6397 - val_loss: 0.0779 - val_iou: 0.9221 - val_dice_coef: 0.7783 - val_precision: 0.8236 - val_recall: 0.9486 - val_accuracy: 0.9195 - val_tversky: 0.8170
# Epoch 59/100
# 360/360 [==============================] - 7s 19ms/step - loss: 0.2017 - iou: 0.7983 - dice_coef: 0.6038 - precision: 0.9309 - recall: 0.4531 - accuracy: 0.8120 - tversky: 0.6362 - val_loss: 0.1065 - val_iou: 0.8935 - val_dice_coef: 0.7226 - val_precision: 0.8538 - val_recall: 0.8102 - val_accuracy: 0.8944 - val_tversky: 0.7456
# Epoch 60/100
# 360/360 [==============================] - 7s 19ms/step - loss: 0.2010 - iou: 0.7990 - dice_coef: 0.6045 - precision: 0.9229 - recall: 0.4601 - accuracy: 0.8130 - tversky: 0.6384 - val_loss: 0.1114 - val_iou: 0.8886 - val_dice_coef: 0.7424 - val_precision: 0.7613 - val_recall: 0.9346 - val_accuracy: 0.8861 - val_tversky: 0.7947
# Epoch 61/100
# 360/360 [==============================] - 7s 19ms/step - loss: 0.1997 - iou: 0.8003 - dice_coef: 0.6070 - precision: 0.9325 - recall: 0.4599 - accuracy: 0.8144 - tversky: 0.6407 - val_loss: 0.2948 - val_iou: 0.7052 - val_dice_coef: 0.5660 - val_precision: 0.4401 - val_recall: 0.9716 - val_accuracy: 0.6058 - val_tversky: 0.6587
# Epoch 62/100
# 360/360 [==============================] - 7s 19ms/step - loss: 0.2022 - iou: 0.7978 - dice_coef: 0.6033 - precision: 0.9325 - recall: 0.4524 - accuracy: 0.8120 - tversky: 0.6358 - val_loss: 0.2875 - val_iou: 0.7125 - val_dice_coef: 0.5913 - val_precision: 0.4619 - val_recall: 0.9418 - val_accuracy: 0.6401 - val_tversky: 0.6847
# Epoch 63/100
# 360/360 [==============================] - 7s 19ms/step - loss: 0.2013 - iou: 0.7987 - dice_coef: 0.6074 - precision: 0.9217 - recall: 0.4598 - accuracy: 0.8123 - tversky: 0.6411 - val_loss: 0.0736 - val_iou: 0.9264 - val_dice_coef: 0.7708 - val_precision: 0.9261 - val_recall: 0.8512 - val_accuracy: 0.9304 - val_tversky: 0.7869
# Epoch 64/100
# 360/360 [==============================] - 7s 19ms/step - loss: 0.1995 - iou: 0.8005 - dice_coef: 0.6082 - precision: 0.9319 - recall: 0.4613 - accuracy: 0.8146 - tversky: 0.6417 - val_loss: 0.1771 - val_iou: 0.8229 - val_dice_coef: 0.6790 - val_precision: 0.6243 - val_recall: 0.9565 - val_accuracy: 0.8038 - val_tversky: 0.7520
# Epoch 65/100
# 360/360 [==============================] - 7s 19ms/step - loss: 0.1985 - iou: 0.8015 - dice_coef: 0.6108 - precision: 0.9317 - recall: 0.4641 - accuracy: 0.8155 - tversky: 0.6445 - val_loss: 0.1650 - val_iou: 0.8350 - val_dice_coef: 0.6643 - val_precision: 0.6568 - val_recall: 0.9064 - val_accuracy: 0.8188 - val_tversky: 0.7204
# Epoch 66/100
# 360/360 [==============================] - 7s 19ms/step - loss: 0.1994 - iou: 0.8006 - dice_coef: 0.6065 - precision: 0.9360 - recall: 0.4586 - accuracy: 0.8145 - tversky: 0.6397 - val_loss: 0.0812 - val_iou: 0.9188 - val_dice_coef: 0.7662 - val_precision: 0.8850 - val_recall: 0.8844 - val_accuracy: 0.9255 - val_tversky: 0.7903
# Epoch 67/100
# 360/360 [==============================] - 7s 19ms/step - loss: 0.1997 - iou: 0.8003 - dice_coef: 0.6067 - precision: 0.9294 - recall: 0.4609 - accuracy: 0.8142 - tversky: 0.6405 - val_loss: 0.0760 - val_iou: 0.9240 - val_dice_coef: 0.7681 - val_precision: 0.8658 - val_recall: 0.9244 - val_accuracy: 0.9309 - val_tversky: 0.7966
# Epoch 68/100
# 360/360 [==============================] - 7s 19ms/step - loss: 0.1969 - iou: 0.8031 - dice_coef: 0.6147 - precision: 0.9393 - recall: 0.4665 - accuracy: 0.8177 - tversky: 0.6485 - val_loss: 0.1488 - val_iou: 0.8512 - val_dice_coef: 0.6925 - val_precision: 0.6918 - val_recall: 0.9517 - val_accuracy: 0.8505 - val_tversky: 0.7606
# Epoch 69/100
# 360/360 [==============================] - 7s 19ms/step - loss: 0.1992 - iou: 0.8008 - dice_coef: 0.6102 - precision: 0.9402 - recall: 0.4584 - accuracy: 0.8149 - tversky: 0.6429 - val_loss: 0.2218 - val_iou: 0.7782 - val_dice_coef: 0.6330 - val_precision: 0.5221 - val_recall: 0.9801 - val_accuracy: 0.7140 - val_tversky: 0.7203
# Epoch 70/100
# 360/360 [==============================] - 7s 19ms/step - loss: 0.1986 - iou: 0.8014 - dice_coef: 0.6125 - precision: 0.9324 - recall: 0.4636 - accuracy: 0.8157 - tversky: 0.6461 - val_loss: 0.1380 - val_iou: 0.8620 - val_dice_coef: 0.6115 - val_precision: 0.9830 - val_recall: 0.5503 - val_accuracy: 0.8546 - val_tversky: 0.5964
# Epoch 71/100
# 360/360 [==============================] - 7s 19ms/step - loss: 0.1972 - iou: 0.8028 - dice_coef: 0.6147 - precision: 0.9403 - recall: 0.4631 - accuracy: 0.8171 - tversky: 0.6475 - val_loss: 0.1589 - val_iou: 0.8411 - val_dice_coef: 0.5853 - val_precision: 0.9142 - val_recall: 0.5355 - val_accuracy: 0.8380 - val_tversky: 0.5720
# Epoch 72/100
# 360/360 [==============================] - 7s 19ms/step - loss: 0.1996 - iou: 0.8004 - dice_coef: 0.6083 - precision: 0.9281 - recall: 0.4630 - accuracy: 0.8147 - tversky: 0.6422 - val_loss: 0.1662 - val_iou: 0.8338 - val_dice_coef: 0.5432 - val_precision: 0.9736 - val_recall: 0.4689 - val_accuracy: 0.8278 - val_tversky: 0.5212
# Epoch 73/100
# 360/360 [==============================] - 7s 19ms/step - loss: 0.1979 - iou: 0.8021 - dice_coef: 0.6134 - precision: 0.9422 - recall: 0.4603 - accuracy: 0.8163 - tversky: 0.6459 - val_loss: 0.0996 - val_iou: 0.9004 - val_dice_coef: 0.6897 - val_precision: 0.9620 - val_recall: 0.7446 - val_accuracy: 0.9093 - val_tversky: 0.7006
# Epoch 74/100
# 360/360 [==============================] - 7s 19ms/step - loss: 0.1980 - iou: 0.8020 - dice_coef: 0.6117 - precision: 0.9312 - recall: 0.4658 - accuracy: 0.8164 - tversky: 0.6455 - val_loss: 0.0688 - val_iou: 0.9312 - val_dice_coef: 0.7850 - val_precision: 0.8912 - val_recall: 0.9303 - val_accuracy: 0.9414 - val_tversky: 0.8189
# Epoch 75/100
# 360/360 [==============================] - 7s 19ms/step - loss: 0.1962 - iou: 0.8038 - dice_coef: 0.6150 - precision: 0.9447 - recall: 0.4659 - accuracy: 0.8188 - tversky: 0.6482 - val_loss: 0.1371 - val_iou: 0.8629 - val_dice_coef: 0.6810 - val_precision: 0.7406 - val_recall: 0.8892 - val_accuracy: 0.8668 - val_tversky: 0.7319
# Epoch 76/100
# 360/360 [==============================] - 7s 19ms/step - loss: 0.1967 - iou: 0.8033 - dice_coef: 0.6133 - precision: 0.9412 - recall: 0.4671 - accuracy: 0.8180 - tversky: 0.6472 - val_loss: 0.0839 - val_iou: 0.9161 - val_dice_coef: 0.7422 - val_precision: 0.8677 - val_recall: 0.9174 - val_accuracy: 0.9289 - val_tversky: 0.7770
# Epoch 77/100
# 360/360 [==============================] - 7s 19ms/step - loss: 0.1970 - iou: 0.8030 - dice_coef: 0.6140 - precision: 0.9429 - recall: 0.4644 - accuracy: 0.8177 - tversky: 0.6474 - val_loss: 0.1655 - val_iou: 0.8345 - val_dice_coef: 0.5124 - val_precision: 0.9859 - val_recall: 0.4724 - val_accuracy: 0.8334 - val_tversky: 0.4878
# Epoch 78/100
# 360/360 [==============================] - 7s 19ms/step - loss: 0.1965 - iou: 0.8035 - dice_coef: 0.6183 - precision: 0.9420 - recall: 0.4661 - accuracy: 0.8182 - tversky: 0.6513 - val_loss: 0.2000 - val_iou: 0.8000 - val_dice_coef: 0.4674 - val_precision: 0.9714 - val_recall: 0.3391 - val_accuracy: 0.7913 - val_tversky: 0.4099
# Epoch 79/100
# 360/360 [==============================] - 7s 19ms/step - loss: 0.1965 - iou: 0.8035 - dice_coef: 0.6159 - precision: 0.9356 - recall: 0.4685 - accuracy: 0.8181 - tversky: 0.6498 - val_loss: 0.1157 - val_iou: 0.8843 - val_dice_coef: 0.6860 - val_precision: 0.8945 - val_recall: 0.7181 - val_accuracy: 0.8839 - val_tversky: 0.6814
# Epoch 80/100
# 360/360 [==============================] - 7s 19ms/step - loss: 0.1968 - iou: 0.8032 - dice_coef: 0.6142 - precision: 0.9428 - recall: 0.4650 - accuracy: 0.8177 - tversky: 0.6476 - val_loss: 0.1328 - val_iou: 0.8672 - val_dice_coef: 0.7028 - val_precision: 0.7307 - val_recall: 0.9191 - val_accuracy: 0.8650 - val_tversky: 0.7533
# Epoch 81/100
# 360/360 [==============================] - 7s 19ms/step - loss: 0.1972 - iou: 0.8028 - dice_coef: 0.6114 - precision: 0.9413 - recall: 0.4650 - accuracy: 0.8175 - tversky: 0.6451 - val_loss: 0.0636 - val_iou: 0.9364 - val_dice_coef: 0.7742 - val_precision: 0.9382 - val_recall: 0.8814 - val_accuracy: 0.9435 - val_tversky: 0.7918
# Epoch 82/100
# 360/360 [==============================] - 7s 19ms/step - loss: 0.1980 - iou: 0.8020 - dice_coef: 0.6101 - precision: 0.9330 - recall: 0.4664 - accuracy: 0.8166 - tversky: 0.6443 - val_loss: 0.1380 - val_iou: 0.8620 - val_dice_coef: 0.6773 - val_precision: 0.7912 - val_recall: 0.8741 - val_accuracy: 0.8871 - val_tversky: 0.7283
# Epoch 83/100
# 360/360 [==============================] - 7s 19ms/step - loss: 0.1992 - iou: 0.8008 - dice_coef: 0.6090 - precision: 0.9337 - recall: 0.4611 - accuracy: 0.8151 - tversky: 0.6424 - val_loss: 0.0959 - val_iou: 0.9041 - val_dice_coef: 0.7377 - val_precision: 0.8524 - val_recall: 0.8962 - val_accuracy: 0.9191 - val_tversky: 0.7808
# Epoch 84/100
# 360/360 [==============================] - 7s 19ms/step - loss: 0.1976 - iou: 0.8024 - dice_coef: 0.6127 - precision: 0.9411 - recall: 0.4638 - accuracy: 0.8171 - tversky: 0.6460 - val_loss: 0.0807 - val_iou: 0.9193 - val_dice_coef: 0.7472 - val_precision: 0.9013 - val_recall: 0.8633 - val_accuracy: 0.9270 - val_tversky: 0.7691
# Epoch 85/100
# 360/360 [==============================] - 7s 19ms/step - loss: 0.1973 - iou: 0.8027 - dice_coef: 0.6164 - precision: 0.9350 - recall: 0.4676 - accuracy: 0.8173 - tversky: 0.6502 - val_loss: 0.2248 - val_iou: 0.7752 - val_dice_coef: 0.6143 - val_precision: 0.5406 - val_recall: 0.9128 - val_accuracy: 0.7290 - val_tversky: 0.6955
# Epoch 86/100
# 360/360 [==============================] - 7s 19ms/step - loss: 0.1951 - iou: 0.8049 - dice_coef: 0.6200 - precision: 0.9503 - recall: 0.4673 - accuracy: 0.8198 - tversky: 0.6531 - val_loss: 0.0992 - val_iou: 0.9008 - val_dice_coef: 0.7460 - val_precision: 0.8372 - val_recall: 0.8984 - val_accuracy: 0.9125 - val_tversky: 0.7892
# Epoch 87/100
# 360/360 [==============================] - 7s 19ms/step - loss: 0.1962 - iou: 0.8038 - dice_coef: 0.6143 - precision: 0.9436 - recall: 0.4663 - accuracy: 0.8185 - tversky: 0.6480 - val_loss: 0.0646 - val_iou: 0.9354 - val_dice_coef: 0.7910 - val_precision: 0.9031 - val_recall: 0.9277 - val_accuracy: 0.9453 - val_tversky: 0.8200
# Epoch 88/100
# 360/360 [==============================] - 7s 19ms/step - loss: 0.1960 - iou: 0.8040 - dice_coef: 0.6159 - precision: 0.9411 - recall: 0.4676 - accuracy: 0.8187 - tversky: 0.6498 - val_loss: 0.1423 - val_iou: 0.8577 - val_dice_coef: 0.7067 - val_precision: 0.6839 - val_recall: 0.9759 - val_accuracy: 0.8508 - val_tversky: 0.7763
# Epoch 89/100
# 360/360 [==============================] - 7s 19ms/step - loss: 0.1964 - iou: 0.8036 - dice_coef: 0.6157 - precision: 0.9461 - recall: 0.4643 - accuracy: 0.8181 - tversky: 0.6487 - val_loss: 0.0627 - val_iou: 0.9373 - val_dice_coef: 0.7988 - val_precision: 0.9100 - val_recall: 0.9037 - val_accuracy: 0.9404 - val_tversky: 0.8192
# Epoch 90/100
# 360/360 [==============================] - 7s 19ms/step - loss: 0.1974 - iou: 0.8026 - dice_coef: 0.6132 - precision: 0.9369 - recall: 0.4652 - accuracy: 0.8170 - tversky: 0.6469 - val_loss: 0.1496 - val_iou: 0.8504 - val_dice_coef: 0.6716 - val_precision: 0.7072 - val_recall: 0.8821 - val_accuracy: 0.8483 - val_tversky: 0.7234
# Epoch 91/100
# 360/360 [==============================] - 7s 19ms/step - loss: 0.1963 - iou: 0.8037 - dice_coef: 0.6178 - precision: 0.9435 - recall: 0.4661 - accuracy: 0.8185 - tversky: 0.6509 - val_loss: 0.0886 - val_iou: 0.9114 - val_dice_coef: 0.7474 - val_precision: 0.8681 - val_recall: 0.8389 - val_accuracy: 0.9092 - val_tversky: 0.7650
# Epoch 92/100
# 360/360 [==============================] - 7s 19ms/step - loss: 0.1959 - iou: 0.8041 - dice_coef: 0.6163 - precision: 0.9473 - recall: 0.4669 - accuracy: 0.8190 - tversky: 0.6498 - val_loss: 0.0512 - val_iou: 0.9488 - val_dice_coef: 0.8298 - val_precision: 0.9116 - val_recall: 0.9347 - val_accuracy: 0.9505 - val_tversky: 0.8516
# Epoch 93/100
# 360/360 [==============================] - 7s 19ms/step - loss: 0.1962 - iou: 0.8038 - dice_coef: 0.6176 - precision: 0.9447 - recall: 0.4653 - accuracy: 0.8184 - tversky: 0.6507 - val_loss: 0.1032 - val_iou: 0.8968 - val_dice_coef: 0.6950 - val_precision: 0.9742 - val_recall: 0.6822 - val_accuracy: 0.8921 - val_tversky: 0.6702
# Epoch 94/100
# 360/360 [==============================] - 7s 19ms/step - loss: 0.1976 - iou: 0.8024 - dice_coef: 0.6139 - precision: 0.9340 - recall: 0.4663 - accuracy: 0.8167 - tversky: 0.6477 - val_loss: 0.2372 - val_iou: 0.7628 - val_dice_coef: 0.6431 - val_precision: 0.5133 - val_recall: 0.9689 - val_accuracy: 0.7033 - val_tversky: 0.7339
# Epoch 95/100
# 360/360 [==============================] - 7s 19ms/step - loss: 0.1955 - iou: 0.8045 - dice_coef: 0.6172 - precision: 0.9437 - recall: 0.4680 - accuracy: 0.8192 - tversky: 0.6507 - val_loss: 0.0910 - val_iou: 0.9090 - val_dice_coef: 0.7627 - val_precision: 0.7997 - val_recall: 0.9375 - val_accuracy: 0.9064 - val_tversky: 0.8054
# Epoch 96/100
# 360/360 [==============================] - 7s 19ms/step - loss: 0.1939 - iou: 0.8061 - dice_coef: 0.6221 - precision: 0.9501 - recall: 0.4716 - accuracy: 0.8211 - tversky: 0.6555 - val_loss: 0.0782 - val_iou: 0.9218 - val_dice_coef: 0.7491 - val_precision: 0.9616 - val_recall: 0.7808 - val_accuracy: 0.9196 - val_tversky: 0.7510
# Epoch 97/100
# 360/360 [==============================] - 7s 19ms/step - loss: 0.1942 - iou: 0.8058 - dice_coef: 0.6220 - precision: 0.9493 - recall: 0.4708 - accuracy: 0.8208 - tversky: 0.6554 - val_loss: 0.0803 - val_iou: 0.9197 - val_dice_coef: 0.7657 - val_precision: 0.8462 - val_recall: 0.9551 - val_accuracy: 0.9306 - val_tversky: 0.8092
# Epoch 98/100
# 360/360 [==============================] - 7s 19ms/step - loss: 0.1963 - iou: 0.8037 - dice_coef: 0.6148 - precision: 0.9370 - recall: 0.4695 - accuracy: 0.8184 - tversky: 0.6491 - val_loss: 0.0806 - val_iou: 0.9194 - val_dice_coef: 0.7287 - val_precision: 0.9594 - val_recall: 0.8065 - val_accuracy: 0.9268 - val_tversky: 0.7433
# Epoch 99/100
# 360/360 [==============================] - 7s 19ms/step - loss: 0.1949 - iou: 0.8051 - dice_coef: 0.6195 - precision: 0.9481 - recall: 0.4689 - accuracy: 0.8201 - tversky: 0.6529 - val_loss: 0.1489 - val_iou: 0.8511 - val_dice_coef: 0.5704 - val_precision: 0.9812 - val_recall: 0.5049 - val_accuracy: 0.8415 - val_tversky: 0.5496
# Epoch 100/100
# 360/360 [==============================] - 7s 19ms/step - loss: 0.1938 - iou: 0.8062 - dice_coef: 0.6205 - precision: 0.9501 - recall: 0.4715 - accuracy: 0.8212 - tversky: 0.6543 - val_loss: 0.1164 - val_iou: 0.8836 - val_dice_coef: 0.6581 - val_precision: 0.9345 - val_recall: 0.7204 - val_accuracy: 0.8951 - val_tversky: 0.6726

# %%
model_1 = Model(inputs=img_input, outputs=pred)
model_1.compile(optimizer= Adam(lr = 0.003), loss= [jaccard_distance], metrics=[iou, dice_coef, precision, recall, accuracy,tversky])

# %%
model_1.load_weights('fcn_100_epoch.h5')

# %% [markdown]
# Testing the statistics after 100 epochs

# %%
print('\n~~~~~~~~~~~~~~~Stats after 100 epoch~~~~~~~~~~~~~~~~~~~')
print('\n-------------On Train Set--------------------------\n')
res = model_1.evaluate(x_train, y_train, batch_size= 18)
print('________________________')
print('IOU:       |   {:.2f}  |'.format(res[1]*100))
print('Dice Coef: |   {:.2f}  |'.format(res[2]*100))
print('Precision: |   {:.2f}  |'.format(res[3]*100))
print('Recall:    |   {:.2f}  |'.format(res[4]*100))
print('Accuracy:  |   {:.2f}  |'.format(res[5]*100))
print('Tversky:   |   {:.2f}  |'.format(res[6]*100))
print("Loss:      |   {:.2f}  |".format(res[0]*100))
print('________________________')
print('\n-------------On Test  Set--------------------------\n')
res = model_1.evaluate(x_test, y_test, batch_size= 18)
print('________________________')
print('IOU:       |   {:.2f}  |'.format(res[1]*100))
print('Dice Coef: |   {:.2f}  |'.format(res[2]*100))
print('Precision: |   {:.2f}  |'.format(res[3]*100))
print('Recall:    |   {:.2f}  |'.format(res[4]*100))
print('Accuracy:  |   {:.2f}  |'.format(res[5]*100))
print('Tversky:   |   {:.2f}  |'.format(res[6]*100))
print("Loss:      |   {:.2f}  |".format(res[0]*100))
print('________________________')
print('\n-------------On validation Set---------------------\n')
res = model_1.evaluate(x_val, y_val, batch_size= 18)
print('________________________')
print('IOU:       |   {:.2f}  |'.format(res[1]*100))
print('Dice Coef: |   {:.2f}  |'.format(res[2]*100))
print('Precision: |   {:.2f}  |'.format(res[3]*100))
print('Recall:    |   {:.2f}  |'.format(res[4]*100))
print('Accuracy:  |   {:.2f}  |'.format(res[5]*100))
print('Tversky:   |   {:.2f}  |'.format(res[6]*100))
print("Loss:      |   {:.2f}  |".format(res[0]*100))
print('________________________')
# Out:
# ~~~~~~~~~~~~~~~Stats after 100 epoch~~~~~~~~~~~~~~~~~~~
#
# -------------On Train Set--------------------------
#
# 360/360 [==============================] - 3s 8ms/step
# ________________________
# IOU:       |   88.40  |
# Dice Coef: |   65.60  |
# Precision: |   94.15  |
# Recall:    |   70.03  |
# Accuracy:  |   88.81  |
# Tversky:   |   66.60  |
# Loss:      |   11.60  |
# ________________________
#
# -------------On Test  Set--------------------------
#
# 50/50 [==============================] - 0s 7ms/step
# ________________________
# IOU:       |   90.08  |
# Dice Coef: |   68.23  |
# Precision: |   96.79  |
# Recall:    |   75.29  |
# Accuracy:  |   91.85  |
# Tversky:   |   69.76  |
# Loss:      |   9.92  |
# ________________________
#
# -------------On validation Set---------------------
#
# 90/90 [==============================] - 1s 7ms/step
# ________________________
# IOU:       |   88.36  |
# Dice Coef: |   65.81  |
# Precision: |   93.45  |
# Recall:    |   72.04  |
# Accuracy:  |   89.51  |
# Tversky:   |   67.26  |
# Loss:      |   11.64  |
# ________________________

# %% [markdown]
# ### Plotting Training Statistics

# %%
plt.figure(figsize=(20, 14))
plt.suptitle('Training Statistics on Train Set')
plt.subplot(2,2,1)
plt.plot(hist.history['loss'], 'red')
plt.title('Loss')
plt.subplot(2,2,2)
plt.plot(hist.history['accuracy'], 'green')
plt.title('Accuracy')
plt.subplot(2,2,3)
plt.plot(hist.history['val_loss'], 'red')
plt.yticks(list(np.arange(0.0, 1.0, 0.10)))
plt.title('Valdiation Loss')
plt.subplot(2,2,4)
plt.plot(hist.history['val_accuracy'], 'green')
plt.yticks(list(np.arange(0.0, 1.0, 0.10)))
plt.title('Validation Accuracy')
plt.show()

# %% [markdown]
# From the above plot we can see that for the training set the the loss and the accuracy has gradually decreased and increased respetively.
# Although for the validation set the loss and the accuracy fluctuates but the loss and the accuracy are relatively low and high respectively throughout the training.
# Also the fluctuations relatively lowers towards the end of the training.

# %% [markdown]
# ## Visualising Predicted Lesions

# %% [markdown]
# We have trained the model on the **training set**.
# We will make predictions on the unseen **test set**

# %%
img_num = 49
img_pred = model_1.predict(x_test[img_num].reshape(1,192,256,3))
plt.figure(figsize=(16,16))
plt.subplot(1,3,1)
plt.imshow(x_test[img_num])
plt.title('Original Image')
plt.subplot(1,3,2)
plt.imshow(y_test[img_num], plt.cm.binary_r)
plt.title('Ground Truth')
plt.subplot(1,3,3)
plt.imshow(img_pred.reshape(192, 256), plt.cm.binary_r)
plt.title('Predicted Output')
plt.show()

# %%
img_num = 10
img_pred = model_1.predict(x_test[img_num].reshape(1,192,256,3))
plt.figure(figsize=(16,16))
plt.subplot(1,3,1)
plt.imshow(x_test[img_num])
plt.title('Original Image')
plt.subplot(1,3,2)
plt.imshow(y_test[img_num], plt.cm.binary_r)
plt.title('Ground Truth')
plt.subplot(1,3,3)
plt.imshow(img_pred.reshape(192, 256), plt.cm.binary_r)
plt.title('Predicted Output')
plt.show()

# %%
img_num = 36
img_pred = model_1.predict(x_test[img_num].reshape(1,192,256,3))
plt.figure(figsize=(16,16))
plt.subplot(1,3,1)
plt.imshow(x_test[img_num])
plt.title('Original Image')
plt.subplot(1,3,2)
plt.imshow(y_test[img_num], plt.cm.binary_r)
plt.title('Ground Truth')
plt.subplot(1,3,3)
plt.imshow(img_pred.reshape(192, 256), plt.cm.binary_r)
plt.title('Predicted Output')
plt.show()

# %%
img_num = 32
img_pred = model_1.predict(x_test[img_num].reshape(1,192,256,3))
plt.figure(figsize=(16,16))
plt.subplot(1,3,1)
plt.imshow(x_test[img_num])
plt.title('Original Image')
plt.subplot(1,3,2)
plt.imshow(y_test[img_num], plt.cm.binary_r)
plt.title('Ground Truth')
plt.subplot(1,3,3)
plt.imshow(img_pred.reshape(192, 256), plt.cm.binary_r)
plt.title('Predicted Output')
plt.show()

# %%
img_num = 29
img_pred = model_1.predict(x_test[img_num].reshape(1,192,256,3))
plt.figure(figsize=(16,16))
plt.subplot(1,3,1)
plt.imshow(x_test[img_num])
plt.title('Original Image')
plt.subplot(1,3,2)
plt.imshow(y_test[img_num], plt.cm.binary_r)
plt.title('Ground Truth')
plt.subplot(1,3,3)
plt.imshow(img_pred.reshape(192, 256), plt.cm.binary_r)
plt.title('Predicted Output')
plt.show()

# %%
img_num = 21
img_pred = model_1.predict(x_test[img_num].reshape(1,192,256,3))
plt.figure(figsize=(16,16))
plt.subplot(1,3,1)
plt.imshow(x_test[img_num])
plt.title('Original Image')
plt.subplot(1,3,2)
plt.imshow(y_test[img_num], plt.cm.binary_r)
plt.title('Ground Truth')
plt.subplot(1,3,3)
plt.imshow(img_pred.reshape(192, 256), plt.cm.binary_r)
plt.title('Predicted Output')
plt.show()

# %% [markdown]
# ## Final Enhance

# %% [markdown]
# * Currently the predicted outputs are blurry because the predicted pixel values are in the range 0 - 1.
# * To make clear edge preditions we can enhance our image by rounding up the pixel values to 1 which are > 0.5  .
# * While rounding down the pixel values to 0 which are < 0.5.
# * We can enhance the image to look for absolute shape predicted by ceiling and flooring the predicted values.

# %%
def enhance(img):
    sub = (model_1.predict(img.reshape(1,192,256,3))).flatten()

    for i in range(len(sub)):
        if sub[i] > 0.5:
            sub[i] = 1
        else:
            sub[i] = 0
    return sub

# %%
plt.figure(figsize=(12,12))
plt.suptitle('Comparing the Prediction after enhancement')
plt.subplot(3,2,1)
plt.imshow(y_test[21],plt.cm.binary_r)
plt.title('Ground Truth')
plt.subplot(3,2,2)
plt.imshow(enhance(x_test[21]).reshape(192,256), plt.cm.binary_r)
plt.title('Predicted')
plt.subplot(3,2,3)
plt.imshow(y_test[47],plt.cm.binary_r)
plt.title('Ground Truth')
plt.subplot(3,2,4)
plt.imshow(enhance(x_test[47]).reshape(192,256), plt.cm.binary_r)
plt.title('Predicted')
plt.subplot(3,2,5)
plt.imshow(y_test[36],plt.cm.binary_r)
plt.title('Ground Truth')
plt.subplot(3,2,6)
plt.imshow(enhance(x_test[36]).reshape(192,256), plt.cm.binary_r)
plt.title('Predicted')
plt.show()

# %% [markdown]
# * So we can observe that our results are very good on the Test dataset which suggests that the model is quite robust and well performing too.

# %% [markdown]
# ### **de nada!**
