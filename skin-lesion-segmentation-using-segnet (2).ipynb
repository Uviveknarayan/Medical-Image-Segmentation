# %% [markdown]
# ## Importing the Libraries

# %%
from tensorflow.keras.models import Model, Sequential
from tensorflow.keras.layers import Activation, Dense, BatchNormalization, Dropout, Conv2D, Conv2DTranspose, MaxPooling2D, UpSampling2D, Input, Reshape
from tensorflow.keras.callbacks import EarlyStopping
from tensorflow.keras.callbacks import ReduceLROnPlateau, EarlyStopping, ModelCheckpoint, LearningRateScheduler
from tensorflow.keras import backend as K
from tensorflow.keras.optimizers import Adam, SGD
import tensorflow as tf
import numpy as np
import pandas as pd
import glob
import PIL
from PIL import Image
import matplotlib.pyplot as plt
import cv2
# %matplotlib inline

from tensorflow.keras.preprocessing.image import ImageDataGenerator
from sklearn.model_selection import train_test_split
from warnings import filterwarnings

filterwarnings('ignore')
plt.rcParams["axes.grid"] = False
np.random.seed(101)

# %% [markdown]
# ## Loading the Data

# %% [markdown]
# Defining a function to load the data in sorted order

# %%
import re
numbers = re.compile(r'(\d+)')
def numericalSort(value):
    parts = numbers.split(value)
    parts[1::2] = map(int, parts[1::2])
    return parts

# %%
filelist_trainx = sorted(glob.glob('../input/*/trainx/*.bmp'), key=numericalSort)
X_train = np.array([np.array(Image.open(fname)) for fname in filelist_trainx])

filelist_trainy = sorted(glob.glob('../input/*/trainy/*.bmp'), key=numericalSort)
Y_train = np.array([np.array(Image.open(fname)) for fname in filelist_trainy])

# %% [markdown]
# Splitting the dataset into training set and test set to verify our model performance without any bias.

# %%
x_train, x_test, y_train, y_test = train_test_split(X_train, Y_train, test_size = 0.25, random_state = 101)

# %% [markdown]
# Let's plot an image to see how the original images look.

# %%
plt.figure(figsize=(20,9))
plt.subplot(2,4,1)
plt.imshow(X_train[0])
plt.subplot(2,4,2)
plt.imshow(X_train[3])
plt.subplot(2,4,3)
plt.imshow(X_train[54])
plt.subplot(2,4,4)
plt.imshow(X_train[77])
plt.subplot(2,4,5)
plt.imshow(X_train[100])
plt.subplot(2,4,6)
plt.imshow(X_train[125])
plt.subplot(2,4,7)
plt.imshow(X_train[130])
plt.subplot(2,4,8)
plt.imshow(X_train[149])
plt.show()

# %% [markdown]
# Now let's see their corresponding masks.

# %%
plt.figure(figsize=(20,9))
plt.subplot(2,4,1)
plt.imshow(Y_train[0], cmap = plt.cm.binary_r)
plt.subplot(2,4,2)
plt.imshow(Y_train[3], cmap = plt.cm.binary_r)
plt.subplot(2,4,3)
plt.imshow(Y_train[54], cmap = plt.cm.binary_r)
plt.subplot(2,4,4)
plt.imshow(Y_train[77], cmap = plt.cm.binary_r)
plt.subplot(2,4,5)
plt.imshow(Y_train[100], cmap = plt.cm.binary_r)
plt.subplot(2,4,6)
plt.imshow(Y_train[125], cmap = plt.cm.binary_r)
plt.subplot(2,4,7)
plt.imshow(Y_train[130], cmap = plt.cm.binary_r)
plt.subplot(2,4,8)
plt.imshow(Y_train[149], cmap = plt.cm.binary_r)
plt.show()

# %% [markdown]
# ## Defining Evaluation Metrics

# %% [markdown]
# #### Intersection over Union
# The Jaccard index, also known as Intersection over Union and the Jaccard similarity coefficient is a statistic used for gauging the similarity and diversity of sample sets. The Jaccard coefficient measures similarity between finite sample sets, and is defined as the size of the intersection divided by the size of the union of the sample sets:

# %% [markdown]
# ![iou](https://www.d2l.ai/_images/iou.svg)

# %%
def iou(y_true, y_pred, smooth = 100):
    intersection = K.sum(K.abs(y_true * y_pred), axis=-1)
    sum_ = K.sum(K.square(y_true), axis = -1) + K.sum(K.square(y_pred), axis=-1)
    jac = (intersection + smooth) / (sum_ - intersection + smooth)
    return jac

# %% [markdown]
# #### Dice coefficient
# The Dice score is not only a measure of how many positives you find, but it also penalizes for the false positives that the method finds, similar to precision. so it is more similar to precision than accuracy.

# %% [markdown]
# ![dc](https://cdn-images-1.medium.com/max/1600/1*Z1hkDvyhFBogT9EkzVkX2A.png)

# %%
def dice_coef(y_true, y_pred, smooth = 100):
    y_true_f = K.flatten(y_true)
    y_pred_f = K.flatten(y_pred)
    intersection = K.sum(y_true_f * y_pred_f)
    return (2. * intersection + smooth) / (K.sum(y_true_f) + K.sum(y_pred_f) + smooth)

# %% [markdown]
# #### Precision
# Precision is a good measure to determine, when the costs of False Positive is high.

# %% [markdown]
# ![precsion](https://wikimedia.org/api/rest_v1/media/math/render/svg/26106935459abe7c266f7b1ebfa2a824b334c807)

# %%
def precision(y_true, y_pred):
    '''Calculates the precision, a metric for multi-label classification of
    how many selected items are relevant.
    '''
    true_positives = K.sum(K.round(K.clip(y_true * y_pred, 0, 1)))
    predicted_positives = K.sum(K.round(K.clip(y_pred, 0, 1)))
    precision = true_positives / (predicted_positives + K.epsilon())
    return precision

# %% [markdown]
# #### Recall
# Recall actually calculates how many of the Actual Positives our model capture through labeling it as Positive (True Positive). Applying the same understanding, we know that Recall shall be the model metric we use to select our best model when there is a high cost associated with False Negative.

# %% [markdown]
# ![recall](https://wikimedia.org/api/rest_v1/media/math/render/svg/4c233366865312bc99c832d1475e152c5074891b)

# %%
def recall(y_true, y_pred):
    '''Calculates the recall, a metric for multi-label classification of
    how many relevant items are selected.
    '''
    true_positives = K.sum(K.round(K.clip(y_true * y_pred, 0, 1)))
    possible_positives = K.sum(K.round(K.clip(y_true, 0, 1)))
    recall = true_positives / (possible_positives + K.epsilon())
    return recall

# %% [markdown]
# #### Accuracy

# %%
def accuracy(y_true, y_pred):
    '''Calculates the mean accuracy rate across all predictions for binary
    classification problems.
    '''
    return K.mean(K.equal(y_true, K.round(y_pred)))

# %%
epsilon = 1e-5
smooth = 1

def tversky(y_true, y_pred):
    y_true_pos = K.flatten(y_true)
    y_pred_pos = K.flatten(y_pred)
    true_pos = K.sum(y_true_pos * y_pred_pos)
    false_neg = K.sum(y_true_pos * (1-y_pred_pos))
    false_pos = K.sum((1-y_true_pos)*y_pred_pos)
    alpha = 0.7
    return (true_pos + smooth)/(true_pos + alpha*false_neg + (1-alpha)*false_pos + smooth)

def focal_tversky(y_true,y_pred):
    y_true = tf.cast(y_true, tf.float32)
    y_pred = tf.cast(y_pred, tf.float32)
    
    pt_1 = tversky(y_true, y_pred)
    gamma = 0.75
    return K.pow((1-pt_1), gamma)

def tversky_loss(y_true, y_pred):
    return 1 - tversky(y_true,y_pred)

# %% [markdown]
# ## Image Augmentation
# To build a powerful image classifier using very little training data, image augmentation is usually required to boost the performance of deep networks. Image augmentation artificially creates training images through different ways of processing or combination of multiple processing, such as random rotation, shifts, shear and flips, etc.

# %% [markdown]
# We are going to define to methods for augmentation, one for **random rotation** and one for **horizontal flipping**

# %%
def random_rotation(x_image, y_image):
    rows_x,cols_x, chl_x = x_image.shape
    rows_y,cols_y = y_image.shape
    rand_num = np.random.randint(-40,40)
    M1 = cv2.getRotationMatrix2D((cols_x/2,rows_x/2),rand_num,1)
    M2 = cv2.getRotationMatrix2D((cols_y/2,rows_y/2),rand_num,1)
    x_image = cv2.warpAffine(x_image,M1,(cols_x,rows_x))
    y_image = cv2.warpAffine(y_image.astype('float32'),M2,(cols_y,rows_y))
    return x_image, y_image.astype('int')

def horizontal_flip(x_image, y_image):
    x_image = cv2.flip(x_image, 1)
    y_image = cv2.flip(y_image.astype('float32'), 1)
    return x_image, y_image.astype('int')

# %%
def img_augmentation(x_train, y_train):
    x_rotat = []
    y_rotat = []
    x_flip = []
    y_flip = []
    x_nois = []
    for idx in range(len(x_train)):
        x,y = random_rotation(x_train[idx], y_train[idx])
        x_rotat.append(x)
        y_rotat.append(y)
        
        x,y = horizontal_flip(x_train[idx], y_train[idx])
        x_flip.append(x)
        y_flip.append(y)
        return np.array(x_rotat), np.array(y_rotat), np.array(x_flip), np.array(y_flip)

# %%
def img_augmentation(x_test, y_test):
    x_rotat = []
    y_rotat = []
    x_flip = []
    y_flip = []
    x_nois = []
    for idx in range(len(x_test)):
        x,y = random_rotation(x_test[idx], y_test[idx])
        x_rotat.append(x)
        y_rotat.append(y)
        
        x,y = horizontal_flip(x_test[idx], y_test[idx])
        x_flip.append(x)
        y_flip.append(y)

    return np.array(x_rotat), np.array(y_rotat), np.array(x_flip), np.array(y_flip)

# %% [markdown]
# calling the functions for the training data.

# %%
x_rotated, y_rotated, x_flipped, y_flipped = img_augmentation(x_train, y_train)
x_rotated_t, y_rotated_t, x_flipped_t, y_flipped_t = img_augmentation(x_test, y_test)

# %% [markdown]
# Let us have a look at our transformations.

# %%
img_num = 114
plt.figure(figsize=(12,12))
plt.subplot(3,2,1)
plt.imshow(x_train[img_num])
plt.title('Original Image')
plt.subplot(3,2,2)
plt.imshow(y_train[img_num], plt.cm.binary_r)
plt.title('Original Mask')
plt.subplot(3,2,3)
plt.imshow(x_rotated[img_num])
plt.title('Rotated Image')
plt.subplot(3,2,4)
plt.imshow(y_rotated[img_num], plt.cm.binary_r)
plt.title('Rotated Mask')
plt.subplot(3,2,5)
plt.imshow(x_flipped[img_num])
plt.title('Flipped Image')
plt.subplot(3,2,6)
plt.imshow(y_flipped[img_num], plt.cm.binary_r)
plt.title('Flipped Mask')
plt.show()

# %% [markdown]
# Now we join all the augmentations image arrays to the original training arrays.

# %%
# For training Set
x_train_full = np.concatenate([x_train, x_rotated, x_flipped])
y_train_full = np.concatenate([y_train, y_rotated, y_flipped])

# %% [markdown]
# #### Making a Validation Set
# We will split our full training set into train and validation set.
# Validation dataset is used to validate the performance after each epoch.

# %%
x_train, x_val, y_train, y_val = train_test_split(x_train_full, y_train_full, test_size = 0.20, random_state = 101)

# %%
print("Length of the Training Set   : {}".format(len(x_train)))
print("Length of the Test Set       : {}".format(len(x_test)))
print("Length of the Validation Set : {}".format(len(x_val)))
# Out:
# Length of the Training Set   : 360
# Length of the Test Set       : 50
# Length of the Validation Set : 90

# %% [markdown]
# ## The Model

# %% [markdown]
# Defining the model in a function which takes two arguments when called
# * **epoch_num**: number of epochs to run
# * **savename**: the name of the model for saving after training

# %% [markdown]
# #### Optimizer and Learning Rate
# * We adopt SGD optimization algorithm, to adjust the learning rate.
# * It is well known that learning rate is one of the critical hyperparameters that have a signiﬁcant impact on classiﬁcation performance.
# * On large datasets, SGD can converge faster than batch training because it performs updates more frequently. We can get away with this because the data often contains redundant information, so the gradient can be reasonably approximated without using the full dataset. Minibatch training can be faster than training on single data points because it can take advantage of vectorized operations to process the entire minibatch at once. The stochastic nature of online/minibatch training can also make it possible to hop out of local minima that might otherwise trap batch training.
# * The learning rate is the conventional 0.001.

# %% [markdown]
# ### Model Function

# %% [markdown]
# ![arch](https://www.researchgate.net/profile/Adam_Czajka2/publication/326151825/figure/fig2/AS:647447659438083@1531374959468/Encoder-decoder-architecture-of-SegNet-Inference-takes-place-from-left-to-right-Size-of.png)

# %% [markdown]
# * The architecture we are implementing is suggested in [this](https://arxiv.org/pdf/1511.00561.pdf) paper.
# * The advised parameters can't exactly be applied to our problem.
# * We will switch the final activation function from **Softmax** to **Sigmoid** as using softmax was producing blank dark images.
# * The loss function in segnet is suggested **categorical crossentropy** due to it's genral use of muliclass segmentation problem but in our case we only have 1 class i.e. the melanoma. So, we will use **binary crossentropy**

# %%
earlystopping = EarlyStopping(monitor='val_loss',
                              mode='min', 
                              verbose=1, 
                              patience=30
                             )
# save the best model with lower validation loss
checkpointer = ModelCheckpoint(filepath="segnet_100_epoch.h5", 
                               verbose=1, 
                               save_best_only=True
                              )
reduce_lr = ReduceLROnPlateau(monitor='val_loss',
                              mode='min',
                              verbose=1,
                              patience=10,
                              min_delta=0.0001,
                              factor=0.2
                             )

# %%
def segnet(epochs_num,savename):

    # Encoding layer
    img_input = Input(shape= (192, 256, 3))
    x = Conv2D(64, (3, 3), padding='same', name='conv1',strides= (1,1))(img_input)
    x = BatchNormalization(name='bn1')(x)
    x = Activation('relu')(x)
    x = Conv2D(64, (3, 3), padding='same', name='conv2')(x)
    x = BatchNormalization(name='bn2')(x)
    x = Activation('relu')(x)
    x = MaxPooling2D()(x)
    
    x = Conv2D(128, (3, 3), padding='same', name='conv3')(x)
    x = BatchNormalization(name='bn3')(x)
    x = Activation('relu')(x)
    x = Conv2D(128, (3, 3), padding='same', name='conv4')(x)
    x = BatchNormalization(name='bn4')(x)
    x = Activation('relu')(x)
    x = MaxPooling2D()(x)

    x = Conv2D(256, (3, 3), padding='same', name='conv5')(x)
    x = BatchNormalization(name='bn5')(x)
    x = Activation('relu')(x)
    x = Conv2D(256, (3, 3), padding='same', name='conv6')(x)
    x = BatchNormalization(name='bn6')(x)
    x = Activation('relu')(x)
    x = Conv2D(256, (3, 3), padding='same', name='conv7')(x)
    x = BatchNormalization(name='bn7')(x)
    x = Activation('relu')(x)
    x = MaxPooling2D()(x)

    x = Conv2D(512, (3, 3), padding='same', name='conv8')(x)
    x = BatchNormalization(name='bn8')(x)
    x = Activation('relu')(x)
    x = Conv2D(512, (3, 3), padding='same', name='conv9')(x)
    x = BatchNormalization(name='bn9')(x)
    x = Activation('relu')(x)
    x = Conv2D(512, (3, 3), padding='same', name='conv10')(x)
    x = BatchNormalization(name='bn10')(x)
    x = Activation('relu')(x)
    x = MaxPooling2D()(x)
    
    x = Conv2D(512, (3, 3), padding='same', name='conv11')(x)
    x = BatchNormalization(name='bn11')(x)
    x = Activation('relu')(x)
    x = Conv2D(512, (3, 3), padding='same', name='conv12')(x)
    x = BatchNormalization(name='bn12')(x)
    x = Activation('relu')(x)
    x = Conv2D(512, (3, 3), padding='same', name='conv13')(x)
    x = BatchNormalization(name='bn13')(x)
    x = Activation('relu')(x)
    x = MaxPooling2D()(x)

    x = Dense(1024, activation = 'relu', name='fc1')(x)
    x = Dense(1024, activation = 'relu', name='fc2')(x)
    # Decoding Layer 
    x = UpSampling2D()(x)
    x = Conv2DTranspose(512, (3, 3), padding='same', name='deconv1')(x)
    x = BatchNormalization(name='bn14')(x)
    x = Activation('relu')(x)
    x = Conv2DTranspose(512, (3, 3), padding='same', name='deconv2')(x)
    x = BatchNormalization(name='bn15')(x)
    x = Activation('relu')(x)
    x = Conv2DTranspose(512, (3, 3), padding='same', name='deconv3')(x)
    x = BatchNormalization(name='bn16')(x)
    x = Activation('relu')(x)
    
    x = UpSampling2D()(x)
    x = Conv2DTranspose(512, (3, 3), padding='same', name='deconv4')(x)
    x = BatchNormalization(name='bn17')(x)
    x = Activation('relu')(x)
    x = Conv2DTranspose(512, (3, 3), padding='same', name='deconv5')(x)
    x = BatchNormalization(name='bn18')(x)
    x = Activation('relu')(x)
    x = Conv2DTranspose(256, (3, 3), padding='same', name='deconv6')(x)
    x = BatchNormalization(name='bn19')(x)
    x = Activation('relu')(x)

    x = UpSampling2D()(x)
    x = Conv2DTranspose(256, (3, 3), padding='same', name='deconv7')(x)
    x = BatchNormalization(name='bn20')(x)
    x = Activation('relu')(x)
    x = Conv2DTranspose(256, (3, 3), padding='same', name='deconv8')(x)
    x = BatchNormalization(name='bn21')(x)
    x = Activation('relu')(x)
    x = Conv2DTranspose(128, (3, 3), padding='same', name='deconv9')(x)
    x = BatchNormalization(name='bn22')(x)
    x = Activation('relu')(x)

    x = UpSampling2D()(x)
    x = Conv2DTranspose(128, (3, 3), padding='same', name='deconv10')(x)
    x = BatchNormalization(name='bn23')(x)
    x = Activation('relu')(x)
    x = Conv2DTranspose(64, (3, 3), padding='same', name='deconv11')(x)
    x = BatchNormalization(name='bn24')(x)
    x = Activation('relu')(x)
    
    x = UpSampling2D()(x)
    x = Conv2DTranspose(64, (3, 3), padding='same', name='deconv12')(x)
    x = BatchNormalization(name='bn25')(x)
    x = Activation('relu')(x)
    x = Conv2DTranspose(1, (3, 3), padding='same', name='deconv13')(x)
    x = BatchNormalization(name='bn26')(x)
    x = Activation('sigmoid')(x)
    pred = Reshape((192,256))(x)
    
    model = Model(inputs=img_input, outputs=pred)
    
    model.compile(optimizer= SGD(lr=0.001, momentum=0.9, decay=0.0005, nesterov=False), loss= ["binary_crossentropy"]
                  , metrics=[iou, dice_coef, precision, recall, accuracy,tversky])
    model.summary()
    hist = model.fit(x_train, y_train, epochs= epochs_num, batch_size= 18, validation_data= (x_val, y_val), verbose=1)
    
    model.save(savename)
    return model,hist

# %% [markdown]
# **After 1 epoch**

# %% [markdown]
# ## Loading the Model

# %% [markdown]
# Here we can load a pretrained model

# %%
# Encoding layer
img_input = Input(shape= (192, 256, 3))
x = Conv2D(64, (3, 3), padding='same', name='conv1',strides= (1,1))(img_input)
x = BatchNormalization(name='bn1')(x)
x = Activation('relu')(x)
x = Conv2D(64, (3, 3), padding='same', name='conv2')(x)
x = BatchNormalization(name='bn2')(x)
x = Activation('relu')(x)
x = MaxPooling2D()(x)

x = Conv2D(128, (3, 3), padding='same', name='conv3')(x)
x = BatchNormalization(name='bn3')(x)
x = Activation('relu')(x)
x = Conv2D(128, (3, 3), padding='same', name='conv4')(x)
x = BatchNormalization(name='bn4')(x)
x = Activation('relu')(x)
x = MaxPooling2D()(x)

x = Conv2D(256, (3, 3), padding='same', name='conv5')(x)
x = BatchNormalization(name='bn5')(x)
x = Activation('relu')(x)
x = Conv2D(256, (3, 3), padding='same', name='conv6')(x)
x = BatchNormalization(name='bn6')(x)
x = Activation('relu')(x)
x = Conv2D(256, (3, 3), padding='same', name='conv7')(x)
x = BatchNormalization(name='bn7')(x)
x = Activation('relu')(x)
x = MaxPooling2D()(x)

x = Conv2D(512, (3, 3), padding='same', name='conv8')(x)
x = BatchNormalization(name='bn8')(x)
x = Activation('relu')(x)
x = Conv2D(512, (3, 3), padding='same', name='conv9')(x)
x = BatchNormalization(name='bn9')(x)
x = Activation('relu')(x)
x = Conv2D(512, (3, 3), padding='same', name='conv10')(x)
x = BatchNormalization(name='bn10')(x)
x = Activation('relu')(x)
x = MaxPooling2D()(x)

x = Conv2D(512, (3, 3), padding='same', name='conv11')(x)
x = BatchNormalization(name='bn11')(x)
x = Activation('relu')(x)
x = Conv2D(512, (3, 3), padding='same', name='conv12')(x)
x = BatchNormalization(name='bn12')(x)
x = Activation('relu')(x)
x = Conv2D(512, (3, 3), padding='same', name='conv13')(x)
x = BatchNormalization(name='bn13')(x)
x = Activation('relu')(x)
x = MaxPooling2D()(x)

x = Dense(1024, activation = 'relu', name='fc1')(x)
x = Dense(1024, activation = 'relu', name='fc2')(x)
# Decoding Layer 
x = UpSampling2D()(x)
x = Conv2DTranspose(512, (3, 3), padding='same', name='deconv1')(x)
x = BatchNormalization(name='bn14')(x)
x = Activation('relu')(x)
x = Conv2DTranspose(512, (3, 3), padding='same', name='deconv2')(x)
x = BatchNormalization(name='bn15')(x)
x = Activation('relu')(x)
x = Conv2DTranspose(512, (3, 3), padding='same', name='deconv3')(x)
x = BatchNormalization(name='bn16')(x)
x = Activation('relu')(x)

x = UpSampling2D()(x)
x = Conv2DTranspose(512, (3, 3), padding='same', name='deconv4')(x)
x = BatchNormalization(name='bn17')(x)
x = Activation('relu')(x)
x = Conv2DTranspose(512, (3, 3), padding='same', name='deconv5')(x)
x = BatchNormalization(name='bn18')(x)
x = Activation('relu')(x)
x = Conv2DTranspose(256, (3, 3), padding='same', name='deconv6')(x)
x = BatchNormalization(name='bn19')(x)
x = Activation('relu')(x)

x = UpSampling2D()(x)
x = Conv2DTranspose(256, (3, 3), padding='same', name='deconv7')(x)
x = BatchNormalization(name='bn20')(x)
x = Activation('relu')(x)
x = Conv2DTranspose(256, (3, 3), padding='same', name='deconv8')(x)
x = BatchNormalization(name='bn21')(x)
x = Activation('relu')(x)
x = Conv2DTranspose(128, (3, 3), padding='same', name='deconv9')(x)
x = BatchNormalization(name='bn22')(x)
x = Activation('relu')(x)

x = UpSampling2D()(x)
x = Conv2DTranspose(128, (3, 3), padding='same', name='deconv10')(x)
x = BatchNormalization(name='bn23')(x)
x = Activation('relu')(x)
x = Conv2DTranspose(64, (3, 3), padding='same', name='deconv11')(x)
x = BatchNormalization(name='bn24')(x)
x = Activation('relu')(x)

x = UpSampling2D()(x)
x = Conv2DTranspose(64, (3, 3), padding='same', name='deconv12')(x)
x = BatchNormalization(name='bn25')(x)
x = Activation('relu')(x)
x = Conv2DTranspose(1, (3, 3), padding='same', name='deconv13')(x)
x = BatchNormalization(name='bn26')(x)
x = Activation('sigmoid')(x)
pred = Reshape((192,256))(x)

# %%
model_0 = Model(inputs=img_input, outputs=pred)

model_0.compile(optimizer= SGD(lr=0.001, momentum=0.9, decay=0.0005, nesterov=False), loss= ["binary_crossentropy"]
              , metrics=[iou, dice_coef, precision, recall, accuracy,tversky])

# %%
with tf.Session() as sess:
     sess.run(tf.global_variables_initializer())

# %% [markdown]
# #### After 100 epochs

# %%
model, hist = segnet(epochs_num= 100, savename= 'segnet_100_epoch.h5')
# Out:
# Model: "model_1"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# input_2 (InputLayer)         [(None, 192, 256, 3)]     0
# _________________________________________________________________
# conv1 (Conv2D)               (None, 192, 256, 64)      1792
# _________________________________________________________________
# bn1 (BatchNormalization)     (None, 192, 256, 64)      256
# _________________________________________________________________
# activation_26 (Activation)   (None, 192, 256, 64)      0
# _________________________________________________________________
# conv2 (Conv2D)               (None, 192, 256, 64)      36928
# _________________________________________________________________
# bn2 (BatchNormalization)     (None, 192, 256, 64)      256
# _________________________________________________________________
# activation_27 (Activation)   (None, 192, 256, 64)      0
# _________________________________________________________________
# max_pooling2d_5 (MaxPooling2 (None, 96, 128, 64)       0
# _________________________________________________________________
# conv3 (Conv2D)               (None, 96, 128, 128)      73856
# _________________________________________________________________
# bn3 (BatchNormalization)     (None, 96, 128, 128)      512
# _________________________________________________________________
# activation_28 (Activation)   (None, 96, 128, 128)      0
# _________________________________________________________________
# conv4 (Conv2D)               (None, 96, 128, 128)      147584
# _________________________________________________________________
# bn4 (BatchNormalization)     (None, 96, 128, 128)      512
# _________________________________________________________________
# activation_29 (Activation)   (None, 96, 128, 128)      0
# _________________________________________________________________
# max_pooling2d_6 (MaxPooling2 (None, 48, 64, 128)       0
# _________________________________________________________________
# conv5 (Conv2D)               (None, 48, 64, 256)       295168
# _________________________________________________________________
# bn5 (BatchNormalization)     (None, 48, 64, 256)       1024
# _________________________________________________________________
# activation_30 (Activation)   (None, 48, 64, 256)       0
# _________________________________________________________________
# conv6 (Conv2D)               (None, 48, 64, 256)       590080
# _________________________________________________________________
# bn6 (BatchNormalization)     (None, 48, 64, 256)       1024
# _________________________________________________________________
# activation_31 (Activation)   (None, 48, 64, 256)       0
# _________________________________________________________________
# conv7 (Conv2D)               (None, 48, 64, 256)       590080
# _________________________________________________________________
# bn7 (BatchNormalization)     (None, 48, 64, 256)       1024
# _________________________________________________________________
# activation_32 (Activation)   (None, 48, 64, 256)       0
# _________________________________________________________________
# max_pooling2d_7 (MaxPooling2 (None, 24, 32, 256)       0
# _________________________________________________________________
# conv8 (Conv2D)               (None, 24, 32, 512)       1180160
# _________________________________________________________________
# bn8 (BatchNormalization)     (None, 24, 32, 512)       2048
# _________________________________________________________________
# activation_33 (Activation)   (None, 24, 32, 512)       0
# _________________________________________________________________
# conv9 (Conv2D)               (None, 24, 32, 512)       2359808
# _________________________________________________________________
# bn9 (BatchNormalization)     (None, 24, 32, 512)       2048
# _________________________________________________________________
# activation_34 (Activation)   (None, 24, 32, 512)       0
# _________________________________________________________________
# conv10 (Conv2D)              (None, 24, 32, 512)       2359808
# _________________________________________________________________
# bn10 (BatchNormalization)    (None, 24, 32, 512)       2048
# _________________________________________________________________
# activation_35 (Activation)   (None, 24, 32, 512)       0
# _________________________________________________________________
# max_pooling2d_8 (MaxPooling2 (None, 12, 16, 512)       0
# _________________________________________________________________
# conv11 (Conv2D)              (None, 12, 16, 512)       2359808
# _________________________________________________________________
# bn11 (BatchNormalization)    (None, 12, 16, 512)       2048
# _________________________________________________________________
# activation_36 (Activation)   (None, 12, 16, 512)       0
# _________________________________________________________________
# conv12 (Conv2D)              (None, 12, 16, 512)       2359808
# _________________________________________________________________
# bn12 (BatchNormalization)    (None, 12, 16, 512)       2048
# _________________________________________________________________
# activation_37 (Activation)   (None, 12, 16, 512)       0
# _________________________________________________________________
# conv13 (Conv2D)              (None, 12, 16, 512)       2359808
# _________________________________________________________________
# bn13 (BatchNormalization)    (None, 12, 16, 512)       2048
# _________________________________________________________________
# activation_38 (Activation)   (None, 12, 16, 512)       0
# _________________________________________________________________
# max_pooling2d_9 (MaxPooling2 (None, 6, 8, 512)         0
# _________________________________________________________________
# fc1 (Dense)                  (None, 6, 8, 1024)        525312
# _________________________________________________________________
# fc2 (Dense)                  (None, 6, 8, 1024)        1049600
# _________________________________________________________________
# up_sampling2d_5 (UpSampling2 (None, 12, 16, 1024)      0
# _________________________________________________________________
# deconv1 (Conv2DTranspose)    (None, 12, 16, 512)       4719104
# _________________________________________________________________
# bn14 (BatchNormalization)    (None, 12, 16, 512)       2048
# _________________________________________________________________
# activation_39 (Activation)   (None, 12, 16, 512)       0
# _________________________________________________________________
# deconv2 (Conv2DTranspose)    (None, 12, 16, 512)       2359808
# _________________________________________________________________
# bn15 (BatchNormalization)    (None, 12, 16, 512)       2048
# _________________________________________________________________
# activation_40 (Activation)   (None, 12, 16, 512)       0
# _________________________________________________________________
# deconv3 (Conv2DTranspose)    (None, 12, 16, 512)       2359808
# _________________________________________________________________
# bn16 (BatchNormalization)    (None, 12, 16, 512)       2048
# _________________________________________________________________
# activation_41 (Activation)   (None, 12, 16, 512)       0
# _________________________________________________________________
# up_sampling2d_6 (UpSampling2 (None, 24, 32, 512)       0
# _________________________________________________________________
# deconv4 (Conv2DTranspose)    (None, 24, 32, 512)       2359808
# _________________________________________________________________
# bn17 (BatchNormalization)    (None, 24, 32, 512)       2048
# _________________________________________________________________
# activation_42 (Activation)   (None, 24, 32, 512)       0
# _________________________________________________________________
# deconv5 (Conv2DTranspose)    (None, 24, 32, 512)       2359808
# _________________________________________________________________
# bn18 (BatchNormalization)    (None, 24, 32, 512)       2048
# _________________________________________________________________
# activation_43 (Activation)   (None, 24, 32, 512)       0
# _________________________________________________________________
# deconv6 (Conv2DTranspose)    (None, 24, 32, 256)       1179904
# _________________________________________________________________
# bn19 (BatchNormalization)    (None, 24, 32, 256)       1024
# _________________________________________________________________
# activation_44 (Activation)   (None, 24, 32, 256)       0
# _________________________________________________________________
# up_sampling2d_7 (UpSampling2 (None, 48, 64, 256)       0
# _________________________________________________________________
# deconv7 (Conv2DTranspose)    (None, 48, 64, 256)       590080
# _________________________________________________________________
# bn20 (BatchNormalization)    (None, 48, 64, 256)       1024
# _________________________________________________________________
# activation_45 (Activation)   (None, 48, 64, 256)       0
# _________________________________________________________________
# deconv8 (Conv2DTranspose)    (None, 48, 64, 256)       590080
# _________________________________________________________________
# bn21 (BatchNormalization)    (None, 48, 64, 256)       1024
# _________________________________________________________________
# activation_46 (Activation)   (None, 48, 64, 256)       0
# _________________________________________________________________
# deconv9 (Conv2DTranspose)    (None, 48, 64, 128)       295040
# _________________________________________________________________
# bn22 (BatchNormalization)    (None, 48, 64, 128)       512
# _________________________________________________________________
# activation_47 (Activation)   (None, 48, 64, 128)       0
# _________________________________________________________________
# up_sampling2d_8 (UpSampling2 (None, 96, 128, 128)      0
# _________________________________________________________________
# deconv10 (Conv2DTranspose)   (None, 96, 128, 128)      147584
# _________________________________________________________________
# bn23 (BatchNormalization)    (None, 96, 128, 128)      512
# _________________________________________________________________
# activation_48 (Activation)   (None, 96, 128, 128)      0
# _________________________________________________________________
# deconv11 (Conv2DTranspose)   (None, 96, 128, 64)       73792
# _________________________________________________________________
# bn24 (BatchNormalization)    (None, 96, 128, 64)       256
# _________________________________________________________________
# activation_49 (Activation)   (None, 96, 128, 64)       0
# _________________________________________________________________
# up_sampling2d_9 (UpSampling2 (None, 192, 256, 64)      0
# _________________________________________________________________
# deconv12 (Conv2DTranspose)   (None, 192, 256, 64)      36928
# _________________________________________________________________
# bn25 (BatchNormalization)    (None, 192, 256, 64)      256
# _________________________________________________________________
# activation_50 (Activation)   (None, 192, 256, 64)      0
# _________________________________________________________________
# deconv13 (Conv2DTranspose)   (None, 192, 256, 1)       577
# _________________________________________________________________
# bn26 (BatchNormalization)    (None, 192, 256, 1)       4
# _________________________________________________________________
# activation_51 (Activation)   (None, 192, 256, 1)       0
# _________________________________________________________________
# reshape_1 (Reshape)          (None, 192, 256)          0
# =================================================================
# Total params: 33,393,669
# Trainable params: 33,377,795
# Non-trainable params: 15,874
# _________________________________________________________________
# Train on 360 samples, validate on 90 samples
# Epoch 1/100
# 360/360 [==============================] - 15s 42ms/sample - loss: 0.7215 - iou: 0.6916 - dice_coef: 0.4188 - precision: 0.4188 - recall: 0.5250 - accuracy: 0.6116 - tversky: 0.4552 - val_loss: 0.6707 - val_iou: 0.6849 - val_dice_coef: 0.3738 - val_precision: 0.0000e+00 - val_recall: 0.0000e+00 - val_accuracy: 0.6872 - val_tversky: 0.4057
# Epoch 2/100
# 360/360 [==============================] - 8s 21ms/sample - loss: 0.5301 - iou: 0.7674 - dice_coef: 0.5207 - precision: 0.6352 - recall: 0.7847 - accuracy: 0.7822 - tversky: 0.5659 - val_loss: 0.6473 - val_iou: 0.6953 - val_dice_coef: 0.3491 - val_precision: 0.0000e+00 - val_recall: 0.0000e+00 - val_accuracy: 0.6872 - val_tversky: 0.3708
# Epoch 3/100
# 360/360 [==============================] - 8s 22ms/sample - loss: 0.4551 - iou: 0.8024 - dice_coef: 0.5618 - precision: 0.7760 - recall: 0.8326 - accuracy: 0.8670 - tversky: 0.6078 - val_loss: 0.6336 - val_iou: 0.7028 - val_dice_coef: 0.3374 - val_precision: 0.0000e+00 - val_recall: 0.0000e+00 - val_accuracy: 0.6872 - val_tversky: 0.3501
# Epoch 4/100
# 360/360 [==============================] - 8s 22ms/sample - loss: 0.4279 - iou: 0.8174 - dice_coef: 0.5791 - precision: 0.7991 - recall: 0.8633 - accuracy: 0.8842 - tversky: 0.6255 - val_loss: 0.6272 - val_iou: 0.7079 - val_dice_coef: 0.3174 - val_precision: 0.0000e+00 - val_recall: 0.0000e+00 - val_accuracy: 0.6872 - val_tversky: 0.3235
# Epoch 5/100
# 360/360 [==============================] - 8s 22ms/sample - loss: 0.4054 - iou: 0.8295 - dice_coef: 0.5937 - precision: 0.8305 - recall: 0.8753 - accuracy: 0.9009 - tversky: 0.6391 - val_loss: 0.6247 - val_iou: 0.7114 - val_dice_coef: 0.3111 - val_precision: 0.0000e+00 - val_recall: 0.0000e+00 - val_accuracy: 0.6872 - val_tversky: 0.3115
# Epoch 6/100
# 360/360 [==============================] - 8s 21ms/sample - loss: 0.3939 - iou: 0.8364 - dice_coef: 0.6005 - precision: 0.8336 - recall: 0.8828 - accuracy: 0.9042 - tversky: 0.6453 - val_loss: 0.6244 - val_iou: 0.7138 - val_dice_coef: 0.3017 - val_precision: 0.0000e+00 - val_recall: 0.0000e+00 - val_accuracy: 0.6872 - val_tversky: 0.2980
# Epoch 7/100
# 360/360 [==============================] - 8s 22ms/sample - loss: 0.3806 - iou: 0.8435 - dice_coef: 0.6089 - precision: 0.8530 - recall: 0.8827 - accuracy: 0.9110 - tversky: 0.6525 - val_loss: 0.6260 - val_iou: 0.7151 - val_dice_coef: 0.2872 - val_precision: 0.0000e+00 - val_recall: 0.0000e+00 - val_accuracy: 0.6872 - val_tversky: 0.2817
# Epoch 8/100
# 360/360 [==============================] - 8s 22ms/sample - loss: 0.3614 - iou: 0.8542 - dice_coef: 0.6240 - precision: 0.8658 - recall: 0.8987 - accuracy: 0.9216 - tversky: 0.6667 - val_loss: 0.6289 - val_iou: 0.7158 - val_dice_coef: 0.2849 - val_precision: 0.0000e+00 - val_recall: 0.0000e+00 - val_accuracy: 0.6872 - val_tversky: 0.2755
# Epoch 9/100
# 360/360 [==============================] - 8s 22ms/sample - loss: 0.3556 - iou: 0.8576 - dice_coef: 0.6270 - precision: 0.8649 - recall: 0.8999 - accuracy: 0.9207 - tversky: 0.6692 - val_loss: 0.6321 - val_iou: 0.7163 - val_dice_coef: 0.2768 - val_precision: 0.0000e+00 - val_recall: 0.0000e+00 - val_accuracy: 0.6872 - val_tversky: 0.2653
# Epoch 10/100
# 360/360 [==============================] - 8s 22ms/sample - loss: 0.3516 - iou: 0.8603 - dice_coef: 0.6290 - precision: 0.8623 - recall: 0.8966 - accuracy: 0.9177 - tversky: 0.6706 - val_loss: 0.6350 - val_iou: 0.7167 - val_dice_coef: 0.2713 - val_precision: 0.0000e+00 - val_recall: 0.0000e+00 - val_accuracy: 0.6872 - val_tversky: 0.2575
# Epoch 11/100
# 360/360 [==============================] - 8s 22ms/sample - loss: 0.3304 - iou: 0.8714 - dice_coef: 0.6455 - precision: 0.8891 - recall: 0.9094 - accuracy: 0.9334 - tversky: 0.6856 - val_loss: 0.6298 - val_iou: 0.7202 - val_dice_coef: 0.2728 - val_precision: 0.2000 - val_recall: 2.0465e-05 - val_accuracy: 0.6872 - val_tversky: 0.2575
# Epoch 12/100
# 360/360 [==============================] - 8s 22ms/sample - loss: 0.3228 - iou: 0.8755 - dice_coef: 0.6513 - precision: 0.8891 - recall: 0.9118 - accuracy: 0.9335 - tversky: 0.6908 - val_loss: 0.6019 - val_iou: 0.7340 - val_dice_coef: 0.2975 - val_precision: 1.0000 - val_recall: 0.0254 - val_accuracy: 0.6950 - val_tversky: 0.2815
# Epoch 13/100
# 360/360 [==============================] - 8s 22ms/sample - loss: 0.3171 - iou: 0.8787 - dice_coef: 0.6557 - precision: 0.8855 - recall: 0.9140 - accuracy: 0.9329 - tversky: 0.6948 - val_loss: 0.5677 - val_iou: 0.7509 - val_dice_coef: 0.3338 - val_precision: 0.9998 - val_recall: 0.0976 - val_accuracy: 0.7175 - val_tversky: 0.3168
# Epoch 14/100
# 360/360 [==============================] - 8s 21ms/sample - loss: 0.3084 - iou: 0.8839 - dice_coef: 0.6630 - precision: 0.8918 - recall: 0.9171 - accuracy: 0.9362 - tversky: 0.7012 - val_loss: 0.4520 - val_iou: 0.8101 - val_dice_coef: 0.4654 - val_precision: 0.9942 - val_recall: 0.4086 - val_accuracy: 0.8161 - val_tversky: 0.4572
# Epoch 15/100
# 360/360 [==============================] - 8s 22ms/sample - loss: 0.2998 - iou: 0.8879 - dice_coef: 0.6692 - precision: 0.8982 - recall: 0.9193 - accuracy: 0.9391 - tversky: 0.7067 - val_loss: 0.3832 - val_iou: 0.8464 - val_dice_coef: 0.5456 - val_precision: 0.9815 - val_recall: 0.5867 - val_accuracy: 0.8688 - val_tversky: 0.5474
# Epoch 16/100
# 360/360 [==============================] - 8s 21ms/sample - loss: 0.2935 - iou: 0.8914 - dice_coef: 0.6752 - precision: 0.9063 - recall: 0.9164 - accuracy: 0.9409 - tversky: 0.7114 - val_loss: 0.3436 - val_iou: 0.8667 - val_dice_coef: 0.5913 - val_precision: 0.9806 - val_recall: 0.6803 - val_accuracy: 0.8960 - val_tversky: 0.5992
# Epoch 17/100
# 360/360 [==============================] - 8s 22ms/sample - loss: 0.2875 - iou: 0.8946 - dice_coef: 0.6798 - precision: 0.9037 - recall: 0.9226 - accuracy: 0.9423 - tversky: 0.7157 - val_loss: 0.3195 - val_iou: 0.8787 - val_dice_coef: 0.6097 - val_precision: 0.9760 - val_recall: 0.7343 - val_accuracy: 0.9122 - val_tversky: 0.6227
# Epoch 18/100
# 360/360 [==============================] - 8s 22ms/sample - loss: 0.2838 - iou: 0.8970 - dice_coef: 0.6839 - precision: 0.9080 - recall: 0.9221 - accuracy: 0.9419 - tversky: 0.7197 - val_loss: 0.3293 - val_iou: 0.8745 - val_dice_coef: 0.6097 - val_precision: 0.9647 - val_recall: 0.7134 - val_accuracy: 0.9024 - val_tversky: 0.6203
# Epoch 19/100
# 360/360 [==============================] - 8s 21ms/sample - loss: 0.2731 - iou: 0.9019 - dice_coef: 0.6909 - precision: 0.9171 - recall: 0.9232 - accuracy: 0.9474 - tversky: 0.7253 - val_loss: 0.3060 - val_iou: 0.8858 - val_dice_coef: 0.6229 - val_precision: 0.9712 - val_recall: 0.7449 - val_accuracy: 0.9159 - val_tversky: 0.6367
# Epoch 20/100
# 360/360 [==============================] - 8s 22ms/sample - loss: 0.2739 - iou: 0.9013 - dice_coef: 0.6927 - precision: 0.9004 - recall: 0.9274 - accuracy: 0.9423 - tversky: 0.7272 - val_loss: 0.2898 - val_iou: 0.8938 - val_dice_coef: 0.6618 - val_precision: 0.9207 - val_recall: 0.8437 - val_accuracy: 0.9281 - val_tversky: 0.6857
# Epoch 21/100
# 360/360 [==============================] - 8s 22ms/sample - loss: 0.2604 - iou: 0.9086 - dice_coef: 0.7029 - precision: 0.9186 - recall: 0.9319 - accuracy: 0.9507 - tversky: 0.7362 - val_loss: 0.2859 - val_iou: 0.8955 - val_dice_coef: 0.6590 - val_precision: 0.9440 - val_recall: 0.8066 - val_accuracy: 0.9255 - val_tversky: 0.6781
# Epoch 22/100
# 360/360 [==============================] - 8s 22ms/sample - loss: 0.2581 - iou: 0.9094 - dice_coef: 0.7047 - precision: 0.9141 - recall: 0.9323 - accuracy: 0.9493 - tversky: 0.7377 - val_loss: 0.2757 - val_iou: 0.9004 - val_dice_coef: 0.6739 - val_precision: 0.8954 - val_recall: 0.8735 - val_accuracy: 0.9316 - val_tversky: 0.7044
# Epoch 23/100
# 360/360 [==============================] - 8s 22ms/sample - loss: 0.2561 - iou: 0.9103 - dice_coef: 0.7074 - precision: 0.9148 - recall: 0.9275 - accuracy: 0.9480 - tversky: 0.7396 - val_loss: 0.2714 - val_iou: 0.9034 - val_dice_coef: 0.6831 - val_precision: 0.9262 - val_recall: 0.8442 - val_accuracy: 0.9305 - val_tversky: 0.7071
# Epoch 24/100
# 360/360 [==============================] - 8s 22ms/sample - loss: 0.2478 - iou: 0.9146 - dice_coef: 0.7140 - precision: 0.9229 - recall: 0.9309 - accuracy: 0.9522 - tversky: 0.7454 - val_loss: 0.2608 - val_iou: 0.9089 - val_dice_coef: 0.6964 - val_precision: 0.9208 - val_recall: 0.8717 - val_accuracy: 0.9360 - val_tversky: 0.7226
# Epoch 25/100
# 360/360 [==============================] - 8s 22ms/sample - loss: 0.2455 - iou: 0.9160 - dice_coef: 0.7180 - precision: 0.9195 - recall: 0.9374 - accuracy: 0.9518 - tversky: 0.7496 - val_loss: 0.2576 - val_iou: 0.9105 - val_dice_coef: 0.7020 - val_precision: 0.9071 - val_recall: 0.8956 - val_accuracy: 0.9384 - val_tversky: 0.7308
# Epoch 26/100
# 360/360 [==============================] - 8s 21ms/sample - loss: 0.2387 - iou: 0.9194 - dice_coef: 0.7233 - precision: 0.9249 - recall: 0.9365 - accuracy: 0.9542 - tversky: 0.7539 - val_loss: 0.2514 - val_iou: 0.9139 - val_dice_coef: 0.7052 - val_precision: 0.9246 - val_recall: 0.8832 - val_accuracy: 0.9407 - val_tversky: 0.7304
# Epoch 27/100
# 360/360 [==============================] - 8s 22ms/sample - loss: 0.2359 - iou: 0.9204 - dice_coef: 0.7249 - precision: 0.9291 - recall: 0.9327 - accuracy: 0.9547 - tversky: 0.7549 - val_loss: 0.2450 - val_iou: 0.9162 - val_dice_coef: 0.7050 - val_precision: 0.9301 - val_recall: 0.8798 - val_accuracy: 0.9423 - val_tversky: 0.7303
# Epoch 28/100
# 360/360 [==============================] - 8s 22ms/sample - loss: 0.2464 - iou: 0.9154 - dice_coef: 0.7174 - precision: 0.9072 - recall: 0.9259 - accuracy: 0.9449 - tversky: 0.7478 - val_loss: 0.2459 - val_iou: 0.9157 - val_dice_coef: 0.7064 - val_precision: 0.9068 - val_recall: 0.8925 - val_accuracy: 0.9400 - val_tversky: 0.7342
# Epoch 29/100
# 360/360 [==============================] - 8s 22ms/sample - loss: 0.2366 - iou: 0.9199 - dice_coef: 0.7265 - precision: 0.9049 - recall: 0.9439 - accuracy: 0.9497 - tversky: 0.7573 - val_loss: 0.2640 - val_iou: 0.9074 - val_dice_coef: 0.6992 - val_precision: 0.8658 - val_recall: 0.9113 - val_accuracy: 0.9285 - val_tversky: 0.7334
# Epoch 30/100
# 360/360 [==============================] - 8s 21ms/sample - loss: 0.2387 - iou: 0.9192 - dice_coef: 0.7258 - precision: 0.9182 - recall: 0.9262 - accuracy: 0.9472 - tversky: 0.7554 - val_loss: 0.2331 - val_iou: 0.9207 - val_dice_coef: 0.7229 - val_precision: 0.9357 - val_recall: 0.8793 - val_accuracy: 0.9429 - val_tversky: 0.7456
# Epoch 31/100
# 360/360 [==============================] - 8s 22ms/sample - loss: 0.2274 - iou: 0.9241 - dice_coef: 0.7347 - precision: 0.9230 - recall: 0.9351 - accuracy: 0.9531 - tversky: 0.7633 - val_loss: 0.2420 - val_iou: 0.9170 - val_dice_coef: 0.7118 - val_precision: 0.9268 - val_recall: 0.8684 - val_accuracy: 0.9377 - val_tversky: 0.7323
# Epoch 32/100
# 360/360 [==============================] - 8s 22ms/sample - loss: 0.2196 - iou: 0.9279 - dice_coef: 0.7416 - precision: 0.9284 - recall: 0.9393 - accuracy: 0.9565 - tversky: 0.7693 - val_loss: 0.2263 - val_iou: 0.9241 - val_dice_coef: 0.7324 - val_precision: 0.9160 - val_recall: 0.9102 - val_accuracy: 0.9460 - val_tversky: 0.7594
# Epoch 33/100
# 360/360 [==============================] - 8s 22ms/sample - loss: 0.2186 - iou: 0.9282 - dice_coef: 0.7425 - precision: 0.9243 - recall: 0.9405 - accuracy: 0.9561 - tversky: 0.7702 - val_loss: 0.2263 - val_iou: 0.9248 - val_dice_coef: 0.7279 - val_precision: 0.9178 - val_recall: 0.8958 - val_accuracy: 0.9445 - val_tversky: 0.7529
# Epoch 34/100
# 360/360 [==============================] - 8s 22ms/sample - loss: 0.2146 - iou: 0.9308 - dice_coef: 0.7486 - precision: 0.9334 - recall: 0.9395 - accuracy: 0.9574 - tversky: 0.7754 - val_loss: 0.2211 - val_iou: 0.9268 - val_dice_coef: 0.7380 - val_precision: 0.9022 - val_recall: 0.9247 - val_accuracy: 0.9469 - val_tversky: 0.7685
# Epoch 35/100
# 360/360 [==============================] - 8s 22ms/sample - loss: 0.2148 - iou: 0.9299 - dice_coef: 0.7475 - precision: 0.9285 - recall: 0.9384 - accuracy: 0.9559 - tversky: 0.7748 - val_loss: 0.2424 - val_iou: 0.9175 - val_dice_coef: 0.7206 - val_precision: 0.9058 - val_recall: 0.8817 - val_accuracy: 0.9349 - val_tversky: 0.7432
# Epoch 36/100
# 360/360 [==============================] - 8s 22ms/sample - loss: 0.2090 - iou: 0.9326 - dice_coef: 0.7534 - precision: 0.9268 - recall: 0.9459 - accuracy: 0.9580 - tversky: 0.7802 - val_loss: 0.2289 - val_iou: 0.9226 - val_dice_coef: 0.7447 - val_precision: 0.8685 - val_recall: 0.9479 - val_accuracy: 0.9397 - val_tversky: 0.7820
# Epoch 37/100
# 360/360 [==============================] - 8s 22ms/sample - loss: 0.2035 - iou: 0.9354 - dice_coef: 0.7574 - precision: 0.9368 - recall: 0.9435 - accuracy: 0.9608 - tversky: 0.7832 - val_loss: 0.2240 - val_iou: 0.9244 - val_dice_coef: 0.7526 - val_precision: 0.8700 - val_recall: 0.9494 - val_accuracy: 0.9404 - val_tversky: 0.7898
# Epoch 38/100
# 360/360 [==============================] - 8s 22ms/sample - loss: 0.1986 - iou: 0.9378 - dice_coef: 0.7623 - precision: 0.9373 - recall: 0.9478 - accuracy: 0.9625 - tversky: 0.7878 - val_loss: 0.2169 - val_iou: 0.9288 - val_dice_coef: 0.7416 - val_precision: 0.8869 - val_recall: 0.9437 - val_accuracy: 0.9467 - val_tversky: 0.7751
# Epoch 39/100
# 360/360 [==============================] - 8s 22ms/sample - loss: 0.2002 - iou: 0.9369 - dice_coef: 0.7623 - precision: 0.9358 - recall: 0.9466 - accuracy: 0.9607 - tversky: 0.7881 - val_loss: 0.2128 - val_iou: 0.9308 - val_dice_coef: 0.7460 - val_precision: 0.9091 - val_recall: 0.9290 - val_accuracy: 0.9488 - val_tversky: 0.7747
# Epoch 40/100
# 360/360 [==============================] - 8s 22ms/sample - loss: 0.1971 - iou: 0.9382 - dice_coef: 0.7643 - precision: 0.9391 - recall: 0.9438 - accuracy: 0.9617 - tversky: 0.7892 - val_loss: 0.2091 - val_iou: 0.9329 - val_dice_coef: 0.7514 - val_precision: 0.9211 - val_recall: 0.9196 - val_accuracy: 0.9501 - val_tversky: 0.7758
# Epoch 41/100
# 360/360 [==============================] - 8s 21ms/sample - loss: 0.1937 - iou: 0.9395 - dice_coef: 0.7682 - precision: 0.9330 - recall: 0.9524 - accuracy: 0.9624 - tversky: 0.7935 - val_loss: 0.2110 - val_iou: 0.9314 - val_dice_coef: 0.7518 - val_precision: 0.9090 - val_recall: 0.9230 - val_accuracy: 0.9472 - val_tversky: 0.7790
# Epoch 42/100
# 360/360 [==============================] - 8s 22ms/sample - loss: 0.1990 - iou: 0.9370 - dice_coef: 0.7639 - precision: 0.9352 - recall: 0.9381 - accuracy: 0.9584 - tversky: 0.7885 - val_loss: 0.2011 - val_iou: 0.9363 - val_dice_coef: 0.7598 - val_precision: 0.9210 - val_recall: 0.9259 - val_accuracy: 0.9520 - val_tversky: 0.7860
# Epoch 43/100
# 360/360 [==============================] - 8s 21ms/sample - loss: 0.1953 - iou: 0.9384 - dice_coef: 0.7675 - precision: 0.9333 - recall: 0.9439 - accuracy: 0.9596 - tversky: 0.7921 - val_loss: 0.2015 - val_iou: 0.9359 - val_dice_coef: 0.7631 - val_precision: 0.9251 - val_recall: 0.9174 - val_accuracy: 0.9509 - val_tversky: 0.7859
# Epoch 44/100
# 360/360 [==============================] - 8s 22ms/sample - loss: 0.1941 - iou: 0.9389 - dice_coef: 0.7689 - precision: 0.9370 - recall: 0.9411 - accuracy: 0.9596 - tversky: 0.7930 - val_loss: 0.2068 - val_iou: 0.9339 - val_dice_coef: 0.7508 - val_precision: 0.9297 - val_recall: 0.9054 - val_accuracy: 0.9489 - val_tversky: 0.7699
# Epoch 45/100
# 360/360 [==============================] - 8s 22ms/sample - loss: 0.1867 - iou: 0.9424 - dice_coef: 0.7760 - precision: 0.9372 - recall: 0.9490 - accuracy: 0.9629 - tversky: 0.7996 - val_loss: 0.2015 - val_iou: 0.9362 - val_dice_coef: 0.7588 - val_precision: 0.9299 - val_recall: 0.9069 - val_accuracy: 0.9501 - val_tversky: 0.7787
# Epoch 46/100
# 360/360 [==============================] - 8s 22ms/sample - loss: 0.1847 - iou: 0.9431 - dice_coef: 0.7782 - precision: 0.9361 - recall: 0.9515 - accuracy: 0.9632 - tversky: 0.8018 - val_loss: 0.2099 - val_iou: 0.9316 - val_dice_coef: 0.7596 - val_precision: 0.9046 - val_recall: 0.9208 - val_accuracy: 0.9442 - val_tversky: 0.7847
# Epoch 47/100
# 360/360 [==============================] - 8s 22ms/sample - loss: 0.1750 - iou: 0.9481 - dice_coef: 0.7872 - precision: 0.9475 - recall: 0.9553 - accuracy: 0.9683 - tversky: 0.8094 - val_loss: 0.2062 - val_iou: 0.9327 - val_dice_coef: 0.7677 - val_precision: 0.8905 - val_recall: 0.9407 - val_accuracy: 0.9449 - val_tversky: 0.7978
# Epoch 48/100
# 360/360 [==============================] - 8s 21ms/sample - loss: 0.1749 - iou: 0.9479 - dice_coef: 0.7874 - precision: 0.9489 - recall: 0.9513 - accuracy: 0.9675 - tversky: 0.8093 - val_loss: 0.1988 - val_iou: 0.9365 - val_dice_coef: 0.7685 - val_precision: 0.9020 - val_recall: 0.9402 - val_accuracy: 0.9493 - val_tversky: 0.7975
# Epoch 49/100
# 360/360 [==============================] - 8s 22ms/sample - loss: 0.1870 - iou: 0.9418 - dice_coef: 0.7775 - precision: 0.9314 - recall: 0.9481 - accuracy: 0.9603 - tversky: 0.8016 - val_loss: 0.1977 - val_iou: 0.9375 - val_dice_coef: 0.7659 - val_precision: 0.9193 - val_recall: 0.9225 - val_accuracy: 0.9508 - val_tversky: 0.7874
# Epoch 50/100
# 360/360 [==============================] - 8s 22ms/sample - loss: 0.1766 - iou: 0.9467 - dice_coef: 0.7859 - precision: 0.9486 - recall: 0.9453 - accuracy: 0.9655 - tversky: 0.8074 - val_loss: 0.2056 - val_iou: 0.9331 - val_dice_coef: 0.7546 - val_precision: 0.9564 - val_recall: 0.8628 - val_accuracy: 0.9442 - val_tversky: 0.7642
# Epoch 51/100
# 360/360 [==============================] - 8s 22ms/sample - loss: 0.1764 - iou: 0.9465 - dice_coef: 0.7873 - precision: 0.9408 - recall: 0.9508 - accuracy: 0.9647 - tversky: 0.8096 - val_loss: 0.1950 - val_iou: 0.9385 - val_dice_coef: 0.7693 - val_precision: 0.9187 - val_recall: 0.9231 - val_accuracy: 0.9503 - val_tversky: 0.7915
# Epoch 52/100
# 360/360 [==============================] - 8s 22ms/sample - loss: 0.1757 - iou: 0.9468 - dice_coef: 0.7882 - precision: 0.9396 - recall: 0.9498 - accuracy: 0.9641 - tversky: 0.8102 - val_loss: 0.1952 - val_iou: 0.9387 - val_dice_coef: 0.7692 - val_precision: 0.9368 - val_recall: 0.8998 - val_accuracy: 0.9495 - val_tversky: 0.7852
# Epoch 53/100
# 360/360 [==============================] - 8s 21ms/sample - loss: 0.1748 - iou: 0.9470 - dice_coef: 0.7906 - precision: 0.9388 - recall: 0.9498 - accuracy: 0.9636 - tversky: 0.8122 - val_loss: 0.1963 - val_iou: 0.9375 - val_dice_coef: 0.7706 - val_precision: 0.9191 - val_recall: 0.9128 - val_accuracy: 0.9481 - val_tversky: 0.7914
# Epoch 54/100
# 360/360 [==============================] - 8s 22ms/sample - loss: 0.1734 - iou: 0.9473 - dice_coef: 0.7910 - precision: 0.9375 - recall: 0.9530 - accuracy: 0.9643 - tversky: 0.8132 - val_loss: 0.1961 - val_iou: 0.9367 - val_dice_coef: 0.7766 - val_precision: 0.8955 - val_recall: 0.9392 - val_accuracy: 0.9470 - val_tversky: 0.8041
# Epoch 55/100
# 360/360 [==============================] - 8s 22ms/sample - loss: 0.1769 - iou: 0.9458 - dice_coef: 0.7879 - precision: 0.9388 - recall: 0.9465 - accuracy: 0.9623 - tversky: 0.8101 - val_loss: 0.1949 - val_iou: 0.9384 - val_dice_coef: 0.7693 - val_precision: 0.9302 - val_recall: 0.9027 - val_accuracy: 0.9484 - val_tversky: 0.7855
# Epoch 56/100
# 360/360 [==============================] - 8s 22ms/sample - loss: 0.1676 - iou: 0.9502 - dice_coef: 0.7975 - precision: 0.9460 - recall: 0.9519 - accuracy: 0.9665 - tversky: 0.8183 - val_loss: 0.2005 - val_iou: 0.9353 - val_dice_coef: 0.7666 - val_precision: 0.9158 - val_recall: 0.9058 - val_accuracy: 0.9447 - val_tversky: 0.7864
# Epoch 57/100
# 360/360 [==============================] - 8s 21ms/sample - loss: 0.1715 - iou: 0.9481 - dice_coef: 0.7939 - precision: 0.9335 - recall: 0.9535 - accuracy: 0.9632 - tversky: 0.8158 - val_loss: 0.2040 - val_iou: 0.9329 - val_dice_coef: 0.7731 - val_precision: 0.8912 - val_recall: 0.9220 - val_accuracy: 0.9409 - val_tversky: 0.7981
# Epoch 58/100
# 360/360 [==============================] - 8s 21ms/sample - loss: 0.1642 - iou: 0.9517 - dice_coef: 0.8002 - precision: 0.9487 - recall: 0.9508 - accuracy: 0.9673 - tversky: 0.8203 - val_loss: 0.1860 - val_iou: 0.9416 - val_dice_coef: 0.7843 - val_precision: 0.9166 - val_recall: 0.9263 - val_accuracy: 0.9506 - val_tversky: 0.8062
# Epoch 59/100
# 360/360 [==============================] - 8s 22ms/sample - loss: 0.1656 - iou: 0.9507 - dice_coef: 0.7997 - precision: 0.9437 - recall: 0.9516 - accuracy: 0.9659 - tversky: 0.8202 - val_loss: 0.1871 - val_iou: 0.9416 - val_dice_coef: 0.7768 - val_precision: 0.9315 - val_recall: 0.9079 - val_accuracy: 0.9504 - val_tversky: 0.7936
# Epoch 60/100
# 360/360 [==============================] - 8s 22ms/sample - loss: 0.1550 - iou: 0.9560 - dice_coef: 0.8093 - precision: 0.9540 - recall: 0.9580 - accuracy: 0.9713 - tversky: 0.8286 - val_loss: 0.1855 - val_iou: 0.9418 - val_dice_coef: 0.7825 - val_precision: 0.9226 - val_recall: 0.9192 - val_accuracy: 0.9506 - val_tversky: 0.8020
# Epoch 61/100
# 360/360 [==============================] - 8s 22ms/sample - loss: 0.1615 - iou: 0.9523 - dice_coef: 0.8048 - precision: 0.9444 - recall: 0.9550 - accuracy: 0.9670 - tversky: 0.8251 - val_loss: 0.1868 - val_iou: 0.9412 - val_dice_coef: 0.7854 - val_precision: 0.9127 - val_recall: 0.9293 - val_accuracy: 0.9497 - val_tversky: 0.8069
# Epoch 62/100
# 360/360 [==============================] - 8s 22ms/sample - loss: 0.1634 - iou: 0.9514 - dice_coef: 0.8031 - precision: 0.9419 - recall: 0.9535 - accuracy: 0.9657 - tversky: 0.8237 - val_loss: 0.1849 - val_iou: 0.9425 - val_dice_coef: 0.7787 - val_precision: 0.9246 - val_recall: 0.9121 - val_accuracy: 0.9508 - val_tversky: 0.7971
# Epoch 63/100
# 360/360 [==============================] - 8s 22ms/sample - loss: 0.1610 - iou: 0.9523 - dice_coef: 0.8049 - precision: 0.9453 - recall: 0.9514 - accuracy: 0.9666 - tversky: 0.8246 - val_loss: 0.1807 - val_iou: 0.9435 - val_dice_coef: 0.7908 - val_precision: 0.9208 - val_recall: 0.9249 - val_accuracy: 0.9515 - val_tversky: 0.8107
# Epoch 64/100
# 360/360 [==============================] - 8s 22ms/sample - loss: 0.1571 - iou: 0.9542 - dice_coef: 0.8089 - precision: 0.9450 - recall: 0.9583 - accuracy: 0.9682 - tversky: 0.8291 - val_loss: 0.1794 - val_iou: 0.9443 - val_dice_coef: 0.7892 - val_precision: 0.9234 - val_recall: 0.9251 - val_accuracy: 0.9521 - val_tversky: 0.8089
# Epoch 65/100
# 360/360 [==============================] - 8s 22ms/sample - loss: 0.1586 - iou: 0.9533 - dice_coef: 0.8069 - precision: 0.9444 - recall: 0.9555 - accuracy: 0.9675 - tversky: 0.8270 - val_loss: 0.1800 - val_iou: 0.9440 - val_dice_coef: 0.7874 - val_precision: 0.9405 - val_recall: 0.9003 - val_accuracy: 0.9512 - val_tversky: 0.8011
# Epoch 66/100
# 360/360 [==============================] - 8s 22ms/sample - loss: 0.1565 - iou: 0.9543 - dice_coef: 0.8099 - precision: 0.9458 - recall: 0.9562 - accuracy: 0.9680 - tversky: 0.8296 - val_loss: 0.1802 - val_iou: 0.9439 - val_dice_coef: 0.7897 - val_precision: 0.9321 - val_recall: 0.9110 - val_accuracy: 0.9510 - val_tversky: 0.8058
# Epoch 67/100
# 360/360 [==============================] - 8s 21ms/sample - loss: 0.1618 - iou: 0.9517 - dice_coef: 0.8053 - precision: 0.9459 - recall: 0.9479 - accuracy: 0.9651 - tversky: 0.8247 - val_loss: 0.1780 - val_iou: 0.9446 - val_dice_coef: 0.7886 - val_precision: 0.9504 - val_recall: 0.8912 - val_accuracy: 0.9518 - val_tversky: 0.7993
# Epoch 68/100
# 360/360 [==============================] - 8s 22ms/sample - loss: 0.1612 - iou: 0.9516 - dice_coef: 0.8068 - precision: 0.9371 - recall: 0.9529 - accuracy: 0.9640 - tversky: 0.8269 - val_loss: 0.1894 - val_iou: 0.9384 - val_dice_coef: 0.7909 - val_precision: 0.8796 - val_recall: 0.9553 - val_accuracy: 0.9451 - val_tversky: 0.8212
# Epoch 69/100
# 360/360 [==============================] - 8s 22ms/sample - loss: 0.1513 - iou: 0.9564 - dice_coef: 0.8155 - precision: 0.9486 - recall: 0.9576 - accuracy: 0.9692 - tversky: 0.8344 - val_loss: 0.1780 - val_iou: 0.9447 - val_dice_coef: 0.7918 - val_precision: 0.9267 - val_recall: 0.9154 - val_accuracy: 0.9514 - val_tversky: 0.8081
# Epoch 70/100
# 360/360 [==============================] - 8s 21ms/sample - loss: 0.1549 - iou: 0.9545 - dice_coef: 0.8115 - precision: 0.9426 - recall: 0.9579 - accuracy: 0.9677 - tversky: 0.8315 - val_loss: 0.1797 - val_iou: 0.9443 - val_dice_coef: 0.7875 - val_precision: 0.9253 - val_recall: 0.9155 - val_accuracy: 0.9506 - val_tversky: 0.8050
# Epoch 71/100
# 360/360 [==============================] - 8s 22ms/sample - loss: 0.1459 - iou: 0.9588 - dice_coef: 0.8207 - precision: 0.9580 - recall: 0.9549 - accuracy: 0.9715 - tversky: 0.8380 - val_loss: 0.1764 - val_iou: 0.9449 - val_dice_coef: 0.7886 - val_precision: 0.9083 - val_recall: 0.9375 - val_accuracy: 0.9515 - val_tversky: 0.8140
# Epoch 72/100
# 360/360 [==============================] - 8s 22ms/sample - loss: 0.1442 - iou: 0.9595 - dice_coef: 0.8230 - precision: 0.9526 - recall: 0.9616 - accuracy: 0.9719 - tversky: 0.8410 - val_loss: 0.1852 - val_iou: 0.9410 - val_dice_coef: 0.7860 - val_precision: 0.8996 - val_recall: 0.9307 - val_accuracy: 0.9468 - val_tversky: 0.8092
# Epoch 73/100
# 360/360 [==============================] - 8s 22ms/sample - loss: 0.1459 - iou: 0.9585 - dice_coef: 0.8210 - precision: 0.9499 - recall: 0.9607 - accuracy: 0.9710 - tversky: 0.8394 - val_loss: 0.1876 - val_iou: 0.9405 - val_dice_coef: 0.7925 - val_precision: 0.8901 - val_recall: 0.9406 - val_accuracy: 0.9455 - val_tversky: 0.8172
# Epoch 74/100
# 360/360 [==============================] - 8s 22ms/sample - loss: 0.1456 - iou: 0.9585 - dice_coef: 0.8213 - precision: 0.9524 - recall: 0.9578 - accuracy: 0.9709 - tversky: 0.8393 - val_loss: 0.1833 - val_iou: 0.9431 - val_dice_coef: 0.7896 - val_precision: 0.9274 - val_recall: 0.9067 - val_accuracy: 0.9483 - val_tversky: 0.8028
# Epoch 75/100
# 360/360 [==============================] - 8s 22ms/sample - loss: 0.1428 - iou: 0.9596 - dice_coef: 0.8246 - precision: 0.9512 - recall: 0.9617 - accuracy: 0.9717 - tversky: 0.8426 - val_loss: 0.1774 - val_iou: 0.9446 - val_dice_coef: 0.7967 - val_precision: 0.9087 - val_recall: 0.9337 - val_accuracy: 0.9504 - val_tversky: 0.8177
# Epoch 76/100
# 360/360 [==============================] - 8s 22ms/sample - loss: 0.1493 - iou: 0.9567 - dice_coef: 0.8186 - precision: 0.9457 - recall: 0.9566 - accuracy: 0.9684 - tversky: 0.8373 - val_loss: 0.1722 - val_iou: 0.9469 - val_dice_coef: 0.8011 - val_precision: 0.9121 - val_recall: 0.9385 - val_accuracy: 0.9524 - val_tversky: 0.8222
# Epoch 77/100
# 360/360 [==============================] - 8s 22ms/sample - loss: 0.1431 - iou: 0.9594 - dice_coef: 0.8245 - precision: 0.9517 - recall: 0.9604 - accuracy: 0.9712 - tversky: 0.8425 - val_loss: 0.1690 - val_iou: 0.9481 - val_dice_coef: 0.8014 - val_precision: 0.9315 - val_recall: 0.9209 - val_accuracy: 0.9539 - val_tversky: 0.8176
# Epoch 78/100
# 360/360 [==============================] - 8s 22ms/sample - loss: 0.1423 - iou: 0.9597 - dice_coef: 0.8258 - precision: 0.9550 - recall: 0.9573 - accuracy: 0.9713 - tversky: 0.8431 - val_loss: 0.1754 - val_iou: 0.9453 - val_dice_coef: 0.7957 - val_precision: 0.9446 - val_recall: 0.8931 - val_accuracy: 0.9504 - val_tversky: 0.8059
# Epoch 79/100
# 360/360 [==============================] - 8s 21ms/sample - loss: 0.1384 - iou: 0.9613 - dice_coef: 0.8295 - precision: 0.9554 - recall: 0.9597 - accuracy: 0.9726 - tversky: 0.8463 - val_loss: 0.1740 - val_iou: 0.9460 - val_dice_coef: 0.7915 - val_precision: 0.9449 - val_recall: 0.8961 - val_accuracy: 0.9516 - val_tversky: 0.8024
# Epoch 80/100
# 360/360 [==============================] - 8s 22ms/sample - loss: 0.1373 - iou: 0.9619 - dice_coef: 0.8311 - precision: 0.9552 - recall: 0.9624 - accuracy: 0.9730 - tversky: 0.8482 - val_loss: 0.1688 - val_iou: 0.9480 - val_dice_coef: 0.8037 - val_precision: 0.9310 - val_recall: 0.9209 - val_accuracy: 0.9539 - val_tversky: 0.8185
# Epoch 81/100
# 360/360 [==============================] - 8s 22ms/sample - loss: 0.1400 - iou: 0.9603 - dice_coef: 0.8291 - precision: 0.9510 - recall: 0.9593 - accuracy: 0.9709 - tversky: 0.8463 - val_loss: 0.1691 - val_iou: 0.9482 - val_dice_coef: 0.8037 - val_precision: 0.9397 - val_recall: 0.9098 - val_accuracy: 0.9534 - val_tversky: 0.8150
# Epoch 82/100
# 360/360 [==============================] - 8s 22ms/sample - loss: 0.1376 - iou: 0.9614 - dice_coef: 0.8315 - precision: 0.9518 - recall: 0.9616 - accuracy: 0.9719 - tversky: 0.8485 - val_loss: 0.1739 - val_iou: 0.9458 - val_dice_coef: 0.7996 - val_precision: 0.9334 - val_recall: 0.9058 - val_accuracy: 0.9501 - val_tversky: 0.8127
# Epoch 83/100
# 360/360 [==============================] - 8s 22ms/sample - loss: 0.1424 - iou: 0.9591 - dice_coef: 0.8269 - precision: 0.9516 - recall: 0.9563 - accuracy: 0.9699 - tversky: 0.8442 - val_loss: 0.1681 - val_iou: 0.9478 - val_dice_coef: 0.8096 - val_precision: 0.9203 - val_recall: 0.9286 - val_accuracy: 0.9523 - val_tversky: 0.8276
# Epoch 84/100
# 360/360 [==============================] - 8s 21ms/sample - loss: 0.1428 - iou: 0.9588 - dice_coef: 0.8252 - precision: 0.9430 - recall: 0.9606 - accuracy: 0.9693 - tversky: 0.8435 - val_loss: 0.1714 - val_iou: 0.9462 - val_dice_coef: 0.8019 - val_precision: 0.9116 - val_recall: 0.9280 - val_accuracy: 0.9512 - val_tversky: 0.8216
# Epoch 85/100
# 360/360 [==============================] - 8s 22ms/sample - loss: 0.1387 - iou: 0.9606 - dice_coef: 0.8296 - precision: 0.9558 - recall: 0.9543 - accuracy: 0.9711 - tversky: 0.8457 - val_loss: 0.1731 - val_iou: 0.9457 - val_dice_coef: 0.7991 - val_precision: 0.9535 - val_recall: 0.8848 - val_accuracy: 0.9500 - val_tversky: 0.8063
# Epoch 86/100
# 360/360 [==============================] - 8s 22ms/sample - loss: 0.1377 - iou: 0.9607 - dice_coef: 0.8309 - precision: 0.9520 - recall: 0.9587 - accuracy: 0.9714 - tversky: 0.8478 - val_loss: 0.1668 - val_iou: 0.9487 - val_dice_coef: 0.8077 - val_precision: 0.9388 - val_recall: 0.9122 - val_accuracy: 0.9532 - val_tversky: 0.8195
# Epoch 87/100
# 360/360 [==============================] - 8s 22ms/sample - loss: 0.1395 - iou: 0.9599 - dice_coef: 0.8313 - precision: 0.9510 - recall: 0.9579 - accuracy: 0.9700 - tversky: 0.8483 - val_loss: 0.1727 - val_iou: 0.9463 - val_dice_coef: 0.8019 - val_precision: 0.9582 - val_recall: 0.8823 - val_accuracy: 0.9506 - val_tversky: 0.8061
# Epoch 88/100
# 360/360 [==============================] - 8s 22ms/sample - loss: 0.1334 - iou: 0.9630 - dice_coef: 0.8354 - precision: 0.9546 - recall: 0.9627 - accuracy: 0.9731 - tversky: 0.8520 - val_loss: 0.1740 - val_iou: 0.9458 - val_dice_coef: 0.8007 - val_precision: 0.9570 - val_recall: 0.8794 - val_accuracy: 0.9498 - val_tversky: 0.8040
# Epoch 89/100
# 360/360 [==============================] - 8s 22ms/sample - loss: 0.1399 - iou: 0.9598 - dice_coef: 0.8302 - precision: 0.9495 - recall: 0.9578 - accuracy: 0.9698 - tversky: 0.8473 - val_loss: 0.1659 - val_iou: 0.9488 - val_dice_coef: 0.8099 - val_precision: 0.9384 - val_recall: 0.9109 - val_accuracy: 0.9530 - val_tversky: 0.8213
# Epoch 90/100
# 360/360 [==============================] - 8s 22ms/sample - loss: 0.1325 - iou: 0.9632 - dice_coef: 0.8375 - precision: 0.9519 - recall: 0.9646 - accuracy: 0.9728 - tversky: 0.8541 - val_loss: 0.1697 - val_iou: 0.9466 - val_dice_coef: 0.8085 - val_precision: 0.9063 - val_recall: 0.9363 - val_accuracy: 0.9501 - val_tversky: 0.8287
# Epoch 91/100
# 360/360 [==============================] - 8s 22ms/sample - loss: 0.1326 - iou: 0.9630 - dice_coef: 0.8371 - precision: 0.9553 - recall: 0.9602 - accuracy: 0.9726 - tversky: 0.8532 - val_loss: 0.1630 - val_iou: 0.9501 - val_dice_coef: 0.8114 - val_precision: 0.9453 - val_recall: 0.9051 - val_accuracy: 0.9542 - val_tversky: 0.8205
# Epoch 92/100
# 360/360 [==============================] - 8s 22ms/sample - loss: 0.1293 - iou: 0.9641 - dice_coef: 0.8403 - precision: 0.9537 - recall: 0.9646 - accuracy: 0.9737 - tversky: 0.8565 - val_loss: 0.1589 - val_iou: 0.9517 - val_dice_coef: 0.8102 - val_precision: 0.9298 - val_recall: 0.9273 - val_accuracy: 0.9560 - val_tversky: 0.8268
# Epoch 93/100
# 360/360 [==============================] - 8s 21ms/sample - loss: 0.1297 - iou: 0.9642 - dice_coef: 0.8390 - precision: 0.9584 - recall: 0.9602 - accuracy: 0.9739 - tversky: 0.8546 - val_loss: 0.1649 - val_iou: 0.9495 - val_dice_coef: 0.8085 - val_precision: 0.9503 - val_recall: 0.8925 - val_accuracy: 0.9528 - val_tversky: 0.8147
# Epoch 94/100
# 360/360 [==============================] - 8s 21ms/sample - loss: 0.1370 - iou: 0.9607 - dice_coef: 0.8344 - precision: 0.9472 - recall: 0.9606 - accuracy: 0.9699 - tversky: 0.8515 - val_loss: 0.1671 - val_iou: 0.9482 - val_dice_coef: 0.8070 - val_precision: 0.9422 - val_recall: 0.9022 - val_accuracy: 0.9519 - val_tversky: 0.8164
# Epoch 95/100
# 360/360 [==============================] - 8s 22ms/sample - loss: 0.1318 - iou: 0.9629 - dice_coef: 0.8383 - precision: 0.9556 - recall: 0.9604 - accuracy: 0.9726 - tversky: 0.8544 - val_loss: 0.1599 - val_iou: 0.9513 - val_dice_coef: 0.8172 - val_precision: 0.9391 - val_recall: 0.9152 - val_accuracy: 0.9546 - val_tversky: 0.8283
# Epoch 96/100
# 360/360 [==============================] - 8s 21ms/sample - loss: 0.1345 - iou: 0.9615 - dice_coef: 0.8362 - precision: 0.9487 - recall: 0.9607 - accuracy: 0.9706 - tversky: 0.8528 - val_loss: 0.1633 - val_iou: 0.9499 - val_dice_coef: 0.8132 - val_precision: 0.9280 - val_recall: 0.9192 - val_accuracy: 0.9527 - val_tversky: 0.8266
# Epoch 97/100
# 360/360 [==============================] - 8s 22ms/sample - loss: 0.1264 - iou: 0.9652 - dice_coef: 0.8447 - precision: 0.9551 - recall: 0.9648 - accuracy: 0.9739 - tversky: 0.8602 - val_loss: 0.1603 - val_iou: 0.9510 - val_dice_coef: 0.8191 - val_precision: 0.9366 - val_recall: 0.9161 - val_accuracy: 0.9543 - val_tversky: 0.8304
# Epoch 98/100
# 360/360 [==============================] - 8s 22ms/sample - loss: 0.1255 - iou: 0.9656 - dice_coef: 0.8454 - precision: 0.9598 - recall: 0.9613 - accuracy: 0.9743 - tversky: 0.8600 - val_loss: 0.1544 - val_iou: 0.9529 - val_dice_coef: 0.8242 - val_precision: 0.9289 - val_recall: 0.9341 - val_accuracy: 0.9570 - val_tversky: 0.8396
# Epoch 99/100
# 360/360 [==============================] - 8s 22ms/sample - loss: 0.1270 - iou: 0.9651 - dice_coef: 0.8445 - precision: 0.9566 - recall: 0.9632 - accuracy: 0.9737 - tversky: 0.8599 - val_loss: 0.1539 - val_iou: 0.9532 - val_dice_coef: 0.8205 - val_precision: 0.9377 - val_recall: 0.9238 - val_accuracy: 0.9572 - val_tversky: 0.8337
# Epoch 100/100
# 360/360 [==============================] - 8s 22ms/sample - loss: 0.1273 - iou: 0.9644 - dice_coef: 0.8438 - precision: 0.9569 - recall: 0.9607 - accuracy: 0.9732 - tversky: 0.8591 - val_loss: 0.1546 - val_iou: 0.9527 - val_dice_coef: 0.8235 - val_precision: 0.9249 - val_recall: 0.9369 - val_accuracy: 0.9563 - val_tversky: 0.8405

# %%
model_1 = Model(inputs=img_input, outputs=pred)
model_1.compile(optimizer= SGD(lr=0.001, momentum=0.9, decay=0.0005, nesterov=False), loss= ["binary_crossentropy"]
              , metrics=[iou, dice_coef, precision, recall, accuracy,tversky])

# %%
model_1.load_weights('segnet_100_epoch.h5')

# %% [markdown]
# Testing the statistics after 100 epochs

# %%
print('\n~~~~~~~~~~~~~~~Stats after 100 epoch~~~~~~~~~~~~~~~~~~~')
print('\n-------------On Train Set--------------------------\n')
res = model_1.evaluate(x_train, y_train, batch_size= 18)
print('________________________')
print('IOU:       |   {:.2f}  |'.format(res[1]*100))
print('Dice Coef: |   {:.2f}  |'.format(res[2]*100))
print('Precision: |   {:.2f}  |'.format(res[3]*100))
print('Recall:    |   {:.2f}  |'.format(res[4]*100))
print('Accuracy:  |   {:.2f}  |'.format(res[5]*100))
print('Tversky:   |   {:.2f}  |'.format(res[6]*100))
print("Loss:      |   {:.2f}  |".format(res[0]*100))
print('________________________')
print('\n-------------On Test  Set--------------------------\n')
res = model_1.evaluate(x_test, y_test, batch_size= 18)
print('________________________')
print('IOU:       |   {:.2f}  |'.format(res[1]*100))
print('Dice Coef: |   {:.2f}  |'.format(res[2]*100))
print('Precision: |   {:.2f}  |'.format(res[3]*100))
print('Recall:    |   {:.2f}  |'.format(res[4]*100))
print('Accuracy:  |   {:.2f}  |'.format(res[5]*100))
print('Tversky:   |   {:.2f}  |'.format(res[6]*100))
print("Loss:      |   {:.2f}  |".format(res[0]*100))
print('________________________')
print('\n-------------On validation Set---------------------\n')
res = model_1.evaluate(x_val, y_val, batch_size= 18)
print('________________________')
print('IOU:       |   {:.2f}  |'.format(res[1]*100))
print('Dice Coef: |   {:.2f}  |'.format(res[2]*100))
print('Precision: |   {:.2f}  |'.format(res[3]*100))
print('Recall:    |   {:.2f}  |'.format(res[4]*100))
print('Accuracy:  |   {:.2f}  |'.format(res[5]*100))
print('Tversky:   |   {:.2f}  |'.format(res[6]*100))
print("Loss:      |   {:.2f}  |".format(res[0]*100))
print('________________________')
# Out:
# ~~~~~~~~~~~~~~~Stats after 100 epoch~~~~~~~~~~~~~~~~~~~
#
# -------------On Train Set--------------------------
#
# 360/360 [==============================] - 3s 9ms/sample - loss: 0.1134 - iou: 0.9704 - dice_coef: 0.8545 - precision: 0.9574 - recall: 0.9736 - accuracy: 0.9781 - tversky: 0.8725
# ________________________
# IOU:       |   97.04  |
# Dice Coef: |   85.45  |
# Precision: |   95.74  |
# Recall:    |   97.36  |
# Accuracy:  |   97.81  |
# Tversky:   |   87.25  |
# Loss:      |   11.34  |
# ________________________
#
# -------------On Test  Set--------------------------
#
# 50/50 [==============================] - 1s 17ms/sample - loss: 0.1875 - iou: 0.9368 - dice_coef: 0.8049 - precision: 0.8909 - recall: 0.9170 - accuracy: 0.9390 - tversky: 0.8236
# ________________________
# IOU:       |   93.68  |
# Dice Coef: |   80.49  |
# Precision: |   89.09  |
# Recall:    |   91.70  |
# Accuracy:  |   93.90  |
# Tversky:   |   82.36  |
# Loss:      |   18.75  |
# ________________________
#
# -------------On validation Set---------------------
#
# 90/90 [==============================] - 1s 7ms/sample - loss: 0.1546 - iou: 0.9527 - dice_coef: 0.8246 - precision: 0.9255 - recall: 0.9366 - accuracy: 0.9563 - tversky: 0.8413
# ________________________
# IOU:       |   95.27  |
# Dice Coef: |   82.46  |
# Precision: |   92.55  |
# Recall:    |   93.66  |
# Accuracy:  |   95.63  |
# Tversky:   |   84.13  |
# Loss:      |   15.46  |
# ________________________

# %% [markdown]
# ### Plotting Training Statistics

# %%
plt.figure(figsize=(20, 14))
plt.suptitle('Training Statistics on Train Set')
plt.subplot(2,2,1)
plt.plot(hist.history['loss'], 'red')
plt.title('Loss')
plt.subplot(2,2,2)
plt.plot(hist.history['accuracy'], 'green')
plt.title('Accuracy')
plt.subplot(2,2,3)
plt.plot(hist.history['val_loss'], 'red')
plt.yticks(list(np.arange(0.0, 1.0, 0.10)))
plt.title('Valdiation Loss')
plt.subplot(2,2,4)
plt.plot(hist.history['val_accuracy'], 'green')
plt.yticks(list(np.arange(0.0, 1.0, 0.10)))
plt.title('Validation Accuracy')
plt.show()

# %% [markdown]
# ## Visualising Predicted Lesions

# %% [markdown]
# We have trained the model on the **training set**.
# We will make predictions on the unseen **test set**

# %%
img_num = 49
img_pred = model_0.predict(x_test[img_num].reshape(1,192,256,3))
plt.figure(figsize=(16,16))
plt.subplot(1,3,1)
plt.imshow(x_test[img_num])
plt.title('Original Image')
plt.subplot(1,3,2)
plt.imshow(y_test[img_num], plt.cm.binary_r)
plt.title('Ground Truth')
plt.subplot(1,3,3)
plt.imshow(img_pred.reshape(192, 256), plt.cm.binary_r)
plt.title('Predicted Output')
plt.show()

# %%
img_num = 10
img_pred = model_1.predict(x_test[img_num].reshape(1,192,256,3))
plt.figure(figsize=(16,16))
plt.subplot(1,3,1)
plt.imshow(x_test[img_num])
plt.title('Original Image')
plt.subplot(1,3,2)
plt.imshow(y_test[img_num], plt.cm.binary_r)
plt.title('Ground Truth')
plt.subplot(1,3,3)
plt.imshow(img_pred.reshape(192, 256), plt.cm.binary_r)
plt.title('Predicted Output')
plt.show()

# %%
img_num = 36
img_pred = model_1.predict(x_test[img_num].reshape(1,192,256,3))
plt.figure(figsize=(16,16))
plt.subplot(1,3,1)
plt.imshow(x_test[img_num])
plt.title('Original Image')
plt.subplot(1,3,2)
plt.imshow(y_test[img_num], plt.cm.binary_r)
plt.title('Ground Truth')
plt.subplot(1,3,3)
plt.imshow(img_pred.reshape(192, 256), plt.cm.binary_r)
plt.title('Predicted Output')
plt.show()

# %%
img_num = 32
img_pred = model_1.predict(x_test[img_num].reshape(1,192,256,3))
plt.figure(figsize=(16,16))
plt.subplot(1,3,1)
plt.imshow(x_test[img_num])
plt.title('Original Image')
plt.subplot(1,3,2)
plt.imshow(y_test[img_num], plt.cm.binary_r)
plt.title('Ground Truth')
plt.subplot(1,3,3)
plt.imshow(img_pred.reshape(192, 256), plt.cm.binary_r)
plt.title('Predicted Output')
plt.show()

# %%
img_num = 29
img_pred = model_1.predict(x_test[img_num].reshape(1,192,256,3))
plt.figure(figsize=(16,16))
plt.subplot(1,3,1)
plt.imshow(x_test[img_num])
plt.title('Original Image')
plt.subplot(1,3,2)
plt.imshow(y_test[img_num], plt.cm.binary_r)
plt.title('Ground Truth')
plt.subplot(1,3,3)
plt.imshow(img_pred.reshape(192, 256), plt.cm.binary_r)
plt.title('Predicted Output')
plt.show()

# %%
img_num = 21
img_pred = model_1.predict(x_test[img_num].reshape(1,192,256,3))
plt.figure(figsize=(16,16))
plt.subplot(1,3,1)
plt.imshow(x_test[img_num])
plt.title('Original Image')
plt.subplot(1,3,2)
plt.imshow(y_test[img_num], plt.cm.binary_r)
plt.title('Ground Truth')
plt.subplot(1,3,3)
plt.imshow(img_pred.reshape(192, 256), plt.cm.binary_r)
plt.title('Predicted Output')
plt.show()

# %% [markdown]
# ## Final Enhance

# %% [markdown]
# * Currently the predicted outputs are blurry because the predicted pixel values are in the range 0 - 1.
# * To make clear edge preditions we can enhance our image by rounding up the pixel values to 1 which are > 0.5  .
# * While rounding down the pixel values to 0 which are < 0.5.
# * We can enhance the image to look for absolute shape predicted by ceiling and flooring the predicted values.

# %%
def enhance(img):
    sub = (model_1.predict(img.reshape(1,192,256,3))).flatten()

    for i in range(len(sub)):
        if sub[i] > 0.5:
            sub[i] = 1
        else:
            sub[i] = 0
    return sub

# %%
plt.figure(figsize=(12,12))
plt.suptitle('Comparing the Prediction after enhancement')
plt.subplot(3,2,1)
plt.imshow(y_test[21],plt.cm.binary_r)
plt.title('Ground Truth')
plt.subplot(3,2,2)
plt.imshow(enhance(x_test[21]).reshape(192,256), plt.cm.binary_r)
plt.title('Predicted')
plt.subplot(3,2,3)
plt.imshow(y_test[47],plt.cm.binary_r)
plt.title('Ground Truth')
plt.subplot(3,2,4)
plt.imshow(enhance(x_test[47]).reshape(192,256), plt.cm.binary_r)
plt.title('Predicted')
plt.subplot(3,2,5)
plt.imshow(y_test[36],plt.cm.binary_r)
plt.title('Ground Truth')
plt.subplot(3,2,6)
plt.imshow(enhance(x_test[36]).reshape(192,256), plt.cm.binary_r)
plt.title('Predicted')
plt.show()

# %% [markdown]
# * So we can observe that our results are very good on the Test dataset which suggests that the model is quite robust and well performing too.

# %% [markdown]
# ### **de nada!**
