# %% [markdown]
# ## Importing the Libraries

# %%
from keras.models import Model, Sequential
from keras.layers import Activation, Dense, BatchNormalization, concatenate, Dropout, Conv2D, Conv2DTranspose, MaxPooling2D, UpSampling2D, Input, Reshape
from keras.callbacks import EarlyStopping
from keras.layers.core import SpatialDropout2D
from keras import backend as K
from keras.optimizers_v1 import Adam
import tensorflow as tf
import numpy as np
import pandas as pd
import glob
import PIL
from PIL import Image
import matplotlib.pyplot as plt
import cv2
# %matplotlib inline

from keras.preprocessing.image import ImageDataGenerator
from sklearn.model_selection import train_test_split
from warnings import filterwarnings

filterwarnings('ignore')
np.random.seed(101)

# %% [markdown]
# ## Loading the Data

# %% [markdown]
# Defining a function to load the data in sorted order

# %%
import re
numbers = re.compile(r'(\d+)')
def numericalSort(value):
    parts = numbers.split(value)
    parts[1::2] = map(int, parts[1::2])
    return parts

# %%
filelist_trainx = sorted(glob.glob('../input/*/trainx/*.bmp'), key=numericalSort)
X_train = np.array([np.array(Image.open(fname)) for fname in filelist_trainx])

filelist_trainy = sorted(glob.glob('../input/*/trainy/*.bmp'), key=numericalSort)
Y_train = np.array([np.array(Image.open(fname)) for fname in filelist_trainy])

# %% [markdown]
# Splitting the dataset into training set and test set to verify our model performance without any bias.

# %%
x_train, x_test, y_train, y_test = train_test_split(X_train, Y_train, test_size = 0.25, random_state = 101)

# %% [markdown]
# Let's plot an image to see how the original images look.

# %%
plt.figure(figsize=(20,9))
plt.subplot(2,4,1)
plt.imshow(X_train[0])
plt.subplot(2,4,2)
plt.imshow(X_train[3])
plt.subplot(2,4,3)
plt.imshow(X_train[54])
plt.subplot(2,4,4)
plt.imshow(X_train[77])
plt.subplot(2,4,5)
plt.imshow(X_train[100])
plt.subplot(2,4,6)
plt.imshow(X_train[125])
plt.subplot(2,4,7)
plt.imshow(X_train[130])
plt.subplot(2,4,8)
plt.imshow(X_train[149])
plt.show()

# %% [markdown]
# Now let's see their corresponding masks.

# %%
plt.figure(figsize=(20,9))
plt.subplot(2,4,1)
plt.imshow(Y_train[0], cmap = plt.cm.binary_r)
plt.subplot(2,4,2)
plt.imshow(Y_train[3], cmap = plt.cm.binary_r)
plt.subplot(2,4,3)
plt.imshow(Y_train[54], cmap = plt.cm.binary_r)
plt.subplot(2,4,4)
plt.imshow(Y_train[77], cmap = plt.cm.binary_r)
plt.subplot(2,4,5)
plt.imshow(Y_train[100], cmap = plt.cm.binary_r)
plt.subplot(2,4,6)
plt.imshow(Y_train[125], cmap = plt.cm.binary_r)
plt.subplot(2,4,7)
plt.imshow(Y_train[130], cmap = plt.cm.binary_r)
plt.subplot(2,4,8)
plt.imshow(Y_train[149], cmap = plt.cm.binary_r)
plt.show()

# %% [markdown]
# ## Defining the Loss Function

# %% [markdown]
# #### Jaccard Distance
# The Jaccard distance, which measures dissimilarity between sample sets, is complementary to the Jaccard coefficient and is obtained by subtracting the Jaccard coefficient from 1, or, equivalently, by dividing the difference of the sizes of the union and the intersection of two sets by the size of the union:

# %% [markdown]
# ![jd](https://www.geeksforgeeks.org/wp-content/ql-cache/quicklatex.com-44046533fcd54e98cb53619b3390e083_l3.svg)

# %%
def jaccard_distance(y_true, y_pred, smooth=100):
    intersection = K.sum(K.abs(y_true * y_pred), axis=-1)
    sum_ = K.sum(K.square(y_true), axis = -1) + K.sum(K.square(y_pred), axis=-1)
    jac = (intersection + smooth) / (sum_ - intersection + smooth)
    return (1 - jac)

# %% [markdown]
# ## Defining Evaluation Metrics

# %% [markdown]
# #### Intersection over Union
# The Jaccard index, also known as Intersection over Union and the Jaccard similarity coefficient is a statistic used for gauging the similarity and diversity of sample sets. The Jaccard coefficient measures similarity between finite sample sets, and is defined as the size of the intersection divided by the size of the union of the sample sets:

# %% [markdown]
# ![iou](https://www.d2l.ai/_images/iou.svg)

# %%
def iou(y_true, y_pred, smooth = 100):
    intersection = K.sum(K.abs(y_true * y_pred), axis=-1)
    sum_ = K.sum(K.square(y_true), axis = -1) + K.sum(K.square(y_pred), axis=-1)
    jac = (intersection + smooth) / (sum_ - intersection + smooth)
    return jac

# %% [markdown]
# #### Dice coefficient
# The Dice score is not only a measure of how many positives you find, but it also penalizes for the false positives that the method finds, similar to precision. so it is more similar to precision than accuracy.

# %% [markdown]
# ![dc](https://cdn-images-1.medium.com/max/1600/1*Z1hkDvyhFBogT9EkzVkX2A.png)

# %%
def dice_coe(y_true, y_pred, smooth = 100):
    y_true_f = K.flatten(y_true)
    y_pred_f = K.flatten(y_pred)
    intersection = K.sum(y_true_f * y_pred_f)
    return (2. * intersection + smooth) / (K.sum(y_true_f) + K.sum(y_pred_f) + smooth)

# %% [markdown]
# #### Precision
# Precision is a good measure to determine, when the costs of False Positive is high.

# %% [markdown]
# ![precsion](https://wikimedia.org/api/rest_v1/media/math/render/svg/26106935459abe7c266f7b1ebfa2a824b334c807)

# %%
def precision(y_true, y_pred):
    '''Calculates the precision, a metric for multi-label classification of
    how many selected items are relevant.
    '''
    true_positives = K.sum(K.round(K.clip(y_true * y_pred, 0, 1)))
    predicted_positives = K.sum(K.round(K.clip(y_pred, 0, 1)))
    precision = true_positives / (predicted_positives + K.epsilon())
    return precision

# %% [markdown]
# #### Recall
# Recall actually calculates how many of the Actual Positives our model capture through labeling it as Positive (True Positive). Applying the same understanding, we know that Recall shall be the model metric we use to select our best model when there is a high cost associated with False Negative.

# %% [markdown]
# ![recall](https://wikimedia.org/api/rest_v1/media/math/render/svg/4c233366865312bc99c832d1475e152c5074891b)

# %%
def recall(y_true, y_pred):
    '''Calculates the recall, a metric for multi-label classification of
    how many relevant items are selected.
    '''
    true_positives = K.sum(K.round(K.clip(y_true * y_pred, 0, 1)))
    possible_positives = K.sum(K.round(K.clip(y_true, 0, 1)))
    recall = true_positives / (possible_positives + K.epsilon())
    return recall

# %% [markdown]
# #### Accuracy

# %%
def accuracy(y_true, y_pred):
    '''Calculates the mean accuracy rate across all predictions for binary
    classification problems.
    '''
    return K.mean(K.equal(y_true, K.round(y_pred)))

# %%
epsilon = 1e-5
smooth = 1

def tversky(y_true, y_pred):
    y_true_pos = K.flatten(y_true)
    y_pred_pos = K.flatten(y_pred)
    true_pos = K.sum(y_true_pos * y_pred_pos)
    false_neg = K.sum(y_true_pos * (1-y_pred_pos))
    false_pos = K.sum((1-y_true_pos)*y_pred_pos)
    alpha = 0.7
    return (true_pos + smooth)/(true_pos + alpha*false_neg + (1-alpha)*false_pos + smooth)

def focal_tversky(y_true,y_pred):
    y_true = tf.cast(y_true, tf.float32)
    y_pred = tf.cast(y_pred, tf.float32)
    
    pt_1 = tversky(y_true, y_pred)
    gamma = 0.75
    return K.pow((1-pt_1), gamma)

def tversky_loss(y_true, y_pred):
    return 1 - tversky(y_true,y_pred)

# %% [markdown]
# ## Image Augmentation
# To build a powerful image classifier using very little training data, image augmentation is usually required to boost the performance of deep networks. Image augmentation artificially creates training images through different ways of processing or combination of multiple processing, such as random rotation, shifts, shear and flips, etc.

# %% [markdown]
# We are going to define to methods for augmentation, one for **random rotation** and one for **horizontal flipping**

# %%
def random_rotation(x_image, y_image):
    rows_x,cols_x, chl_x = x_image.shape
    rows_y,cols_y = y_image.shape
    rand_num = np.random.randint(-40,40)
    M1 = cv2.getRotationMatrix2D((cols_x/2,rows_x/2),rand_num,1)
    M2 = cv2.getRotationMatrix2D((cols_y/2,rows_y/2),rand_num,1)
    x_image = cv2.warpAffine(x_image,M1,(cols_x,rows_x))
    y_image = cv2.warpAffine(y_image.astype('float32'),M2,(cols_y,rows_y))
    return x_image, y_image.astype('int')

def horizontal_flip(x_image, y_image):
    x_image = cv2.flip(x_image, 1)
    y_image = cv2.flip(y_image.astype('float32'), 1)
    return x_image, y_image.astype('int')

# %%
def img_augmentation(x_train, y_train):
    x_rotat = []
    y_rotat = []
    x_flip = []
    y_flip = []
    for idx in range(len(x_train)):
        x,y = random_rotation(x_train[idx], y_train[idx])
        x_rotat.append(x)
        y_rotat.append(y)
        x,y = horizontal_flip(x_train[idx], y_train[idx])
        x_flip.append(x)
        y_flip.append(y)
    return np.array(x_rotat), np.array(y_rotat), np.array(x_flip), np.array(y_flip)

# %% [markdown]
# calling the functions for the training data.

# %%
x_rotated, y_rotated, x_flipped, y_flipped = img_augmentation(x_train, y_train)

# %% [markdown]
# Let us have a look at our transformations.

# %%
img_num = 7
plt.figure(figsize=(12,12))
plt.subplot(3,2,1)
plt.imshow(x_train[img_num])
plt.title('Original Image')
plt.subplot(3,2,2)
plt.imshow(y_train[img_num], plt.cm.binary_r)
plt.title('Original Mask')
plt.subplot(3,2,3)
plt.imshow(x_rotated[img_num])
plt.title('Rotated Image')
plt.subplot(3,2,4)
plt.imshow(y_rotated[img_num], plt.cm.binary_r)
plt.title('Rotated Mask')
plt.subplot(3,2,5)
plt.imshow(x_flipped[img_num])
plt.title('Flipped Image')
plt.subplot(3,2,6)
plt.imshow(y_flipped[img_num], plt.cm.binary_r)
plt.title('Flipped Mask')
plt.show()

# %% [markdown]
# Now we join all the augmentations image arrays to the original training arrays.

# %%
x_train_full = np.concatenate([x_train, x_rotated, x_flipped])
y_train_full = np.concatenate([y_train, y_rotated, y_flipped])

# %% [markdown]
# #### Making a Validation Set
# We will split our full training set into train and validation set.
# Validation dataset is used to validate the performance after each epoch.

# %%
x_train, x_val, y_train, y_val = train_test_split(x_train_full, y_train_full, test_size = 0.20, random_state = 101)

# %%
print("Length of the Training Set   : {}".format(len(x_train)))
print("Length of the Test Set       : {}".format(len(x_test)))
print("Length of the Validation Set : {}".format(len(x_val)))
# Out:
# Length of the Training Set   : 360
# Length of the Test Set       : 50
# Length of the Validation Set : 90

# %% [markdown]
# ## The Model

# %% [markdown]
# Defining the model in a function which takes two arguments when called
# * **epoch_num**: number of epochs to run
# * **savename**: the name of the model for saving after training

# %% [markdown]
# #### Optimizer and Learning Rate
# * We adopt adam optimization algorithm or adaptive moments, to adjust the learning rate.
# * It is well known that learning rate is one of the critical hyperparameters that have a signiﬁcant impact on classiﬁcation performance.
# * Advantages of Adam optimizer are:
#     - Relatively low memory requirements (though higher than gradient descent and gradient descent with momentum).
#     - Usually works well even with a little tuning of hyperparameter
# * Adam is fairly robust to the choice of hyperparameters, and set the learning rate **α** as 0.003 to speed up the training procedure in this study as advised in the paper [here](https://arxiv.org/pdf/1703.05165v2.pdf)

# %% [markdown]
# ### Model Function

# %% [markdown]
# > ![arch](https://raw.githubusercontent.com/hashbanger/Skin_Lesion_Segmentation/master/graphics/unet_arch.png)

# %%
# Number of image channels (for example 3 in case of RGB, or 1 for grayscale images)
INPUT_CHANNELS = 3
# Number of output masks (1 in case you predict only one type of objects)
OUTPUT_MASK_CHANNELS = 1
# Pretrained weights

# %%
def double_conv_layer(x, size, dropout=0.40, batch_norm=True):
    if K.image_dim_ordering() == 'th':
        axis = 1
    else:
        axis = 3
    conv = Conv2D(size, (3, 3), padding='same')(x)
    if batch_norm is True:
        conv = BatchNormalization(axis=axis)(conv)
    conv = Activation('relu')(conv)
    conv = Conv2D(size, (3, 3), padding='same')(conv)
    if batch_norm is True:
        conv = BatchNormalization(axis=axis)(conv)
    conv = Activation('relu')(conv)
    if dropout > 0:
        conv = SpatialDropout2D(dropout)(conv)
    return conv


def UNET_224(epochs_num, savename):
    dropout_val=0.50
    if K.image_dim_ordering() == 'th':
        inputs = Input((INPUT_CHANNELS, 224, 224))
        axis = 1
    else:
        inputs = Input((224, 224, INPUT_CHANNELS))
        axis = 3
    filters = 32

    conv_224 = double_conv_layer(inputs, filters)
    pool_112 = MaxPooling2D(pool_size=(2, 2))(conv_224)

    conv_112 = double_conv_layer(pool_112, 2*filters)
    pool_56 = MaxPooling2D(pool_size=(2, 2))(conv_112)

    conv_56 = double_conv_layer(pool_56, 4*filters)
    pool_28 = MaxPooling2D(pool_size=(2, 2))(conv_56)

    conv_28 = double_conv_layer(pool_28, 8*filters)
    pool_14 = MaxPooling2D(pool_size=(2, 2))(conv_28)

    conv_14 = double_conv_layer(pool_14, 16*filters)
    pool_7 = MaxPooling2D(pool_size=(2, 2))(conv_14)

    conv_7 = double_conv_layer(pool_7, 32*filters)

    up_14 = concatenate([UpSampling2D(size=(2, 2))(conv_7), conv_14], axis=axis)
    up_conv_14 = double_conv_layer(up_14, 16*filters)

    up_28 = concatenate([UpSampling2D(size=(2, 2))(up_conv_14), conv_28], axis=axis)
    up_conv_28 = double_conv_layer(up_28, 8*filters)

    up_56 = concatenate([UpSampling2D(size=(2, 2))(up_conv_28), conv_56], axis=axis)
    up_conv_56 = double_conv_layer(up_56, 4*filters)

    up_112 = concatenate([UpSampling2D(size=(2, 2))(up_conv_56), conv_112], axis=axis)
    up_conv_112 = double_conv_layer(up_112, 2*filters)

    up_224 = concatenate([UpSampling2D(size=(2, 2))(up_conv_112), conv_224], axis=axis)
    up_conv_224 = double_conv_layer(up_224, filters, dropout_val)

    conv_final = Conv2D(OUTPUT_MASK_CHANNELS, (1, 1))(up_conv_224)
    conv_final = Activation('sigmoid')(conv_final)
    pred = Reshape((224,224))(conv_final)
    model = Model(inputs, pred, name="UNET_224")
    model.compile(optimizer= Adam(lr = 0.003), loss= [jaccard_distance]
                  , metrics=[iou, dice_coe, precision, recall, accuracy,tversky])
    model.summary()
    hist = model.fit(x_train, y_train, epochs= epochs_num, batch_size= 18,validation_data=(x_val, y_val), verbose=1)
    model.save(savename)
    return model, hist

# %% [markdown]
# <font color='red'>**Problems In Guided Dropout Implementation**
#
# - The entire network architecture is implemented using Keras.
# - Now to implement the Guided Dropout Layer using Keras we have to know the detailed backend of the Keras Library because:
# - We should know in what form the inputs will be coming to our layer so we could manipulate them.
# - We should also know in what form the output should be given to the next layer.
# - If we implement Guided Dropout from scratch then we will have to implement entire architecture from scratch which will be neither efficient nor easily feasible.</font>

# %% [markdown]
# ### For 1 epoch

# %%
model, hist = UNET_224(1, 'unet_1_epoch.h5')
# Out:
# __________________________________________________________________________________________________
# Layer (type)                    Output Shape         Param #     Connected to
# ==================================================================================================
# input_6 (InputLayer)            (None, 224, 224, 3)  0
# __________________________________________________________________________________________________
# conv2d_116 (Conv2D)             (None, 224, 224, 32) 896         input_6[0][0]
# __________________________________________________________________________________________________
# batch_normalization_111 (BatchN (None, 224, 224, 32) 128         conv2d_116[0][0]
# __________________________________________________________________________________________________
# activation_116 (Activation)     (None, 224, 224, 32) 0           batch_normalization_111[0][0]
# __________________________________________________________________________________________________
# conv2d_117 (Conv2D)             (None, 224, 224, 32) 9248        activation_116[0][0]
# __________________________________________________________________________________________________
# batch_normalization_112 (BatchN (None, 224, 224, 32) 128         conv2d_117[0][0]
# __________________________________________________________________________________________________
# activation_117 (Activation)     (None, 224, 224, 32) 0           batch_normalization_112[0][0]
# __________________________________________________________________________________________________
# spatial_dropout2d_56 (SpatialDr (None, 224, 224, 32) 0           activation_117[0][0]
# __________________________________________________________________________________________________
# max_pooling2d_26 (MaxPooling2D) (None, 112, 112, 32) 0           spatial_dropout2d_56[0][0]
# __________________________________________________________________________________________________
# conv2d_118 (Conv2D)             (None, 112, 112, 64) 18496       max_pooling2d_26[0][0]
# __________________________________________________________________________________________________
# batch_normalization_113 (BatchN (None, 112, 112, 64) 256         conv2d_118[0][0]
# __________________________________________________________________________________________________
# activation_118 (Activation)     (None, 112, 112, 64) 0           batch_normalization_113[0][0]
# __________________________________________________________________________________________________
# conv2d_119 (Conv2D)             (None, 112, 112, 64) 36928       activation_118[0][0]
# __________________________________________________________________________________________________
# batch_normalization_114 (BatchN (None, 112, 112, 64) 256         conv2d_119[0][0]
# __________________________________________________________________________________________________
# activation_119 (Activation)     (None, 112, 112, 64) 0           batch_normalization_114[0][0]
# __________________________________________________________________________________________________
# spatial_dropout2d_57 (SpatialDr (None, 112, 112, 64) 0           activation_119[0][0]
# __________________________________________________________________________________________________
# max_pooling2d_27 (MaxPooling2D) (None, 56, 56, 64)   0           spatial_dropout2d_57[0][0]
# __________________________________________________________________________________________________
# conv2d_120 (Conv2D)             (None, 56, 56, 128)  73856       max_pooling2d_27[0][0]
# __________________________________________________________________________________________________
# batch_normalization_115 (BatchN (None, 56, 56, 128)  512         conv2d_120[0][0]
# __________________________________________________________________________________________________
# activation_120 (Activation)     (None, 56, 56, 128)  0           batch_normalization_115[0][0]
# __________________________________________________________________________________________________
# conv2d_121 (Conv2D)             (None, 56, 56, 128)  147584      activation_120[0][0]
# __________________________________________________________________________________________________
# batch_normalization_116 (BatchN (None, 56, 56, 128)  512         conv2d_121[0][0]
# __________________________________________________________________________________________________
# activation_121 (Activation)     (None, 56, 56, 128)  0           batch_normalization_116[0][0]
# __________________________________________________________________________________________________
# spatial_dropout2d_58 (SpatialDr (None, 56, 56, 128)  0           activation_121[0][0]
# __________________________________________________________________________________________________
# max_pooling2d_28 (MaxPooling2D) (None, 28, 28, 128)  0           spatial_dropout2d_58[0][0]
# __________________________________________________________________________________________________
# conv2d_122 (Conv2D)             (None, 28, 28, 256)  295168      max_pooling2d_28[0][0]
# __________________________________________________________________________________________________
# batch_normalization_117 (BatchN (None, 28, 28, 256)  1024        conv2d_122[0][0]
# __________________________________________________________________________________________________
# activation_122 (Activation)     (None, 28, 28, 256)  0           batch_normalization_117[0][0]
# __________________________________________________________________________________________________
# conv2d_123 (Conv2D)             (None, 28, 28, 256)  590080      activation_122[0][0]
# __________________________________________________________________________________________________
# batch_normalization_118 (BatchN (None, 28, 28, 256)  1024        conv2d_123[0][0]
# __________________________________________________________________________________________________
# activation_123 (Activation)     (None, 28, 28, 256)  0           batch_normalization_118[0][0]
# __________________________________________________________________________________________________
# spatial_dropout2d_59 (SpatialDr (None, 28, 28, 256)  0           activation_123[0][0]
# __________________________________________________________________________________________________
# max_pooling2d_29 (MaxPooling2D) (None, 14, 14, 256)  0           spatial_dropout2d_59[0][0]
# __________________________________________________________________________________________________
# conv2d_124 (Conv2D)             (None, 14, 14, 512)  1180160     max_pooling2d_29[0][0]
# __________________________________________________________________________________________________
# batch_normalization_119 (BatchN (None, 14, 14, 512)  2048        conv2d_124[0][0]
# __________________________________________________________________________________________________
# activation_124 (Activation)     (None, 14, 14, 512)  0           batch_normalization_119[0][0]
# __________________________________________________________________________________________________
# conv2d_125 (Conv2D)             (None, 14, 14, 512)  2359808     activation_124[0][0]
# __________________________________________________________________________________________________
# batch_normalization_120 (BatchN (None, 14, 14, 512)  2048        conv2d_125[0][0]
# __________________________________________________________________________________________________
# activation_125 (Activation)     (None, 14, 14, 512)  0           batch_normalization_120[0][0]
# __________________________________________________________________________________________________
# spatial_dropout2d_60 (SpatialDr (None, 14, 14, 512)  0           activation_125[0][0]
# __________________________________________________________________________________________________
# max_pooling2d_30 (MaxPooling2D) (None, 7, 7, 512)    0           spatial_dropout2d_60[0][0]
# __________________________________________________________________________________________________
# conv2d_126 (Conv2D)             (None, 7, 7, 1024)   4719616     max_pooling2d_30[0][0]
# __________________________________________________________________________________________________
# batch_normalization_121 (BatchN (None, 7, 7, 1024)   4096        conv2d_126[0][0]
# __________________________________________________________________________________________________
# activation_126 (Activation)     (None, 7, 7, 1024)   0           batch_normalization_121[0][0]
# __________________________________________________________________________________________________
# conv2d_127 (Conv2D)             (None, 7, 7, 1024)   9438208     activation_126[0][0]
# __________________________________________________________________________________________________
# batch_normalization_122 (BatchN (None, 7, 7, 1024)   4096        conv2d_127[0][0]
# __________________________________________________________________________________________________
# activation_127 (Activation)     (None, 7, 7, 1024)   0           batch_normalization_122[0][0]
# __________________________________________________________________________________________________
# spatial_dropout2d_61 (SpatialDr (None, 7, 7, 1024)   0           activation_127[0][0]
# __________________________________________________________________________________________________
# up_sampling2d_26 (UpSampling2D) (None, 14, 14, 1024) 0           spatial_dropout2d_61[0][0]
# __________________________________________________________________________________________________
# concatenate_26 (Concatenate)    (None, 14, 14, 1536) 0           up_sampling2d_26[0][0]
#                                                                  spatial_dropout2d_60[0][0]
# __________________________________________________________________________________________________
# conv2d_128 (Conv2D)             (None, 14, 14, 512)  7078400     concatenate_26[0][0]
# __________________________________________________________________________________________________
# batch_normalization_123 (BatchN (None, 14, 14, 512)  2048        conv2d_128[0][0]
# __________________________________________________________________________________________________
# activation_128 (Activation)     (None, 14, 14, 512)  0           batch_normalization_123[0][0]
# __________________________________________________________________________________________________
# conv2d_129 (Conv2D)             (None, 14, 14, 512)  2359808     activation_128[0][0]
# __________________________________________________________________________________________________
# batch_normalization_124 (BatchN (None, 14, 14, 512)  2048        conv2d_129[0][0]
# __________________________________________________________________________________________________
# activation_129 (Activation)     (None, 14, 14, 512)  0           batch_normalization_124[0][0]
# __________________________________________________________________________________________________
# spatial_dropout2d_62 (SpatialDr (None, 14, 14, 512)  0           activation_129[0][0]
# __________________________________________________________________________________________________
# up_sampling2d_27 (UpSampling2D) (None, 28, 28, 512)  0           spatial_dropout2d_62[0][0]
# __________________________________________________________________________________________________
# concatenate_27 (Concatenate)    (None, 28, 28, 768)  0           up_sampling2d_27[0][0]
#                                                                  spatial_dropout2d_59[0][0]
# __________________________________________________________________________________________________
# conv2d_130 (Conv2D)             (None, 28, 28, 256)  1769728     concatenate_27[0][0]
# __________________________________________________________________________________________________
# batch_normalization_125 (BatchN (None, 28, 28, 256)  1024        conv2d_130[0][0]
# __________________________________________________________________________________________________
# activation_130 (Activation)     (None, 28, 28, 256)  0           batch_normalization_125[0][0]
# __________________________________________________________________________________________________
# conv2d_131 (Conv2D)             (None, 28, 28, 256)  590080      activation_130[0][0]
# __________________________________________________________________________________________________
# batch_normalization_126 (BatchN (None, 28, 28, 256)  1024        conv2d_131[0][0]
# __________________________________________________________________________________________________
# activation_131 (Activation)     (None, 28, 28, 256)  0           batch_normalization_126[0][0]
# __________________________________________________________________________________________________
# spatial_dropout2d_63 (SpatialDr (None, 28, 28, 256)  0           activation_131[0][0]
# __________________________________________________________________________________________________
# up_sampling2d_28 (UpSampling2D) (None, 56, 56, 256)  0           spatial_dropout2d_63[0][0]
# __________________________________________________________________________________________________
# concatenate_28 (Concatenate)    (None, 56, 56, 384)  0           up_sampling2d_28[0][0]
#                                                                  spatial_dropout2d_58[0][0]
# __________________________________________________________________________________________________
# conv2d_132 (Conv2D)             (None, 56, 56, 128)  442496      concatenate_28[0][0]
# __________________________________________________________________________________________________
# batch_normalization_127 (BatchN (None, 56, 56, 128)  512         conv2d_132[0][0]
# __________________________________________________________________________________________________
# activation_132 (Activation)     (None, 56, 56, 128)  0           batch_normalization_127[0][0]
# __________________________________________________________________________________________________
# conv2d_133 (Conv2D)             (None, 56, 56, 128)  147584      activation_132[0][0]
# __________________________________________________________________________________________________
# batch_normalization_128 (BatchN (None, 56, 56, 128)  512         conv2d_133[0][0]
# __________________________________________________________________________________________________
# activation_133 (Activation)     (None, 56, 56, 128)  0           batch_normalization_128[0][0]
# __________________________________________________________________________________________________
# spatial_dropout2d_64 (SpatialDr (None, 56, 56, 128)  0           activation_133[0][0]
# __________________________________________________________________________________________________
# up_sampling2d_29 (UpSampling2D) (None, 112, 112, 128 0           spatial_dropout2d_64[0][0]
# __________________________________________________________________________________________________
# concatenate_29 (Concatenate)    (None, 112, 112, 192 0           up_sampling2d_29[0][0]
#                                                                  spatial_dropout2d_57[0][0]
# __________________________________________________________________________________________________
# conv2d_134 (Conv2D)             (None, 112, 112, 64) 110656      concatenate_29[0][0]
# __________________________________________________________________________________________________
# batch_normalization_129 (BatchN (None, 112, 112, 64) 256         conv2d_134[0][0]
# __________________________________________________________________________________________________
# activation_134 (Activation)     (None, 112, 112, 64) 0           batch_normalization_129[0][0]
# __________________________________________________________________________________________________
# conv2d_135 (Conv2D)             (None, 112, 112, 64) 36928       activation_134[0][0]
# __________________________________________________________________________________________________
# batch_normalization_130 (BatchN (None, 112, 112, 64) 256         conv2d_135[0][0]
# __________________________________________________________________________________________________
# activation_135 (Activation)     (None, 112, 112, 64) 0           batch_normalization_130[0][0]
# __________________________________________________________________________________________________
# spatial_dropout2d_65 (SpatialDr (None, 112, 112, 64) 0           activation_135[0][0]
# __________________________________________________________________________________________________
# up_sampling2d_30 (UpSampling2D) (None, 224, 224, 64) 0           spatial_dropout2d_65[0][0]
# __________________________________________________________________________________________________
# concatenate_30 (Concatenate)    (None, 224, 224, 96) 0           up_sampling2d_30[0][0]
#                                                                  spatial_dropout2d_56[0][0]
# __________________________________________________________________________________________________
# conv2d_136 (Conv2D)             (None, 224, 224, 32) 27680       concatenate_30[0][0]
# __________________________________________________________________________________________________
# batch_normalization_131 (BatchN (None, 224, 224, 32) 128         conv2d_136[0][0]
# __________________________________________________________________________________________________
# activation_136 (Activation)     (None, 224, 224, 32) 0           batch_normalization_131[0][0]
# __________________________________________________________________________________________________
# conv2d_137 (Conv2D)             (None, 224, 224, 32) 9248        activation_136[0][0]
# __________________________________________________________________________________________________
# batch_normalization_132 (BatchN (None, 224, 224, 32) 128         conv2d_137[0][0]
# __________________________________________________________________________________________________
# activation_137 (Activation)     (None, 224, 224, 32) 0           batch_normalization_132[0][0]
# __________________________________________________________________________________________________
# spatial_dropout2d_66 (SpatialDr (None, 224, 224, 32) 0           activation_137[0][0]
# __________________________________________________________________________________________________
# conv2d_138 (Conv2D)             (None, 224, 224, 1)  33          spatial_dropout2d_66[0][0]
# __________________________________________________________________________________________________
# activation_138 (Activation)     (None, 224, 224, 1)  0           conv2d_138[0][0]
# __________________________________________________________________________________________________
# reshape_6 (Reshape)             (None, 224, 224)     0           activation_138[0][0]
# ==================================================================================================
# Total params: 31,466,753
# Trainable params: 31,454,721
# Non-trainable params: 12,032
# __________________________________________________________________________________________________
# Train on 360 samples, validate on 90 samples
# Epoch 1/1
# 360/360 [==============================] - 16s 44ms/step - loss: 0.1716 - iou: 0.8284 - dice_coe: 0.5940 - precision: 0.7025 - recall: 0.6384 - accuracy: 0.7888 - tversky: 0.6030 - val_loss: 0.4749 - val_iou: 0.5251 - val_dice_coe: 0.4750 - val_precision: 0.3131 - val_recall: 1.0000 - val_accuracy: 0.3131 - val_tversky: 0.5999

# %% [markdown]
# ## Loading the Model

# %% [markdown]
# Here we can load a pretrained model

# %%
dropout_val=0.50
if K.image_dim_ordering() == 'th':
    inputs = Input((INPUT_CHANNELS, 224, 224))
    axis = 1
else:
    inputs = Input((224, 224, INPUT_CHANNELS))
    axis = 3
filters = 32

conv_224 = double_conv_layer(inputs, filters)
pool_112 = MaxPooling2D(pool_size=(2, 2))(conv_224)

conv_112 = double_conv_layer(pool_112, 2*filters)
pool_56 = MaxPooling2D(pool_size=(2, 2))(conv_112)

conv_56 = double_conv_layer(pool_56, 4*filters)
pool_28 = MaxPooling2D(pool_size=(2, 2))(conv_56)

conv_28 = double_conv_layer(pool_28, 8*filters)
pool_14 = MaxPooling2D(pool_size=(2, 2))(conv_28)

conv_14 = double_conv_layer(pool_14, 16*filters)
pool_7 = MaxPooling2D(pool_size=(2, 2))(conv_14)

conv_7 = double_conv_layer(pool_7, 32*filters)

up_14 = concatenate([UpSampling2D(size=(2, 2))(conv_7), conv_14], axis=axis)
up_conv_14 = double_conv_layer(up_14, 16*filters)

up_28 = concatenate([UpSampling2D(size=(2, 2))(up_conv_14), conv_28], axis=axis)
up_conv_28 = double_conv_layer(up_28, 8*filters)

up_56 = concatenate([UpSampling2D(size=(2, 2))(up_conv_28), conv_56], axis=axis)
up_conv_56 = double_conv_layer(up_56, 4*filters)

up_112 = concatenate([UpSampling2D(size=(2, 2))(up_conv_56), conv_112], axis=axis)
up_conv_112 = double_conv_layer(up_112, 2*filters)

up_224 = concatenate([UpSampling2D(size=(2, 2))(up_conv_112), conv_224], axis=axis)
up_conv_224 = double_conv_layer(up_224, filters, dropout_val)

conv_final = Conv2D(OUTPUT_MASK_CHANNELS, (1, 1))(up_conv_224)
conv_final = Activation('sigmoid')(conv_final)
pred = Reshape((224,224))(conv_final)

# %%
model_0 = Model(inputs, pred, name="UNET_224")
model_0.compile(optimizer= Adam(lr = 0.003), loss= [jaccard_distance]
                  , metrics=[iou, dice_coe, precision, recall, accuracy,tversky])

# %%
model_0.load_weights('unet_1_epoch.h5')

# %%
print('\n~~~~~~~~~~~~~~~Stats after 1 epoch~~~~~~~~~~~~~~~~~~~')
print('\n-------------On Train Set--------------------------\n')
res = model_0.evaluate(x_train, y_train, batch_size= 18)
print('________________________')
print('IOU:       |   {:.2f}  |'.format(res[1]*100))
print('Dice Coef: |   {:.2f}  |'.format(res[2]*100))
print('Precision: |   {:.2f}  |'.format(res[3]*100))
print('Recall:    |   {:.2f}  |'.format(res[4]*100))
print('Accuracy:  |   {:.2f}  |'.format(res[5]*100))
print('Tversky:   |   {:.2f}  |'.format(res[6]*100))
print("Loss:      |   {:.2f}  |".format(res[0]*100))
print('________________________')
print('\n-------------On Test  Set--------------------------\n')
res = model_0.evaluate(x_test, y_test, batch_size= 18)
print('________________________')
print('IOU:       |   {:.2f}  |'.format(res[1]*100))
print('Dice Coef: |   {:.2f}  |'.format(res[2]*100))
print('Precision: |   {:.2f}  |'.format(res[3]*100))
print('Recall:    |   {:.2f}  |'.format(res[4]*100))
print('Accuracy:  |   {:.2f}  |'.format(res[5]*100))
print('Tversky:   |   {:.2f}  |'.format(res[6]*100))
print("Loss:      |   {:.2f}  |".format(res[0]*100))
print('________________________')
print('\n-------------On validation Set---------------------\n')
res = model_0.evaluate(x_val, y_val, batch_size= 18)
print('________________________')
print('IOU:       |   {:.2f}  |'.format(res[1]*100))
print('Dice Coef: |   {:.2f}  |'.format(res[2]*100))
print('Precision: |   {:.2f}  |'.format(res[3]*100))
print('Recall:    |   {:.2f}  |'.format(res[4]*100))
print('Accuracy:  |   {:.2f}  |'.format(res[5]*100))
print('Tversky:   |   {:.2f}  |'.format(res[6]*100))
print("Loss:      |   {:.2f}  |".format(res[0]*100))
print('________________________')
# Out:
# ~~~~~~~~~~~~~~~Stats after 1 epoch~~~~~~~~~~~~~~~~~~~
#
# -------------On Train Set--------------------------
#
# 360/360 [==============================] - 4s 12ms/step
# ________________________
# IOU:       |   53.24  |
# Dice Coef: |   48.51  |
# Precision: |   32.37  |
# Recall:    |   100.00  |
# Accuracy:  |   32.37  |
# Tversky:   |   60.78  |
# Loss:      |   46.76  |
# ________________________
#
# -------------On Test  Set--------------------------
#
# 50/50 [==============================] - 0s 5ms/step
# ________________________
# IOU:       |   52.54  |
# Dice Coef: |   47.52  |
# Precision: |   31.35  |
# Recall:    |   100.00  |
# Accuracy:  |   31.35  |
# Tversky:   |   59.97  |
# Loss:      |   47.46  |
# ________________________
#
# -------------On validation Set---------------------
#
# 90/90 [==============================] - 0s 5ms/step
# ________________________
# IOU:       |   52.51  |
# Dice Coef: |   47.50  |
# Precision: |   31.31  |
# Recall:    |   100.00  |
# Accuracy:  |   31.31  |
# Tversky:   |   59.99  |
# Loss:      |   47.49  |
# ________________________

# %% [markdown]
# #### After 100 epochs

# %%
model, hist = UNET_224(epochs_num= 100, savename= 'unet_100_epoch.h5')
# Out:
# __________________________________________________________________________________________________
# Layer (type)                    Output Shape         Param #     Connected to
# ==================================================================================================
# input_8 (InputLayer)            (None, 224, 224, 3)  0
# __________________________________________________________________________________________________
# conv2d_162 (Conv2D)             (None, 224, 224, 32) 896         input_8[0][0]
# __________________________________________________________________________________________________
# batch_normalization_155 (BatchN (None, 224, 224, 32) 128         conv2d_162[0][0]
# __________________________________________________________________________________________________
# activation_162 (Activation)     (None, 224, 224, 32) 0           batch_normalization_155[0][0]
# __________________________________________________________________________________________________
# conv2d_163 (Conv2D)             (None, 224, 224, 32) 9248        activation_162[0][0]
# __________________________________________________________________________________________________
# batch_normalization_156 (BatchN (None, 224, 224, 32) 128         conv2d_163[0][0]
# __________________________________________________________________________________________________
# activation_163 (Activation)     (None, 224, 224, 32) 0           batch_normalization_156[0][0]
# __________________________________________________________________________________________________
# spatial_dropout2d_78 (SpatialDr (None, 224, 224, 32) 0           activation_163[0][0]
# __________________________________________________________________________________________________
# max_pooling2d_36 (MaxPooling2D) (None, 112, 112, 32) 0           spatial_dropout2d_78[0][0]
# __________________________________________________________________________________________________
# conv2d_164 (Conv2D)             (None, 112, 112, 64) 18496       max_pooling2d_36[0][0]
# __________________________________________________________________________________________________
# batch_normalization_157 (BatchN (None, 112, 112, 64) 256         conv2d_164[0][0]
# __________________________________________________________________________________________________
# activation_164 (Activation)     (None, 112, 112, 64) 0           batch_normalization_157[0][0]
# __________________________________________________________________________________________________
# conv2d_165 (Conv2D)             (None, 112, 112, 64) 36928       activation_164[0][0]
# __________________________________________________________________________________________________
# batch_normalization_158 (BatchN (None, 112, 112, 64) 256         conv2d_165[0][0]
# __________________________________________________________________________________________________
# activation_165 (Activation)     (None, 112, 112, 64) 0           batch_normalization_158[0][0]
# __________________________________________________________________________________________________
# spatial_dropout2d_79 (SpatialDr (None, 112, 112, 64) 0           activation_165[0][0]
# __________________________________________________________________________________________________
# max_pooling2d_37 (MaxPooling2D) (None, 56, 56, 64)   0           spatial_dropout2d_79[0][0]
# __________________________________________________________________________________________________
# conv2d_166 (Conv2D)             (None, 56, 56, 128)  73856       max_pooling2d_37[0][0]
# __________________________________________________________________________________________________
# batch_normalization_159 (BatchN (None, 56, 56, 128)  512         conv2d_166[0][0]
# __________________________________________________________________________________________________
# activation_166 (Activation)     (None, 56, 56, 128)  0           batch_normalization_159[0][0]
# __________________________________________________________________________________________________
# conv2d_167 (Conv2D)             (None, 56, 56, 128)  147584      activation_166[0][0]
# __________________________________________________________________________________________________
# batch_normalization_160 (BatchN (None, 56, 56, 128)  512         conv2d_167[0][0]
# __________________________________________________________________________________________________
# activation_167 (Activation)     (None, 56, 56, 128)  0           batch_normalization_160[0][0]
# __________________________________________________________________________________________________
# spatial_dropout2d_80 (SpatialDr (None, 56, 56, 128)  0           activation_167[0][0]
# __________________________________________________________________________________________________
# max_pooling2d_38 (MaxPooling2D) (None, 28, 28, 128)  0           spatial_dropout2d_80[0][0]
# __________________________________________________________________________________________________
# conv2d_168 (Conv2D)             (None, 28, 28, 256)  295168      max_pooling2d_38[0][0]
# __________________________________________________________________________________________________
# batch_normalization_161 (BatchN (None, 28, 28, 256)  1024        conv2d_168[0][0]
# __________________________________________________________________________________________________
# activation_168 (Activation)     (None, 28, 28, 256)  0           batch_normalization_161[0][0]
# __________________________________________________________________________________________________
# conv2d_169 (Conv2D)             (None, 28, 28, 256)  590080      activation_168[0][0]
# __________________________________________________________________________________________________
# batch_normalization_162 (BatchN (None, 28, 28, 256)  1024        conv2d_169[0][0]
# __________________________________________________________________________________________________
# activation_169 (Activation)     (None, 28, 28, 256)  0           batch_normalization_162[0][0]
# __________________________________________________________________________________________________
# spatial_dropout2d_81 (SpatialDr (None, 28, 28, 256)  0           activation_169[0][0]
# __________________________________________________________________________________________________
# max_pooling2d_39 (MaxPooling2D) (None, 14, 14, 256)  0           spatial_dropout2d_81[0][0]
# __________________________________________________________________________________________________
# conv2d_170 (Conv2D)             (None, 14, 14, 512)  1180160     max_pooling2d_39[0][0]
# __________________________________________________________________________________________________
# batch_normalization_163 (BatchN (None, 14, 14, 512)  2048        conv2d_170[0][0]
# __________________________________________________________________________________________________
# activation_170 (Activation)     (None, 14, 14, 512)  0           batch_normalization_163[0][0]
# __________________________________________________________________________________________________
# conv2d_171 (Conv2D)             (None, 14, 14, 512)  2359808     activation_170[0][0]
# __________________________________________________________________________________________________
# batch_normalization_164 (BatchN (None, 14, 14, 512)  2048        conv2d_171[0][0]
# __________________________________________________________________________________________________
# activation_171 (Activation)     (None, 14, 14, 512)  0           batch_normalization_164[0][0]
# __________________________________________________________________________________________________
# spatial_dropout2d_82 (SpatialDr (None, 14, 14, 512)  0           activation_171[0][0]
# __________________________________________________________________________________________________
# max_pooling2d_40 (MaxPooling2D) (None, 7, 7, 512)    0           spatial_dropout2d_82[0][0]
# __________________________________________________________________________________________________
# conv2d_172 (Conv2D)             (None, 7, 7, 1024)   4719616     max_pooling2d_40[0][0]
# __________________________________________________________________________________________________
# batch_normalization_165 (BatchN (None, 7, 7, 1024)   4096        conv2d_172[0][0]
# __________________________________________________________________________________________________
# activation_172 (Activation)     (None, 7, 7, 1024)   0           batch_normalization_165[0][0]
# __________________________________________________________________________________________________
# conv2d_173 (Conv2D)             (None, 7, 7, 1024)   9438208     activation_172[0][0]
# __________________________________________________________________________________________________
# batch_normalization_166 (BatchN (None, 7, 7, 1024)   4096        conv2d_173[0][0]
# __________________________________________________________________________________________________
# activation_173 (Activation)     (None, 7, 7, 1024)   0           batch_normalization_166[0][0]
# __________________________________________________________________________________________________
# spatial_dropout2d_83 (SpatialDr (None, 7, 7, 1024)   0           activation_173[0][0]
# __________________________________________________________________________________________________
# up_sampling2d_36 (UpSampling2D) (None, 14, 14, 1024) 0           spatial_dropout2d_83[0][0]
# __________________________________________________________________________________________________
# concatenate_36 (Concatenate)    (None, 14, 14, 1536) 0           up_sampling2d_36[0][0]
#                                                                  spatial_dropout2d_82[0][0]
# __________________________________________________________________________________________________
# conv2d_174 (Conv2D)             (None, 14, 14, 512)  7078400     concatenate_36[0][0]
# __________________________________________________________________________________________________
# batch_normalization_167 (BatchN (None, 14, 14, 512)  2048        conv2d_174[0][0]
# __________________________________________________________________________________________________
# activation_174 (Activation)     (None, 14, 14, 512)  0           batch_normalization_167[0][0]
# __________________________________________________________________________________________________
# conv2d_175 (Conv2D)             (None, 14, 14, 512)  2359808     activation_174[0][0]
# __________________________________________________________________________________________________
# batch_normalization_168 (BatchN (None, 14, 14, 512)  2048        conv2d_175[0][0]
# __________________________________________________________________________________________________
# activation_175 (Activation)     (None, 14, 14, 512)  0           batch_normalization_168[0][0]
# __________________________________________________________________________________________________
# spatial_dropout2d_84 (SpatialDr (None, 14, 14, 512)  0           activation_175[0][0]
# __________________________________________________________________________________________________
# up_sampling2d_37 (UpSampling2D) (None, 28, 28, 512)  0           spatial_dropout2d_84[0][0]
# __________________________________________________________________________________________________
# concatenate_37 (Concatenate)    (None, 28, 28, 768)  0           up_sampling2d_37[0][0]
#                                                                  spatial_dropout2d_81[0][0]
# __________________________________________________________________________________________________
# conv2d_176 (Conv2D)             (None, 28, 28, 256)  1769728     concatenate_37[0][0]
# __________________________________________________________________________________________________
# batch_normalization_169 (BatchN (None, 28, 28, 256)  1024        conv2d_176[0][0]
# __________________________________________________________________________________________________
# activation_176 (Activation)     (None, 28, 28, 256)  0           batch_normalization_169[0][0]
# __________________________________________________________________________________________________
# conv2d_177 (Conv2D)             (None, 28, 28, 256)  590080      activation_176[0][0]
# __________________________________________________________________________________________________
# batch_normalization_170 (BatchN (None, 28, 28, 256)  1024        conv2d_177[0][0]
# __________________________________________________________________________________________________
# activation_177 (Activation)     (None, 28, 28, 256)  0           batch_normalization_170[0][0]
# __________________________________________________________________________________________________
# spatial_dropout2d_85 (SpatialDr (None, 28, 28, 256)  0           activation_177[0][0]
# __________________________________________________________________________________________________
# up_sampling2d_38 (UpSampling2D) (None, 56, 56, 256)  0           spatial_dropout2d_85[0][0]
# __________________________________________________________________________________________________
# concatenate_38 (Concatenate)    (None, 56, 56, 384)  0           up_sampling2d_38[0][0]
#                                                                  spatial_dropout2d_80[0][0]
# __________________________________________________________________________________________________
# conv2d_178 (Conv2D)             (None, 56, 56, 128)  442496      concatenate_38[0][0]
# __________________________________________________________________________________________________
# batch_normalization_171 (BatchN (None, 56, 56, 128)  512         conv2d_178[0][0]
# __________________________________________________________________________________________________
# activation_178 (Activation)     (None, 56, 56, 128)  0           batch_normalization_171[0][0]
# __________________________________________________________________________________________________
# conv2d_179 (Conv2D)             (None, 56, 56, 128)  147584      activation_178[0][0]
# __________________________________________________________________________________________________
# batch_normalization_172 (BatchN (None, 56, 56, 128)  512         conv2d_179[0][0]
# __________________________________________________________________________________________________
# activation_179 (Activation)     (None, 56, 56, 128)  0           batch_normalization_172[0][0]
# __________________________________________________________________________________________________
# spatial_dropout2d_86 (SpatialDr (None, 56, 56, 128)  0           activation_179[0][0]
# __________________________________________________________________________________________________
# up_sampling2d_39 (UpSampling2D) (None, 112, 112, 128 0           spatial_dropout2d_86[0][0]
# __________________________________________________________________________________________________
# concatenate_39 (Concatenate)    (None, 112, 112, 192 0           up_sampling2d_39[0][0]
#                                                                  spatial_dropout2d_79[0][0]
# __________________________________________________________________________________________________
# conv2d_180 (Conv2D)             (None, 112, 112, 64) 110656      concatenate_39[0][0]
# __________________________________________________________________________________________________
# batch_normalization_173 (BatchN (None, 112, 112, 64) 256         conv2d_180[0][0]
# __________________________________________________________________________________________________
# activation_180 (Activation)     (None, 112, 112, 64) 0           batch_normalization_173[0][0]
# __________________________________________________________________________________________________
# conv2d_181 (Conv2D)             (None, 112, 112, 64) 36928       activation_180[0][0]
# __________________________________________________________________________________________________
# batch_normalization_174 (BatchN (None, 112, 112, 64) 256         conv2d_181[0][0]
# __________________________________________________________________________________________________
# activation_181 (Activation)     (None, 112, 112, 64) 0           batch_normalization_174[0][0]
# __________________________________________________________________________________________________
# spatial_dropout2d_87 (SpatialDr (None, 112, 112, 64) 0           activation_181[0][0]
# __________________________________________________________________________________________________
# up_sampling2d_40 (UpSampling2D) (None, 224, 224, 64) 0           spatial_dropout2d_87[0][0]
# __________________________________________________________________________________________________
# concatenate_40 (Concatenate)    (None, 224, 224, 96) 0           up_sampling2d_40[0][0]
#                                                                  spatial_dropout2d_78[0][0]
# __________________________________________________________________________________________________
# conv2d_182 (Conv2D)             (None, 224, 224, 32) 27680       concatenate_40[0][0]
# __________________________________________________________________________________________________
# batch_normalization_175 (BatchN (None, 224, 224, 32) 128         conv2d_182[0][0]
# __________________________________________________________________________________________________
# activation_182 (Activation)     (None, 224, 224, 32) 0           batch_normalization_175[0][0]
# __________________________________________________________________________________________________
# conv2d_183 (Conv2D)             (None, 224, 224, 32) 9248        activation_182[0][0]
# __________________________________________________________________________________________________
# batch_normalization_176 (BatchN (None, 224, 224, 32) 128         conv2d_183[0][0]
# __________________________________________________________________________________________________
# activation_183 (Activation)     (None, 224, 224, 32) 0           batch_normalization_176[0][0]
# __________________________________________________________________________________________________
# spatial_dropout2d_88 (SpatialDr (None, 224, 224, 32) 0           activation_183[0][0]
# __________________________________________________________________________________________________
# conv2d_184 (Conv2D)             (None, 224, 224, 1)  33          spatial_dropout2d_88[0][0]
# __________________________________________________________________________________________________
# activation_184 (Activation)     (None, 224, 224, 1)  0           conv2d_184[0][0]
# __________________________________________________________________________________________________
# reshape_8 (Reshape)             (None, 224, 224)     0           activation_184[0][0]
# ==================================================================================================
# Total params: 31,466,753
# Trainable params: 31,454,721
# Non-trainable params: 12,032
# __________________________________________________________________________________________________
# Train on 360 samples, validate on 90 samples
# Epoch 1/100
# 360/360 [==============================] - 18s 50ms/step - loss: 0.2221 - iou: 0.7779 - dice_coe: 0.5636 - precision: 0.6477 - recall: 0.7519 - accuracy: 0.7472 - tversky: 0.6213 - val_loss: 0.4409 - val_iou: 0.5591 - val_dice_coe: 0.4715 - val_precision: 0.3239 - val_recall: 0.8856 - val_accuracy: 0.3805 - val_tversky: 0.5817
# Epoch 2/100
# 360/360 [==============================] - 6s 16ms/step - loss: 0.1408 - iou: 0.8592 - dice_coe: 0.6573 - precision: 0.8336 - recall: 0.7447 - accuracy: 0.8665 - tversky: 0.6989 - val_loss: 0.4670 - val_iou: 0.5330 - val_dice_coe: 0.4800 - val_precision: 0.3176 - val_recall: 1.0000 - val_accuracy: 0.3279 - val_tversky: 0.6047
# Epoch 3/100
# 360/360 [==============================] - 6s 16ms/step - loss: 0.1202 - iou: 0.8798 - dice_coe: 0.6957 - precision: 0.8610 - recall: 0.7728 - accuracy: 0.8802 - tversky: 0.7250 - val_loss: 0.4269 - val_iou: 0.5731 - val_dice_coe: 0.5088 - val_precision: 0.3474 - val_recall: 0.9925 - val_accuracy: 0.4119 - val_tversky: 0.6305
# Epoch 4/100
# 360/360 [==============================] - 6s 16ms/step - loss: 0.1002 - iou: 0.8998 - dice_coe: 0.7422 - precision: 0.8788 - recall: 0.7982 - accuracy: 0.8974 - tversky: 0.7655 - val_loss: 0.3275 - val_iou: 0.6725 - val_dice_coe: 0.5671 - val_precision: 0.4201 - val_recall: 0.9209 - val_accuracy: 0.5758 - val_tversky: 0.6692
# Epoch 5/100
# 360/360 [==============================] - 6s 16ms/step - loss: 0.0910 - iou: 0.9090 - dice_coe: 0.7637 - precision: 0.8957 - recall: 0.7997 - accuracy: 0.9023 - tversky: 0.7771 - val_loss: 0.3429 - val_iou: 0.6571 - val_dice_coe: 0.5668 - val_precision: 0.4087 - val_recall: 0.9655 - val_accuracy: 0.5533 - val_tversky: 0.6778
# Epoch 6/100
# 360/360 [==============================] - 6s 16ms/step - loss: 0.0936 - iou: 0.9064 - dice_coe: 0.7688 - precision: 0.8744 - recall: 0.7976 - accuracy: 0.8945 - tversky: 0.7827 - val_loss: 0.2317 - val_iou: 0.7683 - val_dice_coe: 0.6491 - val_precision: 0.5245 - val_recall: 0.8989 - val_accuracy: 0.7137 - val_tversky: 0.7300
# Epoch 7/100
# 360/360 [==============================] - 6s 16ms/step - loss: 0.0848 - iou: 0.9152 - dice_coe: 0.7877 - precision: 0.8863 - recall: 0.8108 - accuracy: 0.9025 - tversky: 0.7969 - val_loss: 0.2083 - val_iou: 0.7917 - val_dice_coe: 0.6712 - val_precision: 0.5651 - val_recall: 0.8829 - val_accuracy: 0.7422 - val_tversky: 0.7406
# Epoch 8/100
# 360/360 [==============================] - 6s 16ms/step - loss: 0.0887 - iou: 0.9113 - dice_coe: 0.7848 - precision: 0.8868 - recall: 0.8018 - accuracy: 0.9011 - tversky: 0.7902 - val_loss: 0.1329 - val_iou: 0.8671 - val_dice_coe: 0.7205 - val_precision: 0.8252 - val_recall: 0.6716 - val_accuracy: 0.8517 - val_tversky: 0.7084
# Epoch 9/100
# 360/360 [==============================] - 6s 16ms/step - loss: 0.0837 - iou: 0.9163 - dice_coe: 0.7970 - precision: 0.8806 - recall: 0.8285 - accuracy: 0.9061 - tversky: 0.8032 - val_loss: 0.1773 - val_iou: 0.8227 - val_dice_coe: 0.6988 - val_precision: 0.6229 - val_recall: 0.8436 - val_accuracy: 0.7825 - val_tversky: 0.7486
# Epoch 10/100
# 360/360 [==============================] - 6s 16ms/step - loss: 0.0833 - iou: 0.9167 - dice_coe: 0.7941 - precision: 0.8969 - recall: 0.8067 - accuracy: 0.9066 - tversky: 0.7964 - val_loss: 0.1981 - val_iou: 0.8019 - val_dice_coe: 0.6963 - val_precision: 0.5604 - val_recall: 0.9778 - val_accuracy: 0.7540 - val_tversky: 0.7849
# Epoch 11/100
# 360/360 [==============================] - 6s 16ms/step - loss: 0.0845 - iou: 0.9155 - dice_coe: 0.8012 - precision: 0.8552 - recall: 0.8535 - accuracy: 0.9046 - tversky: 0.8139 - val_loss: 0.1182 - val_iou: 0.8818 - val_dice_coe: 0.7908 - val_precision: 0.7335 - val_recall: 0.9023 - val_accuracy: 0.8635 - val_tversky: 0.8293
# Epoch 12/100
# 360/360 [==============================] - 6s 16ms/step - loss: 0.0847 - iou: 0.9153 - dice_coe: 0.7952 - precision: 0.8893 - recall: 0.8140 - accuracy: 0.9038 - tversky: 0.7964 - val_loss: 0.1597 - val_iou: 0.8403 - val_dice_coe: 0.7380 - val_precision: 0.6254 - val_recall: 0.9490 - val_accuracy: 0.8052 - val_tversky: 0.8062
# Epoch 13/100
# 360/360 [==============================] - 6s 16ms/step - loss: 0.0837 - iou: 0.9163 - dice_coe: 0.7995 - precision: 0.8875 - recall: 0.8188 - accuracy: 0.9054 - tversky: 0.7990 - val_loss: 0.0793 - val_iou: 0.9207 - val_dice_coe: 0.8347 - val_precision: 0.8620 - val_recall: 0.8627 - val_accuracy: 0.9127 - val_tversky: 0.8411
# Epoch 14/100
# 360/360 [==============================] - 6s 16ms/step - loss: 0.0794 - iou: 0.9206 - dice_coe: 0.8080 - precision: 0.8951 - recall: 0.8292 - accuracy: 0.9120 - tversky: 0.8100 - val_loss: 0.2322 - val_iou: 0.7678 - val_dice_coe: 0.6699 - val_precision: 0.5144 - val_recall: 0.9686 - val_accuracy: 0.7014 - val_tversky: 0.7614
# Epoch 15/100
# 360/360 [==============================] - 6s 16ms/step - loss: 0.0726 - iou: 0.9274 - dice_coe: 0.8250 - precision: 0.9067 - recall: 0.8408 - accuracy: 0.9192 - tversky: 0.8249 - val_loss: 0.1109 - val_iou: 0.8891 - val_dice_coe: 0.8004 - val_precision: 0.7633 - val_recall: 0.8787 - val_accuracy: 0.8772 - val_tversky: 0.8272
# Epoch 16/100
# 360/360 [==============================] - 6s 16ms/step - loss: 0.0824 - iou: 0.9176 - dice_coe: 0.8080 - precision: 0.8743 - recall: 0.8362 - accuracy: 0.9062 - tversky: 0.8121 - val_loss: 0.1459 - val_iou: 0.8541 - val_dice_coe: 0.7484 - val_precision: 0.6660 - val_recall: 0.8928 - val_accuracy: 0.8251 - val_tversky: 0.7963
# Epoch 17/100
# 360/360 [==============================] - 6s 16ms/step - loss: 0.0790 - iou: 0.9210 - dice_coe: 0.8117 - precision: 0.8896 - recall: 0.8371 - accuracy: 0.9116 - tversky: 0.8155 - val_loss: 0.0993 - val_iou: 0.9007 - val_dice_coe: 0.7828 - val_precision: 0.8989 - val_recall: 0.7267 - val_accuracy: 0.8893 - val_tversky: 0.7529
# Epoch 18/100
# 360/360 [==============================] - 6s 16ms/step - loss: 0.0814 - iou: 0.9186 - dice_coe: 0.8088 - precision: 0.8905 - recall: 0.8211 - accuracy: 0.9063 - tversky: 0.8109 - val_loss: 0.0990 - val_iou: 0.9010 - val_dice_coe: 0.7839 - val_precision: 0.8546 - val_recall: 0.7621 - val_accuracy: 0.8833 - val_tversky: 0.7740
# Epoch 19/100
# 360/360 [==============================] - 6s 16ms/step - loss: 0.0760 - iou: 0.9240 - dice_coe: 0.8143 - precision: 0.8951 - recall: 0.8349 - accuracy: 0.9125 - tversky: 0.8141 - val_loss: 0.1008 - val_iou: 0.8992 - val_dice_coe: 0.7666 - val_precision: 0.9557 - val_recall: 0.6497 - val_accuracy: 0.8801 - val_tversky: 0.7176
# Epoch 20/100
# 360/360 [==============================] - 6s 16ms/step - loss: 0.0748 - iou: 0.9252 - dice_coe: 0.8202 - precision: 0.8859 - recall: 0.8503 - accuracy: 0.9149 - tversky: 0.8223 - val_loss: 0.0904 - val_iou: 0.9096 - val_dice_coe: 0.8044 - val_precision: 0.9682 - val_recall: 0.6985 - val_accuracy: 0.8968 - val_tversky: 0.7589
# Epoch 21/100
# 360/360 [==============================] - 6s 16ms/step - loss: 0.0738 - iou: 0.9262 - dice_coe: 0.8263 - precision: 0.9093 - recall: 0.8319 - accuracy: 0.9156 - tversky: 0.8239 - val_loss: 0.0786 - val_iou: 0.9214 - val_dice_coe: 0.8553 - val_precision: 0.8130 - val_recall: 0.9236 - val_accuracy: 0.9086 - val_tversky: 0.8764
# Epoch 22/100
# 360/360 [==============================] - 6s 16ms/step - loss: 0.0846 - iou: 0.9154 - dice_coe: 0.8034 - precision: 0.8869 - recall: 0.8167 - accuracy: 0.9030 - tversky: 0.8043 - val_loss: 0.0916 - val_iou: 0.9084 - val_dice_coe: 0.7788 - val_precision: 0.9742 - val_recall: 0.6827 - val_accuracy: 0.8938 - val_tversky: 0.7281
# Epoch 23/100
# 360/360 [==============================] - 6s 16ms/step - loss: 0.0843 - iou: 0.9157 - dice_coe: 0.8071 - precision: 0.8769 - recall: 0.8160 - accuracy: 0.9010 - tversky: 0.8064 - val_loss: 0.0833 - val_iou: 0.9167 - val_dice_coe: 0.8334 - val_precision: 0.8406 - val_recall: 0.8659 - val_accuracy: 0.9055 - val_tversky: 0.8391
# Epoch 24/100
# 360/360 [==============================] - 6s 16ms/step - loss: 0.0740 - iou: 0.9260 - dice_coe: 0.8228 - precision: 0.8942 - recall: 0.8467 - accuracy: 0.9161 - tversky: 0.8245 - val_loss: 0.0710 - val_iou: 0.9290 - val_dice_coe: 0.8394 - val_precision: 0.9233 - val_recall: 0.8160 - val_accuracy: 0.9203 - val_tversky: 0.8205
# Epoch 25/100
# 360/360 [==============================] - 6s 16ms/step - loss: 0.0718 - iou: 0.9282 - dice_coe: 0.8324 - precision: 0.8969 - recall: 0.8551 - accuracy: 0.9197 - tversky: 0.8315 - val_loss: 0.0714 - val_iou: 0.9286 - val_dice_coe: 0.8460 - val_precision: 0.9331 - val_recall: 0.8090 - val_accuracy: 0.9205 - val_tversky: 0.8263
# Epoch 26/100
# 360/360 [==============================] - 6s 16ms/step - loss: 0.0695 - iou: 0.9305 - dice_coe: 0.8381 - precision: 0.9062 - recall: 0.8534 - accuracy: 0.9219 - tversky: 0.8379 - val_loss: 0.0656 - val_iou: 0.9344 - val_dice_coe: 0.8652 - val_precision: 0.9530 - val_recall: 0.8122 - val_accuracy: 0.9274 - val_tversky: 0.8402
# Epoch 27/100
# 360/360 [==============================] - 6s 16ms/step - loss: 0.0739 - iou: 0.9261 - dice_coe: 0.8230 - precision: 0.9142 - recall: 0.8151 - accuracy: 0.9146 - tversky: 0.8164 - val_loss: 0.0663 - val_iou: 0.9337 - val_dice_coe: 0.8658 - val_precision: 0.8924 - val_recall: 0.8729 - val_accuracy: 0.9262 - val_tversky: 0.8648
# Epoch 28/100
# 360/360 [==============================] - 6s 16ms/step - loss: 0.0714 - iou: 0.9286 - dice_coe: 0.8370 - precision: 0.8927 - recall: 0.8555 - accuracy: 0.9193 - tversky: 0.8375 - val_loss: 0.0760 - val_iou: 0.9240 - val_dice_coe: 0.8475 - val_precision: 0.9624 - val_recall: 0.7648 - val_accuracy: 0.9155 - val_tversky: 0.8126
# Epoch 29/100
# 360/360 [==============================] - 6s 16ms/step - loss: 0.0692 - iou: 0.9308 - dice_coe: 0.8355 - precision: 0.9237 - recall: 0.8350 - accuracy: 0.9219 - tversky: 0.8279 - val_loss: 0.0707 - val_iou: 0.9293 - val_dice_coe: 0.8440 - val_precision: 0.9669 - val_recall: 0.7708 - val_accuracy: 0.9189 - val_tversky: 0.8082
# Epoch 30/100
# 360/360 [==============================] - 6s 16ms/step - loss: 0.0647 - iou: 0.9353 - dice_coe: 0.8473 - precision: 0.9066 - recall: 0.8685 - accuracy: 0.9267 - tversky: 0.8488 - val_loss: 0.0554 - val_iou: 0.9446 - val_dice_coe: 0.8796 - val_precision: 0.9404 - val_recall: 0.8586 - val_accuracy: 0.9378 - val_tversky: 0.8649
# Epoch 31/100
# 360/360 [==============================] - 6s 16ms/step - loss: 0.0681 - iou: 0.9319 - dice_coe: 0.8379 - precision: 0.9014 - recall: 0.8607 - accuracy: 0.9227 - tversky: 0.8386 - val_loss: 0.0550 - val_iou: 0.9450 - val_dice_coe: 0.8693 - val_precision: 0.9454 - val_recall: 0.8602 - val_accuracy: 0.9397 - val_tversky: 0.8559
# Epoch 32/100
# 360/360 [==============================] - 6s 16ms/step - loss: 0.0702 - iou: 0.9298 - dice_coe: 0.8355 - precision: 0.9215 - recall: 0.8276 - accuracy: 0.9194 - tversky: 0.8275 - val_loss: 0.0713 - val_iou: 0.9287 - val_dice_coe: 0.8526 - val_precision: 0.9523 - val_recall: 0.7959 - val_accuracy: 0.9212 - val_tversky: 0.8242
# Epoch 33/100
# 360/360 [==============================] - 6s 16ms/step - loss: 0.0694 - iou: 0.9306 - dice_coe: 0.8396 - precision: 0.9185 - recall: 0.8405 - accuracy: 0.9222 - tversky: 0.8361 - val_loss: 0.0659 - val_iou: 0.9341 - val_dice_coe: 0.8611 - val_precision: 0.9397 - val_recall: 0.8205 - val_accuracy: 0.9263 - val_tversky: 0.8429
# Epoch 34/100
# 360/360 [==============================] - 6s 16ms/step - loss: 0.0656 - iou: 0.9344 - dice_coe: 0.8440 - precision: 0.9330 - recall: 0.8418 - accuracy: 0.9274 - tversky: 0.8396 - val_loss: 0.0524 - val_iou: 0.9476 - val_dice_coe: 0.8885 - val_precision: 0.9225 - val_recall: 0.8859 - val_accuracy: 0.9395 - val_tversky: 0.8852
# Epoch 35/100
# 360/360 [==============================] - 6s 16ms/step - loss: 0.0655 - iou: 0.9345 - dice_coe: 0.8468 - precision: 0.9047 - recall: 0.8661 - accuracy: 0.9264 - tversky: 0.8500 - val_loss: 0.0643 - val_iou: 0.9357 - val_dice_coe: 0.8786 - val_precision: 0.8758 - val_recall: 0.9066 - val_accuracy: 0.9290 - val_tversky: 0.8886
# Epoch 36/100
# 360/360 [==============================] - 6s 16ms/step - loss: 0.0654 - iou: 0.9346 - dice_coe: 0.8480 - precision: 0.9086 - recall: 0.8632 - accuracy: 0.9259 - tversky: 0.8499 - val_loss: 0.0730 - val_iou: 0.9270 - val_dice_coe: 0.8566 - val_precision: 0.8415 - val_recall: 0.9104 - val_accuracy: 0.9174 - val_tversky: 0.8749
# Epoch 37/100
# 360/360 [==============================] - 6s 16ms/step - loss: 0.0665 - iou: 0.9335 - dice_coe: 0.8494 - precision: 0.9103 - recall: 0.8574 - accuracy: 0.9237 - tversky: 0.8468 - val_loss: 0.0588 - val_iou: 0.9412 - val_dice_coe: 0.8821 - val_precision: 0.9097 - val_recall: 0.8791 - val_accuracy: 0.9335 - val_tversky: 0.8784
# Epoch 38/100
# 360/360 [==============================] - 6s 16ms/step - loss: 0.0647 - iou: 0.9353 - dice_coe: 0.8478 - precision: 0.9204 - recall: 0.8458 - accuracy: 0.9245 - tversky: 0.8431 - val_loss: 0.0648 - val_iou: 0.9352 - val_dice_coe: 0.8720 - val_precision: 0.9051 - val_recall: 0.8665 - val_accuracy: 0.9274 - val_tversky: 0.8683
# Epoch 39/100
# 360/360 [==============================] - 6s 16ms/step - loss: 0.0648 - iou: 0.9352 - dice_coe: 0.8433 - precision: 0.9113 - recall: 0.8558 - accuracy: 0.9247 - tversky: 0.8434 - val_loss: 0.1113 - val_iou: 0.8887 - val_dice_coe: 0.8085 - val_precision: 0.7368 - val_recall: 0.9200 - val_accuracy: 0.8701 - val_tversky: 0.8458
# Epoch 40/100
# 360/360 [==============================] - 6s 16ms/step - loss: 0.0635 - iou: 0.9365 - dice_coe: 0.8495 - precision: 0.9141 - recall: 0.8683 - accuracy: 0.9293 - tversky: 0.8502 - val_loss: 0.0878 - val_iou: 0.9122 - val_dice_coe: 0.8268 - val_precision: 0.9082 - val_recall: 0.7650 - val_accuracy: 0.9005 - val_tversky: 0.8008
# Epoch 41/100
# 360/360 [==============================] - 6s 16ms/step - loss: 0.0614 - iou: 0.9386 - dice_coe: 0.8580 - precision: 0.9149 - recall: 0.8729 - accuracy: 0.9315 - tversky: 0.8584 - val_loss: 0.0575 - val_iou: 0.9425 - val_dice_coe: 0.8829 - val_precision: 0.9014 - val_recall: 0.8883 - val_accuracy: 0.9327 - val_tversky: 0.8844
# Epoch 42/100
# 360/360 [==============================] - 6s 16ms/step - loss: 0.0648 - iou: 0.9352 - dice_coe: 0.8515 - precision: 0.9127 - recall: 0.8628 - accuracy: 0.9266 - tversky: 0.8504 - val_loss: 0.0831 - val_iou: 0.9169 - val_dice_coe: 0.8075 - val_precision: 0.9749 - val_recall: 0.7108 - val_accuracy: 0.9022 - val_tversky: 0.7631
# Epoch 43/100
# 360/360 [==============================] - 6s 16ms/step - loss: 0.0629 - iou: 0.9371 - dice_coe: 0.8520 - precision: 0.9157 - recall: 0.8631 - accuracy: 0.9286 - tversky: 0.8487 - val_loss: 0.0994 - val_iou: 0.9006 - val_dice_coe: 0.7951 - val_precision: 0.9865 - val_recall: 0.6690 - val_accuracy: 0.8922 - val_tversky: 0.7396
# Epoch 44/100
# 360/360 [==============================] - 6s 16ms/step - loss: 0.0584 - iou: 0.9416 - dice_coe: 0.8659 - precision: 0.9229 - recall: 0.8714 - accuracy: 0.9335 - tversky: 0.8631 - val_loss: 0.0646 - val_iou: 0.9354 - val_dice_coe: 0.8668 - val_precision: 0.9688 - val_recall: 0.7953 - val_accuracy: 0.9264 - val_tversky: 0.8354
# Epoch 45/100
# 360/360 [==============================] - 6s 16ms/step - loss: 0.0614 - iou: 0.9386 - dice_coe: 0.8563 - precision: 0.9213 - recall: 0.8679 - accuracy: 0.9312 - tversky: 0.8552 - val_loss: 0.0534 - val_iou: 0.9466 - val_dice_coe: 0.8922 - val_precision: 0.9099 - val_recall: 0.8964 - val_accuracy: 0.9390 - val_tversky: 0.8916
# Epoch 46/100
# 360/360 [==============================] - 6s 16ms/step - loss: 0.0630 - iou: 0.9370 - dice_coe: 0.8490 - precision: 0.9222 - recall: 0.8489 - accuracy: 0.9279 - tversky: 0.8431 - val_loss: 0.0850 - val_iou: 0.9150 - val_dice_coe: 0.8139 - val_precision: 0.9847 - val_recall: 0.7050 - val_accuracy: 0.9024 - val_tversky: 0.7638
# Epoch 47/100
# 360/360 [==============================] - 6s 16ms/step - loss: 0.0642 - iou: 0.9358 - dice_coe: 0.8519 - precision: 0.9112 - recall: 0.8609 - accuracy: 0.9259 - tversky: 0.8503 - val_loss: 0.0656 - val_iou: 0.9344 - val_dice_coe: 0.8758 - val_precision: 0.8349 - val_recall: 0.9389 - val_accuracy: 0.9218 - val_tversky: 0.8976
# Epoch 48/100
# 360/360 [==============================] - 6s 16ms/step - loss: 0.0657 - iou: 0.9343 - dice_coe: 0.8468 - precision: 0.9053 - recall: 0.8715 - accuracy: 0.9263 - tversky: 0.8502 - val_loss: 0.0609 - val_iou: 0.9391 - val_dice_coe: 0.8667 - val_precision: 0.9710 - val_recall: 0.7987 - val_accuracy: 0.9273 - val_tversky: 0.8371
# Epoch 49/100
# 360/360 [==============================] - 6s 16ms/step - loss: 0.0543 - iou: 0.9457 - dice_coe: 0.8709 - precision: 0.9354 - recall: 0.8708 - accuracy: 0.9383 - tversky: 0.8665 - val_loss: 0.0593 - val_iou: 0.9407 - val_dice_coe: 0.8730 - val_precision: 0.9670 - val_recall: 0.8144 - val_accuracy: 0.9312 - val_tversky: 0.8473
# Epoch 50/100
# 360/360 [==============================] - 6s 16ms/step - loss: 0.0660 - iou: 0.9340 - dice_coe: 0.8485 - precision: 0.9083 - recall: 0.8586 - accuracy: 0.9237 - tversky: 0.8477 - val_loss: 0.0491 - val_iou: 0.9509 - val_dice_coe: 0.8898 - val_precision: 0.9694 - val_recall: 0.8449 - val_accuracy: 0.9413 - val_tversky: 0.8684
# Epoch 51/100
# 360/360 [==============================] - 6s 16ms/step - loss: 0.0557 - iou: 0.9443 - dice_coe: 0.8707 - precision: 0.9236 - recall: 0.8892 - accuracy: 0.9390 - tversky: 0.8720 - val_loss: 0.0606 - val_iou: 0.9394 - val_dice_coe: 0.8641 - val_precision: 0.9655 - val_recall: 0.8042 - val_accuracy: 0.9282 - val_tversky: 0.8380
# Epoch 52/100
# 360/360 [==============================] - 6s 16ms/step - loss: 0.0600 - iou: 0.9400 - dice_coe: 0.8600 - precision: 0.9122 - recall: 0.8736 - accuracy: 0.9302 - tversky: 0.8600 - val_loss: 0.0512 - val_iou: 0.9488 - val_dice_coe: 0.8861 - val_precision: 0.9369 - val_recall: 0.8800 - val_accuracy: 0.9421 - val_tversky: 0.8771
# Epoch 53/100
# 360/360 [==============================] - 6s 16ms/step - loss: 0.0634 - iou: 0.9366 - dice_coe: 0.8548 - precision: 0.9200 - recall: 0.8591 - accuracy: 0.9279 - tversky: 0.8509 - val_loss: 0.0441 - val_iou: 0.9559 - val_dice_coe: 0.8950 - val_precision: 0.9306 - val_recall: 0.9073 - val_accuracy: 0.9496 - val_tversky: 0.8909
# Epoch 54/100
# 360/360 [==============================] - 6s 16ms/step - loss: 0.0607 - iou: 0.9393 - dice_coe: 0.8621 - precision: 0.9174 - recall: 0.8799 - accuracy: 0.9331 - tversky: 0.8632 - val_loss: 0.0500 - val_iou: 0.9500 - val_dice_coe: 0.8844 - val_precision: 0.9532 - val_recall: 0.8546 - val_accuracy: 0.9400 - val_tversky: 0.8705
# Epoch 55/100
# 360/360 [==============================] - 6s 16ms/step - loss: 0.0555 - iou: 0.9445 - dice_coe: 0.8686 - precision: 0.9402 - recall: 0.8638 - accuracy: 0.9373 - tversky: 0.8629 - val_loss: 0.0651 - val_iou: 0.9349 - val_dice_coe: 0.8710 - val_precision: 0.8434 - val_recall: 0.9347 - val_accuracy: 0.9251 - val_tversky: 0.8913
# Epoch 56/100
# 360/360 [==============================] - 6s 16ms/step - loss: 0.0552 - iou: 0.9448 - dice_coe: 0.8704 - precision: 0.9195 - recall: 0.8875 - accuracy: 0.9377 - tversky: 0.8704 - val_loss: 0.0534 - val_iou: 0.9466 - val_dice_coe: 0.8833 - val_precision: 0.9640 - val_recall: 0.8404 - val_accuracy: 0.9385 - val_tversky: 0.8633
# Epoch 57/100
# 360/360 [==============================] - 6s 16ms/step - loss: 0.0600 - iou: 0.9400 - dice_coe: 0.8637 - precision: 0.9065 - recall: 0.8754 - accuracy: 0.9298 - tversky: 0.8637 - val_loss: 0.0474 - val_iou: 0.9526 - val_dice_coe: 0.8944 - val_precision: 0.9557 - val_recall: 0.8685 - val_accuracy: 0.9450 - val_tversky: 0.8815
# Epoch 58/100
# 360/360 [==============================] - 6s 16ms/step - loss: 0.0533 - iou: 0.9467 - dice_coe: 0.8747 - precision: 0.9343 - recall: 0.8813 - accuracy: 0.9409 - tversky: 0.8730 - val_loss: 0.0489 - val_iou: 0.9511 - val_dice_coe: 0.8966 - val_precision: 0.9359 - val_recall: 0.8874 - val_accuracy: 0.9446 - val_tversky: 0.8894
# Epoch 59/100
# 360/360 [==============================] - 6s 16ms/step - loss: 0.0575 - iou: 0.9425 - dice_coe: 0.8657 - precision: 0.9158 - recall: 0.8824 - accuracy: 0.9349 - tversky: 0.8658 - val_loss: 0.0636 - val_iou: 0.9364 - val_dice_coe: 0.8789 - val_precision: 0.8382 - val_recall: 0.9493 - val_accuracy: 0.9256 - val_tversky: 0.9020
# Epoch 60/100
# 360/360 [==============================] - 6s 16ms/step - loss: 0.0588 - iou: 0.9412 - dice_coe: 0.8654 - precision: 0.9140 - recall: 0.8801 - accuracy: 0.9319 - tversky: 0.8655 - val_loss: 0.0524 - val_iou: 0.9476 - val_dice_coe: 0.8871 - val_precision: 0.9651 - val_recall: 0.8496 - val_accuracy: 0.9417 - val_tversky: 0.8686
# Epoch 61/100
# 360/360 [==============================] - 6s 16ms/step - loss: 0.0586 - iou: 0.9414 - dice_coe: 0.8615 - precision: 0.9273 - recall: 0.8683 - accuracy: 0.9326 - tversky: 0.8600 - val_loss: 0.0641 - val_iou: 0.9359 - val_dice_coe: 0.8788 - val_precision: 0.8240 - val_recall: 0.9592 - val_accuracy: 0.9224 - val_tversky: 0.9070
# Epoch 62/100
# 360/360 [==============================] - 6s 16ms/step - loss: 0.0550 - iou: 0.9450 - dice_coe: 0.8726 - precision: 0.9229 - recall: 0.8834 - accuracy: 0.9381 - tversky: 0.8709 - val_loss: 0.0529 - val_iou: 0.9471 - val_dice_coe: 0.8836 - val_precision: 0.9188 - val_recall: 0.8821 - val_accuracy: 0.9373 - val_tversky: 0.8785
# Epoch 63/100
# 360/360 [==============================] - 6s 16ms/step - loss: 0.0563 - iou: 0.9437 - dice_coe: 0.8696 - precision: 0.9169 - recall: 0.8838 - accuracy: 0.9366 - tversky: 0.8698 - val_loss: 0.0447 - val_iou: 0.9553 - val_dice_coe: 0.9073 - val_precision: 0.9085 - val_recall: 0.9267 - val_accuracy: 0.9475 - val_tversky: 0.9126
# Epoch 64/100
# 360/360 [==============================] - 6s 16ms/step - loss: 0.0579 - iou: 0.9421 - dice_coe: 0.8609 - precision: 0.9390 - recall: 0.8512 - accuracy: 0.9329 - tversky: 0.8531 - val_loss: 0.0558 - val_iou: 0.9442 - val_dice_coe: 0.8704 - val_precision: 0.9642 - val_recall: 0.8145 - val_accuracy: 0.9312 - val_tversky: 0.8451
# Epoch 65/100
# 360/360 [==============================] - 6s 16ms/step - loss: 0.0571 - iou: 0.9429 - dice_coe: 0.8678 - precision: 0.9243 - recall: 0.8775 - accuracy: 0.9349 - tversky: 0.8664 - val_loss: 0.0587 - val_iou: 0.9413 - val_dice_coe: 0.8806 - val_precision: 0.9186 - val_recall: 0.8713 - val_accuracy: 0.9342 - val_tversky: 0.8757
# Epoch 66/100
# 360/360 [==============================] - 6s 16ms/step - loss: 0.0610 - iou: 0.9390 - dice_coe: 0.8584 - precision: 0.9176 - recall: 0.8694 - accuracy: 0.9308 - tversky: 0.8586 - val_loss: 0.0613 - val_iou: 0.9387 - val_dice_coe: 0.8755 - val_precision: 0.9782 - val_recall: 0.8058 - val_accuracy: 0.9314 - val_tversky: 0.8460
# Epoch 67/100
# 360/360 [==============================] - 6s 16ms/step - loss: 0.0556 - iou: 0.9444 - dice_coe: 0.8718 - precision: 0.9255 - recall: 0.8849 - accuracy: 0.9380 - tversky: 0.8715 - val_loss: 0.0536 - val_iou: 0.9464 - val_dice_coe: 0.8925 - val_precision: 0.8723 - val_recall: 0.9377 - val_accuracy: 0.9366 - val_tversky: 0.9083
# Epoch 68/100
# 360/360 [==============================] - 6s 16ms/step - loss: 0.0553 - iou: 0.9447 - dice_coe: 0.8748 - precision: 0.9237 - recall: 0.8777 - accuracy: 0.9357 - tversky: 0.8721 - val_loss: 0.0594 - val_iou: 0.9406 - val_dice_coe: 0.8691 - val_precision: 0.9714 - val_recall: 0.8055 - val_accuracy: 0.9300 - val_tversky: 0.8402
# Epoch 69/100
# 360/360 [==============================] - 6s 16ms/step - loss: 0.0539 - iou: 0.9461 - dice_coe: 0.8761 - precision: 0.9313 - recall: 0.8820 - accuracy: 0.9397 - tversky: 0.8739 - val_loss: 0.0609 - val_iou: 0.9391 - val_dice_coe: 0.8695 - val_precision: 0.9131 - val_recall: 0.8716 - val_accuracy: 0.9329 - val_tversky: 0.8670
# Epoch 70/100
# 360/360 [==============================] - 6s 16ms/step - loss: 0.0528 - iou: 0.9472 - dice_coe: 0.8751 - precision: 0.9288 - recall: 0.8900 - accuracy: 0.9405 - tversky: 0.8748 - val_loss: 0.0531 - val_iou: 0.9469 - val_dice_coe: 0.8823 - val_precision: 0.9565 - val_recall: 0.8397 - val_accuracy: 0.9365 - val_tversky: 0.8623
# Epoch 71/100
# 360/360 [==============================] - 6s 16ms/step - loss: 0.0533 - iou: 0.9467 - dice_coe: 0.8773 - precision: 0.9366 - recall: 0.8861 - accuracy: 0.9407 - tversky: 0.8736 - val_loss: 0.0518 - val_iou: 0.9482 - val_dice_coe: 0.8840 - val_precision: 0.9567 - val_recall: 0.8591 - val_accuracy: 0.9421 - val_tversky: 0.8689
# Epoch 72/100
# 360/360 [==============================] - 6s 16ms/step - loss: 0.0492 - iou: 0.9508 - dice_coe: 0.8850 - precision: 0.9253 - recall: 0.9042 - accuracy: 0.9447 - tversky: 0.8858 - val_loss: 0.0569 - val_iou: 0.9431 - val_dice_coe: 0.8801 - val_precision: 0.9168 - val_recall: 0.8772 - val_accuracy: 0.9355 - val_tversky: 0.8753
# Epoch 73/100
# 360/360 [==============================] - 6s 16ms/step - loss: 0.0487 - iou: 0.9513 - dice_coe: 0.8872 - precision: 0.9289 - recall: 0.9001 - accuracy: 0.9447 - tversky: 0.8871 - val_loss: 0.0431 - val_iou: 0.9569 - val_dice_coe: 0.9028 - val_precision: 0.9484 - val_recall: 0.8840 - val_accuracy: 0.9474 - val_tversky: 0.8938
# Epoch 74/100
# 360/360 [==============================] - 6s 16ms/step - loss: 0.0526 - iou: 0.9474 - dice_coe: 0.8771 - precision: 0.9360 - recall: 0.8835 - accuracy: 0.9414 - tversky: 0.8745 - val_loss: 0.0358 - val_iou: 0.9642 - val_dice_coe: 0.9139 - val_precision: 0.9504 - val_recall: 0.9125 - val_accuracy: 0.9571 - val_tversky: 0.9078
# Epoch 75/100
# 360/360 [==============================] - 6s 16ms/step - loss: 0.0492 - iou: 0.9508 - dice_coe: 0.8888 - precision: 0.9281 - recall: 0.8989 - accuracy: 0.9443 - tversky: 0.8885 - val_loss: 0.0586 - val_iou: 0.9414 - val_dice_coe: 0.8817 - val_precision: 0.8897 - val_recall: 0.9064 - val_accuracy: 0.9339 - val_tversky: 0.8880
# Epoch 76/100
# 360/360 [==============================] - 6s 16ms/step - loss: 0.0516 - iou: 0.9484 - dice_coe: 0.8805 - precision: 0.9261 - recall: 0.8984 - accuracy: 0.9424 - tversky: 0.8810 - val_loss: 0.0600 - val_iou: 0.9400 - val_dice_coe: 0.8713 - val_precision: 0.9173 - val_recall: 0.8654 - val_accuracy: 0.9316 - val_tversky: 0.8634
# Epoch 77/100
# 360/360 [==============================] - 6s 16ms/step - loss: 0.0482 - iou: 0.9518 - dice_coe: 0.8890 - precision: 0.9367 - recall: 0.8961 - accuracy: 0.9456 - tversky: 0.8870 - val_loss: 0.0659 - val_iou: 0.9341 - val_dice_coe: 0.8600 - val_precision: 0.9557 - val_recall: 0.8033 - val_accuracy: 0.9252 - val_tversky: 0.8355
# Epoch 78/100
# 360/360 [==============================] - 6s 16ms/step - loss: 0.0544 - iou: 0.9456 - dice_coe: 0.8754 - precision: 0.9167 - recall: 0.8929 - accuracy: 0.9377 - tversky: 0.8758 - val_loss: 0.0375 - val_iou: 0.9625 - val_dice_coe: 0.9181 - val_precision: 0.9401 - val_recall: 0.9232 - val_accuracy: 0.9570 - val_tversky: 0.9169
# Epoch 79/100
# 360/360 [==============================] - 6s 16ms/step - loss: 0.0529 - iou: 0.9471 - dice_coe: 0.8778 - precision: 0.9279 - recall: 0.8820 - accuracy: 0.9387 - tversky: 0.8755 - val_loss: 0.0582 - val_iou: 0.9418 - val_dice_coe: 0.8733 - val_precision: 0.9586 - val_recall: 0.8164 - val_accuracy: 0.9304 - val_tversky: 0.8489
# Epoch 80/100
# 360/360 [==============================] - 6s 16ms/step - loss: 0.0488 - iou: 0.9512 - dice_coe: 0.8872 - precision: 0.9402 - recall: 0.8903 - accuracy: 0.9448 - tversky: 0.8850 - val_loss: 0.0471 - val_iou: 0.9529 - val_dice_coe: 0.8987 - val_precision: 0.9695 - val_recall: 0.8533 - val_accuracy: 0.9446 - val_tversky: 0.8779
# Epoch 81/100
# 360/360 [==============================] - 6s 16ms/step - loss: 0.0495 - iou: 0.9505 - dice_coe: 0.8901 - precision: 0.9202 - recall: 0.9050 - accuracy: 0.9439 - tversky: 0.8928 - val_loss: 0.0488 - val_iou: 0.9512 - val_dice_coe: 0.8994 - val_precision: 0.9325 - val_recall: 0.8967 - val_accuracy: 0.9452 - val_tversky: 0.8976
# Epoch 82/100
# 360/360 [==============================] - 6s 16ms/step - loss: 0.0527 - iou: 0.9473 - dice_coe: 0.8772 - precision: 0.9302 - recall: 0.8852 - accuracy: 0.9402 - tversky: 0.8742 - val_loss: 0.0507 - val_iou: 0.9493 - val_dice_coe: 0.8952 - val_precision: 0.9025 - val_recall: 0.9191 - val_accuracy: 0.9423 - val_tversky: 0.9006
# Epoch 83/100
# 360/360 [==============================] - 6s 16ms/step - loss: 0.0477 - iou: 0.9523 - dice_coe: 0.8882 - precision: 0.9351 - recall: 0.8984 - accuracy: 0.9466 - tversky: 0.8850 - val_loss: 0.0554 - val_iou: 0.9446 - val_dice_coe: 0.8764 - val_precision: 0.9677 - val_recall: 0.8203 - val_accuracy: 0.9335 - val_tversky: 0.8516
# Epoch 84/100
# 360/360 [==============================] - 6s 16ms/step - loss: 0.0553 - iou: 0.9447 - dice_coe: 0.8759 - precision: 0.9187 - recall: 0.8889 - accuracy: 0.9380 - tversky: 0.8750 - val_loss: 0.0812 - val_iou: 0.9188 - val_dice_coe: 0.8286 - val_precision: 0.9824 - val_recall: 0.7243 - val_accuracy: 0.9083 - val_tversky: 0.7817
# Epoch 85/100
# 360/360 [==============================] - 6s 16ms/step - loss: 0.0578 - iou: 0.9422 - dice_coe: 0.8676 - precision: 0.9382 - recall: 0.8580 - accuracy: 0.9335 - tversky: 0.8607 - val_loss: 0.0932 - val_iou: 0.9068 - val_dice_coe: 0.8089 - val_precision: 0.9851 - val_recall: 0.6885 - val_accuracy: 0.8975 - val_tversky: 0.7567
# Epoch 86/100
# 360/360 [==============================] - 6s 16ms/step - loss: 0.0549 - iou: 0.9451 - dice_coe: 0.8777 - precision: 0.9260 - recall: 0.8851 - accuracy: 0.9378 - tversky: 0.8780 - val_loss: 0.0485 - val_iou: 0.9515 - val_dice_coe: 0.9016 - val_precision: 0.9570 - val_recall: 0.8684 - val_accuracy: 0.9449 - val_tversky: 0.8874
# Epoch 87/100
# 360/360 [==============================] - 6s 16ms/step - loss: 0.0476 - iou: 0.9524 - dice_coe: 0.8900 - precision: 0.9418 - recall: 0.8903 - accuracy: 0.9462 - tversky: 0.8872 - val_loss: 0.0678 - val_iou: 0.9322 - val_dice_coe: 0.8581 - val_precision: 0.9776 - val_recall: 0.7675 - val_accuracy: 0.9202 - val_tversky: 0.8220
# Epoch 88/100
# 360/360 [==============================] - 6s 16ms/step - loss: 0.0494 - iou: 0.9506 - dice_coe: 0.8900 - precision: 0.9271 - recall: 0.9012 - accuracy: 0.9440 - tversky: 0.8905 - val_loss: 0.0629 - val_iou: 0.9371 - val_dice_coe: 0.8611 - val_precision: 0.9731 - val_recall: 0.7827 - val_accuracy: 0.9230 - val_tversky: 0.8307
# Epoch 89/100
# 360/360 [==============================] - 6s 16ms/step - loss: 0.0441 - iou: 0.9559 - dice_coe: 0.8976 - precision: 0.9451 - recall: 0.9011 - accuracy: 0.9511 - tversky: 0.8943 - val_loss: 0.0375 - val_iou: 0.9625 - val_dice_coe: 0.9136 - val_precision: 0.9536 - val_recall: 0.9075 - val_accuracy: 0.9562 - val_tversky: 0.9066
# Epoch 90/100
# 360/360 [==============================] - 6s 16ms/step - loss: 0.0467 - iou: 0.9533 - dice_coe: 0.8936 - precision: 0.9425 - recall: 0.8938 - accuracy: 0.9471 - tversky: 0.8894 - val_loss: 0.0649 - val_iou: 0.9351 - val_dice_coe: 0.8449 - val_precision: 0.9904 - val_recall: 0.7532 - val_accuracy: 0.9191 - val_tversky: 0.8042
# Epoch 91/100
# 360/360 [==============================] - 6s 16ms/step - loss: 0.0494 - iou: 0.9506 - dice_coe: 0.8883 - precision: 0.9272 - recall: 0.9028 - accuracy: 0.9436 - tversky: 0.8897 - val_loss: 0.0530 - val_iou: 0.9470 - val_dice_coe: 0.8821 - val_precision: 0.9763 - val_recall: 0.8176 - val_accuracy: 0.9347 - val_tversky: 0.8568
# Epoch 92/100
# 360/360 [==============================] - 6s 16ms/step - loss: 0.0421 - iou: 0.9579 - dice_coe: 0.9030 - precision: 0.9489 - recall: 0.9070 - accuracy: 0.9534 - tversky: 0.9006 - val_loss: 0.0440 - val_iou: 0.9560 - val_dice_coe: 0.8957 - val_precision: 0.9363 - val_recall: 0.8964 - val_accuracy: 0.9467 - val_tversky: 0.8921
# Epoch 93/100
# 360/360 [==============================] - 6s 16ms/step - loss: 0.0451 - iou: 0.9549 - dice_coe: 0.8966 - precision: 0.9309 - recall: 0.9127 - accuracy: 0.9489 - tversky: 0.8976 - val_loss: 0.0406 - val_iou: 0.9594 - val_dice_coe: 0.9055 - val_precision: 0.9145 - val_recall: 0.9353 - val_accuracy: 0.9510 - val_tversky: 0.9125
# Epoch 94/100
# 360/360 [==============================] - 6s 16ms/step - loss: 0.0472 - iou: 0.9528 - dice_coe: 0.8882 - precision: 0.9297 - recall: 0.9029 - accuracy: 0.9463 - tversky: 0.8879 - val_loss: 0.0430 - val_iou: 0.9570 - val_dice_coe: 0.9012 - val_precision: 0.9650 - val_recall: 0.8667 - val_accuracy: 0.9470 - val_tversky: 0.8860
# Epoch 95/100
# 360/360 [==============================] - 6s 16ms/step - loss: 0.0483 - iou: 0.9517 - dice_coe: 0.8923 - precision: 0.9299 - recall: 0.9059 - accuracy: 0.9465 - tversky: 0.8922 - val_loss: 0.0605 - val_iou: 0.9395 - val_dice_coe: 0.8626 - val_precision: 0.9839 - val_recall: 0.7776 - val_accuracy: 0.9248 - val_tversky: 0.8285
# Epoch 96/100
# 360/360 [==============================] - 6s 16ms/step - loss: 0.0442 - iou: 0.9558 - dice_coe: 0.8970 - precision: 0.9459 - recall: 0.9019 - accuracy: 0.9502 - tversky: 0.8939 - val_loss: 0.0428 - val_iou: 0.9572 - val_dice_coe: 0.8994 - val_precision: 0.9532 - val_recall: 0.8828 - val_accuracy: 0.9484 - val_tversky: 0.8896
# Epoch 97/100
# 360/360 [==============================] - 6s 16ms/step - loss: 0.0490 - iou: 0.9510 - dice_coe: 0.8876 - precision: 0.9347 - recall: 0.8919 - accuracy: 0.9441 - tversky: 0.8836 - val_loss: 0.0522 - val_iou: 0.9478 - val_dice_coe: 0.8857 - val_precision: 0.8991 - val_recall: 0.9176 - val_accuracy: 0.9399 - val_tversky: 0.8932
# Epoch 98/100
# 360/360 [==============================] - 6s 16ms/step - loss: 0.0499 - iou: 0.9501 - dice_coe: 0.8873 - precision: 0.9311 - recall: 0.8993 - accuracy: 0.9437 - tversky: 0.8871 - val_loss: 0.0388 - val_iou: 0.9612 - val_dice_coe: 0.9130 - val_precision: 0.9146 - val_recall: 0.9441 - val_accuracy: 0.9550 - val_tversky: 0.9218
# Epoch 99/100
# 360/360 [==============================] - 6s 16ms/step - loss: 0.0479 - iou: 0.9521 - dice_coe: 0.8863 - precision: 0.9407 - recall: 0.8927 - accuracy: 0.9460 - tversky: 0.8844 - val_loss: 0.0383 - val_iou: 0.9617 - val_dice_coe: 0.9136 - val_precision: 0.9489 - val_recall: 0.9076 - val_accuracy: 0.9551 - val_tversky: 0.9086
# Epoch 100/100
# 360/360 [==============================] - 6s 16ms/step - loss: 0.0438 - iou: 0.9562 - dice_coe: 0.9009 - precision: 0.9372 - recall: 0.9150 - accuracy: 0.9518 - tversky: 0.9015 - val_loss: 0.0436 - val_iou: 0.9564 - val_dice_coe: 0.9013 - val_precision: 0.9537 - val_recall: 0.8750 - val_accuracy: 0.9466 - val_tversky: 0.8879

# %%
model_1 = Model(inputs, pred, name="UNET_224")
model_1.compile(optimizer= Adam(lr = 0.003), loss= [jaccard_distance]
                  , metrics=[iou, dice_coe, precision, recall, accuracy,tversky])

# %%
model_1.load_weights('unet_100_epoch.h5')

# %% [markdown]
# ![](http://)Testing the statistics after 100 epochs

# %%
print('\n~~~~~~~~~~~~~~~Stats after 100 epoch~~~~~~~~~~~~~~~~~~~')
print('\n-------------On Train Set--------------------------\n')
res = model_1.evaluate(x_train, y_train, batch_size= 18)
print('________________________')
print('IOU:       |   {:.2f}  |'.format(res[1]*100))
print('Dice Coef: |   {:.2f}  |'.format(res[2]*100))
print('Precision: |   {:.2f}  |'.format(res[3]*100))
print('Recall:    |   {:.2f}  |'.format(res[4]*100))
print('Accuracy:  |   {:.2f}  |'.format(res[5]*100))
print('Tversky:   |   {:.2f}  |'.format(res[6]*100))
print("Loss:      |   {:.2f}  |".format(res[0]*100))
print('________________________')
print('\n-------------On Test  Set--------------------------\n')
res = model_1.evaluate(x_test, y_test, batch_size= 18)
print('________________________')
print('IOU:       |   {:.2f}  |'.format(res[1]*100))
print('Dice Coef: |   {:.2f}  |'.format(res[2]*100))
print('Precision: |   {:.2f}  |'.format(res[3]*100))
print('Recall:    |   {:.2f}  |'.format(res[4]*100))
print('Accuracy:  |   {:.2f}  |'.format(res[5]*100))
print('Tversky:   |   {:.2f}  |'.format(res[6]*100))
print("Loss:      |   {:.2f}  |".format(res[0]*100))
print('________________________')
print('\n-------------On validation Set---------------------\n')
res = model_1.evaluate(x_val, y_val, batch_size= 18)
print('________________________')
print('IOU:       |   {:.2f}  |'.format(res[1]*100))
print('Dice Coef: |   {:.2f}  |'.format(res[2]*100))
print('Precision: |   {:.2f}  |'.format(res[3]*100))
print('Recall:    |   {:.2f}  |'.format(res[4]*100))
print('Accuracy:  |   {:.2f}  |'.format(res[5]*100))
print('Tversky:   |   {:.2f}  |'.format(res[6]*100))
print("Loss:      |   {:.2f}  |".format(res[0]*100))
print('________________________')
# Out:
# ~~~~~~~~~~~~~~~Stats after 100 epoch~~~~~~~~~~~~~~~~~~~
#
# -------------On Train Set--------------------------
#
# 360/360 [==============================] - 5s 14ms/step
# ________________________
# IOU:       |   96.10  |
# Dice Coef: |   91.42  |
# Precision: |   96.65  |
# Recall:    |   88.72  |
# Accuracy:  |   95.37  |
# Tversky:   |   90.03  |
# Loss:      |   3.90  |
# ________________________
#
# -------------On Test  Set--------------------------
#
# 50/50 [==============================] - 0s 5ms/step
# ________________________
# IOU:       |   96.05  |
# Dice Coef: |   91.71  |
# Precision: |   94.35  |
# Recall:    |   91.47  |
# Accuracy:  |   95.71  |
# Tversky:   |   91.25  |
# Loss:      |   3.95  |
# ________________________
#
# -------------On validation Set---------------------
#
# 90/90 [==============================] - 0s 5ms/step
# ________________________
# IOU:       |   95.64  |
# Dice Coef: |   90.13  |
# Precision: |   95.37  |
# Recall:    |   87.50  |
# Accuracy:  |   94.66  |
# Tversky:   |   88.79  |
# Loss:      |   4.36  |
# ________________________

# %% [markdown]
# ### Plotting Training Stats

# %% [markdown]
# ## Visualising Predicted Lesions

# %%
plt.figure(figsize=(20, 14))
plt.suptitle('Training Statistics on Train Set')
plt.subplot(2,2,1)
plt.plot(hist.history['loss'], 'red')
plt.title('Loss')
plt.subplot(2,2,2)
plt.plot(hist.history['accuracy'], 'green')
plt.title('Accuracy')
plt.subplot(2,2,3)
plt.plot(hist.history['val_loss'], 'red')
plt.yticks(list(np.arange(0.0, 1.0, 0.10)))
plt.title('Valdiation Loss')
plt.subplot(2,2,4)
plt.plot(hist.history['val_accuracy'], 'green')
plt.yticks(list(np.arange(0.0, 1.0, 0.10)))
plt.title('Validation Accuracy')
plt.show()

# %% [markdown]
# We have trained the model on the **training set**.
# We will make predictions on the unseen **test set**

# %%
img_num = 49
img_pred = model_1.predict(x_test[img_num].reshape(1,224,224,3))
plt.figure(figsize=(16,16))
plt.subplot(1,3,1)
plt.imshow(x_test[img_num])
plt.title('Original Image')
plt.subplot(1,3,2)
plt.imshow(y_test[img_num], plt.cm.binary_r)
plt.title('Ground Truth')
plt.subplot(1,3,3)
plt.imshow(img_pred.reshape(224, 224), plt.cm.binary_r)
plt.title('Predicted Output')
plt.show()

# %%
img_num = 10
img_pred = model_1.predict(x_test[img_num].reshape(1,224,224,3))
plt.figure(figsize=(16,16))
plt.subplot(1,3,1)
plt.imshow(x_test[img_num])
plt.title('Original Image')
plt.subplot(1,3,2)
plt.imshow(y_test[img_num], plt.cm.binary_r)
plt.title('Ground Truth')
plt.subplot(1,3,3)
plt.imshow(img_pred.reshape(224,224), plt.cm.binary_r)
plt.title('Predicted Output')
plt.show()

# %%
img_num = 36
img_pred = model_1.predict(x_test[img_num].reshape(1,224,224,3))
plt.figure(figsize=(16,16))
plt.subplot(1,3,1)
plt.imshow(x_test[img_num])
plt.title('Original Image')
plt.subplot(1,3,2)
plt.imshow(y_test[img_num], plt.cm.binary_r)
plt.title('Ground Truth')
plt.subplot(1,3,3)
plt.imshow(img_pred.reshape(224,224), plt.cm.binary_r)
plt.title('Predicted Output')
plt.show()

# %%
img_num = 32
img_pred = model_1.predict(x_test[img_num].reshape(1,224,224,3))
plt.figure(figsize=(16,16))
plt.subplot(1,3,1)
plt.imshow(x_test[img_num])
plt.title('Original Image')
plt.subplot(1,3,2)
plt.imshow(y_test[img_num], plt.cm.binary_r)
plt.title('Ground Truth')
plt.subplot(1,3,3)
plt.imshow(img_pred.reshape(224,224), plt.cm.binary_r)
plt.title('Predicted Output')
plt.show()

# %%
img_num = 29
img_pred = model_1.predict(x_test[img_num].reshape(1,224,224,3))
plt.figure(figsize=(16,16))
plt.subplot(1,3,1)
plt.imshow(x_test[img_num])
plt.title('Original Image')
plt.subplot(1,3,2)
plt.imshow(y_test[img_num], plt.cm.binary_r)
plt.title('Ground Truth')
plt.subplot(1,3,3)
plt.imshow(img_pred.reshape(224,224), plt.cm.binary_r)
plt.title('Predicted Output')
plt.show()

# %%
img_num = 21
img_pred = model_1.predict(x_test[img_num].reshape(1,224,224,3))
plt.figure(figsize=(16,16))
plt.subplot(1,3,1)
plt.imshow(x_test[img_num])
plt.title('Original Image')
plt.subplot(1,3,2)
plt.imshow(y_test[img_num], plt.cm.binary_r)
plt.title('Ground Truth')
plt.subplot(1,3,3)
plt.imshow(img_pred.reshape(224,224), plt.cm.binary_r)
plt.title('Predicted Output')
plt.show()

# %% [markdown]
# ## Final Enhance

# %% [markdown]
# * Currently the predicted outputs are blurry because the predicted pixel values are in the range 0 - 1.
# * To make clear edge preditions we can enhance our image by rounding up the pixel values to 1 which are > 0.5  .
# * While rounding down the pixel values to 0 which are < 0.5.
# * We can enhance the image to look for absolute shape predicted by ceiling and flooring the predicted values.

# %%
def enhance(img):
    sub = (model_1.predict(img.reshape(1,224,224,3))).flatten()

    for i in range(len(sub)):
        if sub[i] > 0.5:
            sub[i] = 1
        else:
            sub[i] = 0
    return sub

# %%
plt.figure(figsize=(12,12))
plt.suptitle('Comparing the Prediction after enhancement')
plt.subplot(3,2,1)
plt.imshow(y_test[21],plt.cm.binary_r)
plt.title('Ground Truth')
plt.subplot(3,2,2)
plt.imshow(enhance(x_test[21]).reshape(224,224), plt.cm.binary_r)
plt.title('Predicted')
plt.subplot(3,2,3)
plt.imshow(y_test[47],plt.cm.binary_r)
plt.title('Ground Truth')
plt.subplot(3,2,4)
plt.imshow(enhance(x_test[47]).reshape(224,224), plt.cm.binary_r)
plt.title('Predicted')
plt.subplot(3,2,5)
plt.imshow(y_test[36],plt.cm.binary_r)
plt.title('Ground Truth')
plt.subplot(3,2,6)
plt.imshow(enhance(x_test[36]).reshape(224,224), plt.cm.binary_r)
plt.title('Predicted')
plt.show()

# %% [markdown]
# * So we can observe that our results are very good on the Test dataset which suggests that the model is quite robust and well performing too.

# %% [markdown]
# ### **de nada!**
